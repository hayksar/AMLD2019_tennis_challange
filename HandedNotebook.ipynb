# %% [markdown]
# # AMLD workshop by L2F – Learn to Forecast
#
# Welcome to the "Machine Learning Competition: Tennis Analysis" workshop at AMLD 2019, organized by [L2F – Learn to Forecast](https://www.l2f.ch/)!
#
# Starting from Jeff Sackman's crowdsourced [Match Charting Project](https://github.com/JeffSackmann/tennis_MatchChartingProject) dataset, we have put together for you a dataset containing detailed shot-by-shot descriptions of a large collection of points played between the Swiss tennis star Roger Federer and his historical rival Rafael Nadal (RN). The information recorded includes the type of shot, direction of shot, depth of returns, types of errors, and more. This is better explained below; we have also put together some preliminary data preparation to help you get started.
#
# ## Goal
#
# The goal of this workshop is for you to come up with an optimized Phederos – the god of tennis – who will be able to destroy his ancient human rival. Do you think you can beat the beast?
#
# From a more technical perspective, we ask you to provide a strategy function which, given an opponent's shot, will return what you believe to be an optimal response shot. Your answer must be in the form of a JSON dictionary as follows: each key is an opponent's shot, and the corresponding value is a list from which we will uniformly sample your response.
#
# For more clarity, let us consider an example of such a strategy (the strings denote shot types which are better explained below):
#
# *strat* = {'f3': ['b2', 'b2', 'b3', 'v1'], 'f1': ['f2'], ...}.
#
# The keys in this dictionary are shots RN can produce. Suppose RN is performing a forehand on your backhand (the code for this shot is 'f3'); *strat* would reply to this shot in a *probabilistic* way as follows:
# - 'b2' with probability 1/2,
# - 'b3' with probability 1/4,
# - 'v1' with probability 1/4.
#
# On the other hand, the same strategy replies *deterministically* to 'f1' (which is a forehand on our forehand), since we say 'f2' (a forehand straight to RN) with probability 1. In this way, your strategy can incorporate simple deterministic and more complex probabilistic decision-making in an arbitrary way.
#
# ## Testing environment
#
# You have to beat a stochastic model which replies to your shots based on past statistics, but never replies with shots which have historically occurred too rarely. More precisely, this simulation environment will react based on the counting statistics of outcomes to (human) Federer's shots. By 'outcome' here we mean either:
# - a simple reply shot or serve by historical RN (this is perhaps a bit confusing at first, but we consider a player's serve as a 'reply' to the opponent's 'waiting');
# - a 'termination token', e.g. '*' for a winning shot, meaning that RN could not respond to your winning shot and the point terminates, or '@' indicating that with your shot you made an unforced error and lost the point – but note that such tokens can include more detailed information than this and be more than one character long;
# - a shot by RN and a termination token, concatenated in a simple string, e.g., 'f1*' would indicate that our simulated RN replied with a winning forehand shot – ouch!
#
# The Python code for this tester can be found in the last part of this notebook.
#
# ### Important remarks
#
# - The simulation environment will prompt you with shots or termination/waiting tokens from a predetermined list, which can be accessed by loading the pickle file *possible_prompts.p*. Make sure you know how to react to each of the elements in this list!
# - The pickle file *allowed_shots.p* contains a list which can be obtained from the list in *possible_prompts.p* by removing termination and waiting tokens. Replying with a string not in this list leads to losing of the point.
# - The "past statistics" in the stochastic model you will be fighting against come from a hold-out "test set" and **not** from the dataset you have access to. Make sure to build models which generalize well!
# - We will impose a time constraint on the duration of the evalutation of your policy: we expect that your policy can be evaluated on an i7 quadcore 1000000 times in less than 3 minutes.
#
# Will the true heroes of Machine Learning rise? :)

# %% [markdown]
# # Data from Jeff Sackmann's GitHub
#
# As explained above, we provide you with a pandas dataframe (*dataframe.p*), taken from Jeff Sackmann's original dataset.
#
# Each row is one point:
# - the variables 'Player1' and 'Player2' are the name of the players
# - the 'match_id' variable identifies the tournament and date
# - the varaible 'Shots' is a string containing all the shots, played alternatively from the players, during the point
# - the variable 'Shots1' are the shots played only by RF
# - the variable 'Shots0' contain the shots played only by RN
# - The 'Outcome' variable describes the outcome of the point
# - The 'Server' variable has boolean values: it is 1 in case RF is serving
# - The 'Winner' variable has boolean values: it is 1 in case RF has won the point
#
# Numbers are used to indicate direction and depth, while letters are used to specific shot types (e.g. 'f' stands for 'forehand') and error types ('n' stands for 'net'). The letter 'X' means that RN is waiting for RF to serve... don't let him wait too much! A few symbols are used for other purposes, such as types of errors (e.g. '@' means 'unforced error' and '+' indicates an approach shot).
#
# To understand the codes for each shot, we prepared an explanation file named "Shot encodings" with more details. You can also check [this example video](https://drive.google.com/open?id=1Q4obFagfzxkFy_mq9C5gWITQiXxBQfCf) for a visual demonstration of this way of encoding.

# %%
# Importing libraries

import numpy as np
import pickle
import pandas as pd
from nltk import ngrams
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# Historical data

df = pd.read_pickle('dataframe.p')
df.head()
# Out:
#                                             match_id       Player1  \
# 0  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 1  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 2  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 3  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 4  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
#
#          Player2                     Shots         Shots1      Shots0 Outcome  \
# 0  Roger_Federer              4 b;37 f1 f1        b;37 f1        4 f1       *
# 1  Roger_Federer                      6 b3             b3           6      w#
# 2  Roger_Federer                         6                          6       *
# 3  Roger_Federer  5 b18 b2 f1 b2 f1 s2 b+3  b18 f1 f1 b+3  5 b2 b2 s2       *
# 4  Roger_Federer              4 b27 f+3 b1         b27 b1       4 f+3       *
#
#    Server  Winner
# 0       0       1
# 1       0       0
# 2       0       0
# 3       0       1
# 4       0       1

# %%
server_nadal = df[df.Server == 0]

# %%
server_nadal_lost = server_nadal[server_nadal.Winner == 1]

# %%
len(server_nadal), len(server_nadal_lost)
# Out:
# (2256, 809)

# %%
server_nadal.head()
# Out:
#                                             match_id       Player1  \
# 0  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 1  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 2  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 3  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 4  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
#
#          Player2                     Shots         Shots1      Shots0 Outcome  \
# 0  Roger_Federer              4 b;37 f1 f1        b;37 f1        4 f1       *
# 1  Roger_Federer                      6 b3             b3           6      w#
# 2  Roger_Federer                         6                          6       *
# 3  Roger_Federer  5 b18 b2 f1 b2 f1 s2 b+3  b18 f1 f1 b+3  5 b2 b2 s2       *
# 4  Roger_Federer              4 b27 f+3 b1         b27 b1       4 f+3       *
#
#    Server  Winner
# 0       0       1
# 1       0       0
# 2       0       0
# 3       0       1
# 4       0       1

# %%
server_nadal_lost.head()
# Out:
#                                              match_id       Player1  \
# 0   20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 3   20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 4   20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 12  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 19  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
#
#           Player2                     Shots         Shots1       Shots0  \
# 0   Roger_Federer              4 b;37 f1 f1        b;37 f1         4 f1
# 3   Roger_Federer  5 b18 b2 f1 b2 f1 s2 b+3  b18 f1 f1 b+3   5 b2 b2 s2
# 4   Roger_Federer              4 b27 f+3 b1         b27 b1        4 f+3
# 12  Roger_Federer  5 b28 f3 b2 b;2 f1 b1 f1   b28 b2 f1 f1  5 f3 b;2 b1
# 19  Roger_Federer      4 f17 b1 f3 f2 f1 b2      f17 f3 f1   4 b1 f2 b2
#
#    Outcome  Server  Winner
# 0        *       0       1
# 3        *       0       1
# 4        *       0       1
# 12       *       0       1
# 19      d@       0       1

# %%
nadal_serve_win_response = {}
for i in server_nadal_lost.Shots.values:
    shots_s = i.split(' ')
    
    for k in range(0, len(shots_s) - 1, 2):
        n_shot, f_shot = shots_s[k:k+2]
        if n_shot in nadal_serve_win_response:
            nadal_serve_win_response[n_shot].append(f_shot)
        else:
            nadal_serve_win_response[n_shot] = [f_shot]

# %%
server_federer = df[df.Server == 1]

# %%
server_federer_won = server_federer[server_federer.Winner == 1]

# %%
server_federer_won
# Out:
#                                                match_id        Player1  \
# 5     20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 7     20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 8     20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 9     20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 14    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 15    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 16    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 18    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 25    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 26    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 27    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 34    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 35    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 36    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 38    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 41    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 42    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 43    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 48    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 49    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 53    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 54    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 56    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 57    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 65    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 66    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 71    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 72    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 74    20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...   Rafael_Nadal
# 82        20151101-M-Basel-F-Rafael_Nadal-Roger_Federer   Rafael_Nadal
# ...                                                 ...            ...
# 4437  20050403-M-Miami_Masters-F-Roger_Federer-Rafae...  Roger_Federer
# 4438  20050403-M-Miami_Masters-F-Roger_Federer-Rafae...  Roger_Federer
# 4439  20050403-M-Miami_Masters-F-Roger_Federer-Rafae...  Roger_Federer
# 4444  20050403-M-Miami_Masters-F-Roger_Federer-Rafae...  Roger_Federer
# 4445  20050403-M-Miami_Masters-F-Roger_Federer-Rafae...  Roger_Federer
# 4446  20050403-M-Miami_Masters-F-Roger_Federer-Rafae...  Roger_Federer
# 4451  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4452  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4453  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4457  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4458  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4459  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4464  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4465  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4467  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4473  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4474  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4481  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4482  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4492  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4493  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4494  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4500  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4502  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4505  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4506  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4507  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4516  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4517  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
# 4518  20040328-M-Miami_Masters-R32-Roger_Federer-Raf...  Roger_Federer
#
#             Player2                                         Shots  \
# 5     Roger_Federer                                          4 b2
# 7     Roger_Federer                            4 b28 b2 s3 f+1 b1
# 8     Roger_Federer                                             4
# 9     Roger_Federer                                   5 f37 s1 b1
# 14    Roger_Federer                         6 b27 f+3 f3 z1 m3 o3
# 15    Roger_Federer  4 b29 f1 s2 f3 f3 b2 f2 b2 b2 f1 b2 b2 b1 f1
# 16    Roger_Federer                            4 f238 f2 f3 b3 f3
# 18    Roger_Federer                                          c6 s
# 25    Roger_Federer                                           6 f
# 26    Roger_Federer                                             4
# 27    Roger_Federer                                             6
# 34    Roger_Federer                                             6
# 35    Roger_Federer                                4 f38 f3 f2 f1
# 36    Roger_Federer                                      4 b28 f3
# 38    Roger_Federer                                          6 f1
# 41    Roger_Federer                                4 f28 f1 b3 f3
# 42    Roger_Federer                                          4 f1
# 43    Roger_Federer                                             6
# 48    Roger_Federer                                          4 s2
# 49    Roger_Federer                                  4+ f37 z1 b1
# 53    Roger_Federer                            4+ s37 f1 b1 v3 f1
# 54    Roger_Federer                                             6
# 56    Roger_Federer                                     4+ b28 z3
# 57    Roger_Federer                                          5 f3
# 65    Roger_Federer                                  6+ b28 z3 f2
# 66    Roger_Federer                                          4 b1
# 71    Roger_Federer                                             6
# 72    Roger_Federer                                         4+ f1
# 74    Roger_Federer                4 b27 b2 f1 f;1 b2 f2 b2 b2 b3
# 82    Roger_Federer                                      4 b18 f3
# ...             ...                                           ...
# 4437   Rafael_Nadal                             5 f27 f+1 m1 o3 f
# 4438   Rafael_Nadal                                          4 f1
# 4439   Rafael_Nadal                                             6
# 4444   Rafael_Nadal                                     4 f28 o=1
# 4445   Rafael_Nadal                                  4 f37 s2 f+2
# 4446   Rafael_Nadal                             5 b17 f2 f3 b2 f1
# 4451   Rafael_Nadal                             5 f39 b2 f1 f1 b1
# 4452   Rafael_Nadal                                          5 r2
# 4453   Rafael_Nadal                                             4
# 4457   Rafael_Nadal                       6 f29 f3 f3 f1 b1 f1 b2
# 4458   Rafael_Nadal                                          6 b3
# 4459   Rafael_Nadal                                          6 b2
# 4464   Rafael_Nadal                                             4
# 4465   Rafael_Nadal                                          4 b2
# 4467   Rafael_Nadal                                   5 f28 f1 b2
# 4473   Rafael_Nadal                                          4 f2
# 4474   Rafael_Nadal                                     4 f27 f-1
# 4481   Rafael_Nadal                                    4+ b27 o-3
# 4482   Rafael_Nadal                                             4
# 4492   Rafael_Nadal                                             4
# 4493   Rafael_Nadal                                      6 b28 f3
# 4494   Rafael_Nadal                                             6
# 4500   Rafael_Nadal                      5 f27 f3 f2 f+1 b1 v1 s2
# 4502   Rafael_Nadal                 5 b28 f2 f1 f1 f1 f1 b2 f1 b3
# 4505   Rafael_Nadal                                     4 b27 f+1
# 4506   Rafael_Nadal                    6 b18 f2 f3 b2 f3 b3 f1 f3
# 4507   Rafael_Nadal                                         4+ b1
# 4516   Rafael_Nadal                                     4 b27 f+1
# 4517   Rafael_Nadal                                             6
# 4518   Rafael_Nadal                                   4 b19 f1 b3
#
#                       Shots1                 Shots0 Outcome  Server  Winner
# 5                          4                     b2      d#       1       1
# 7                   4 b2 f+1              b28 s3 b1      w#       1       1
# 8                          4                              *       1       1
# 9                       5 s1                 f37 b1      w@       1       1
# 14               6 f+3 z1 o3              b27 f3 m3       *       1       1
# 15    4 f1 f3 b2 b2 f1 b2 f1  b29 s2 f3 f2 b2 b2 b1       *       1       1
# 16                   4 f2 b3             f238 f3 f3      w@       1       1
# 18                        c6                      s       #       1       1
# 25                         6                      f       #       1       1
# 26                         4                              *       1       1
# 27                         6                              *       1       1
# 34                         6                              *       1       1
# 35                   4 f3 f1                 f38 f2       *       1       1
# 36                      4 f3                    b28       *       1       1
# 38                         6                     f1      x#       1       1
# 41                   4 f1 f3                 f28 b3       *       1       1
# 42                         4                     f1      n#       1       1
# 43                         6                              *       1       1
# 48                         4                     s2      d#       1       1
# 49                     4+ z1                 f37 b1      n#       1       1
# 53                  4+ f1 v3              s37 b1 f1      d#       1       1
# 54                         6                              *       1       1
# 56                     4+ z3                    b28       *       1       1
# 57                         5                     f3      w@       1       1
# 65                     6+ z3                 b28 f2      d#       1       1
# 66                         4                     b1      d@       1       1
# 71                         6                              *       1       1
# 72                        4+                     f1      n@       1       1
# 74            4 b2 f;1 f2 b2        b27 f1 b2 b2 b3      d@       1       1
# 82                      4 f3                    b18       *       1       1
# ...                      ...                    ...     ...     ...     ...
# 4437                5 f+1 o3               f27 m1 f       #       1       1
# 4438                       4                     f1      w@       1       1
# 4439                       6                              *       1       1
# 4444                   4 o=1                    f28       *       1       1
# 4445                    4 s2                f37 f+2      n@       1       1
# 4446                 5 f2 b2              b17 f3 f1      w@       1       1
# 4451                 5 b2 f1              f39 f1 b1      n@       1       1
# 4452                       5                     r2      d#       1       1
# 4453                       4                              *       1       1
# 4457              6 f3 f1 f1           f29 f3 b1 b2      n#       1       1
# 4458                       6                     b3      w#       1       1
# 4459                       6                     b2      n#       1       1
# 4464                       4                              *       1       1
# 4465                       4                     b2      d#       1       1
# 4467                    5 f1                 f28 b2      n@       1       1
# 4473                       4                     f2      d#       1       1
# 4474                   4 f-1                    f27       *       1       1
# 4481                  4+ o-3                    b27       *       1       1
# 4482                       4                              *       1       1
# 4492                       4                              *       1       1
# 4493                    6 f3                    b28       *       1       1
# 4494                       6                              *       1       1
# 4500             5 f3 f+1 v1           f27 f2 b1 s2      n#       1       1
# 4502           5 f2 f1 f1 f1        b28 f1 f1 b2 b3      w@       1       1
# 4505                   4 f+1                    b27       *       1       1
# 4506           6 f2 b2 b3 f3           b18 f3 f3 f1       *       1       1
# 4507                      4+                     b1      n#       1       1
# 4516                   4 f+1                    b27       *       1       1
# 4517                       6                              *       1       1
# 4518                    4 f1                 b19 b3      w@       1       1
#
# [1438 rows x 9 columns]

# %%
federer_serve_win_response = {}
for i in server_federer_won.Shots.values:
    shots_s = i.split(' ')
    if len(shots_s) < 3:
        continue
    for k in range(1, len(shots_s) - 1, 2):
        n_shot, f_shot = shots_s[k:k+2]
        if n_shot in federer_serve_win_response:
            federer_serve_win_response[n_shot].append(f_shot)
        else:
            federer_serve_win_response[n_shot] = [f_shot]

# %%
promp_dict = ['']

# %%
all_dict = federer_serve_win_response.copy()
for k, v in nadal_serve_win_response.items():
    if k in all_dict:
        all_dict[k].extend(v)
    else:
        all_dict[k] = v

# %%
from collections import Counter

# %%
cnt = Counter([i.split(' ')[0] for i in server_federer_won.Shots.values])

# %%
serves = [i.split(' ')[0] for i in server_federer_won.Shots.values if cnt[i] > 10]

# %%
all_dict['X'] = serves

# %% [markdown]
# # Prompts and shots
#
# We provide here the list of possible prompts and allowed shots – historically the most common shots – that you have to use. There are many more shots in the dataframe, but we only stick to the 100 shots provided and the 40 shots provided. It means that the historical RN/tester, will only shoot with one of the 100 prompts and you can reply using only one of the 40 shots.

# %%
# Loading the prompts and the shots

all_shots = pickle.load(open("allowed_shots.p", "rb"))
poss_prompts = pickle.load(open("possible_prompts.p" , "rb"))

print('Allowed shots: ', all_shots, '\n')
print('Possible prompts: ', poss_prompts)
# Out:
# Allowed shots:  ['4', '4+', '5', '6', '6+', 'X', 'b', 'b1', 'b17', 'b18', 'b19', 'b2', 'b27', 'b28', 'b29', 'b3', 'b37', 'b38', 'f', 'f+1', 'f+3', 'f1', 'f18', 'f2', 'f27', 'f28', 'f29', 'f3', 'f37', 'f38', 'r2', 's', 's1', 's2', 's28', 's3', 'v1', 'v3', 'z1', 'z3']
#
# Possible prompts:  ['f3', 'f1', 'b2', 'b1', 'X', 'f2', 'b3', '4', '6', '5', '*', 'b28', 'f28', 'b27', 's2', 'f+3', 's3', 'n@', 'f+1', 'b18', 'd@', 'f38', 'b29', 's1', 'b38', 'f37', '#', 'w@', 'f27', 'f29', 'n#', 'd#', 'f', 'b', 's28', 'b37', 'b17', 'f1*', 'b19', 'b39', 'w#', 'r2', 'f18', 'f39', 'z3', 'v1', 'v3', 'f#', 's27', '4+', '6+', 'z1', 'b1*', 'f3*', 'm2', 'f17', 'r3', 's', 'r1', 's29', 's38', 'b+1', 'z2', 'o3', 'c6', 'v2', 'c4', 'b1w@', 'b#', 'b1n@', 'b+3', 'f19', 'b3*', 'f+2', 'f1w@', 'b3w@', 's37', 's39', 'f3n@', 'f3w@', 'm3', 'f1n@', 'b1d@', 'b2n#', 'f2d@', 'f1n#', 'b1w#', 's#', 'b1n#', 'x@', 'f1w#', 'y3', 'f2d#', 'b2d@', 'f2n#', 'f3d@', 'y1', 'b3w#', 'o1', 'f-3']

# %%
all_chars = set([])
for i in all_shots:
    all_chars = all_chars.union(set(i))

# %%
all_chars = ''.join(list(all_chars))
all_chars
# Out:
# 's2317v56+r8z94Xfb'

# %%
mapper = set()
for k, v in all_dict.items():
    v_cnt = Counter(v)
    mapper = mapper.union(set([i for i in v_cnt.keys() if i not in all_shots]))

# %%
def transform(s):
    if s.startswith('f'):
        return ''.join([i for i in s if i in all_chars])
    else:
        return ''.join([i for i in s if i in [j for j in all_chars if j!='+']])

# %%
mapper2 = {i: transform(i) if transform(i) not in ['0', '4', '5', '6'] else '' for i in mapper}

# %%
mapper2
# Out:
# {'1': '1',
#  'b+1': 'b1',
#  'b+18': 'b18',
#  'b+2': 'b2',
#  'b+28': 'b28',
#  'b+3': 'b3',
#  'b-3': 'b3',
#  'b3-': 'b3',
#  'b32': 'b32',
#  'b39': 'b39',
#  'b8': 'b8',
#  'b9': 'b9',
#  'b;17': 'b17',
#  'b;2': 'b2',
#  'b;27': 'b27',
#  'b;28': 'b28',
#  'b;3': 'b3',
#  'b;37': 'b37',
#  'c4': '',
#  'c6': '',
#  'f+': 'f+',
#  'f+-1': 'f+1',
#  'f+2': 'f+2',
#  'f+29': 'f+29',
#  'f-1': 'f1',
#  'f-2': 'f2',
#  'f-3': 'f3',
#  'f1+1': 'f1+1',
#  'f1-': 'f1',
#  'f17': 'f17',
#  'f19': 'f19',
#  'f3+3': 'f3+3',
#  'f3-': 'f3',
#  'f39': 'f39',
#  'f8': 'f8',
#  'f;1': 'f1',
#  'f;17': 'f17',
#  'f;2': 'f2',
#  'f;3': 'f3',
#  'h': '',
#  'h+3': '3',
#  'h1': '1',
#  'h2': '2',
#  'h3': '3',
#  'i1': '1',
#  'i2': '2',
#  'i3': '3',
#  'i=2': '2',
#  'j+1': '1',
#  'j+2': '2',
#  'j1': '1',
#  'j2': '2',
#  'j3': '3',
#  'j;1': '1',
#  'j=+1': '1',
#  'k': '',
#  'k3': '3',
#  'l': '',
#  'l1': '1',
#  'm': '',
#  'm1': '1',
#  'm2': '2',
#  'o': '',
#  'o-3': '3',
#  'o1': '1',
#  'o2': '2',
#  'o3': '3',
#  'o=1': '1',
#  'o=2': '2',
#  'o=3': '3',
#  'p2': '2',
#  'p3': '3',
#  'r+1': 'r1',
#  'r1': 'r1',
#  'r28': 'r28',
#  'r29': 'r29',
#  'r3': 'r3',
#  's+1': 's1',
#  's+19': 's19',
#  's+2': 's2',
#  's+3': 's3',
#  's-1': 's1',
#  's-2': 's2',
#  's17': 's17',
#  's18': 's18',
#  's19': 's19',
#  's27': 's27',
#  's29': 's29',
#  's37': 's37',
#  's38': 's38',
#  's39': 's39',
#  'u+1': '1',
#  'u+3': '3',
#  'u-1': '1',
#  'u-3': '3',
#  'u1': '1',
#  'u3': '3',
#  'v': 'v',
#  'v2': 'v2',
#  'y': '',
#  'y+1': '1',
#  'y+3': '3',
#  'y-1': '1',
#  'y1': '1',
#  'y2': '2',
#  'y3': '3',
#  'z+1': 'z1',
#  'z2': 'z2',
#  'z=3': 'z3'}

# %%
all_dict2 = {}
for k, v in all_dict.copy().items():
    v1 = [transform(i) for i in v if transform(i) in all_shots]
    all_dict2[k] = v1

# %% [markdown]
# # Testing function for your model performances
#
# See the file *aux_functions*.  The following function makes the historical RN become alive and play against you!

# %%
from aux_functions import *

# %%
Model, shots_opo_com = aux_fn(df, poss_prompts, all_shots)

# %%
# Building up the model function

#################### The threshold on shots rarity ###################
threshold = 1                                                        #
######################################################################

# Given current prompt p_t and shot s_t, return next prompt p_(t+1)
def model(prompt, shot):
    n_grams_ps = Model[poss_prompts.index(prompt), all_shots.index(shot)]
    if(len(n_grams_ps) > threshold):    # exclude rare reactions
        return np.random.choice(n_grams_ps)
    return 'n@'   # when (p, s) never happened, return unforced error in net

# Example: RN just served ('5') and we want to reply with a forehand ('f28'). This is what RN will reply (stochastic function)
model('5', 'f28')
# Out:
# 'f3'

# %%
all_dict2
# Out:
# {'4': ['b37',
#   'b27',
#   'f18',
#   'b28',
#   'f38',
#   'f28',
#   'b18',
#   'f29',
#   'f18',
#   'b37',
#   'f18',
#   'b19',
#   'b28',
#   'f29',
#   'b37',
#   's28',
#   'b19',
#   'b28',
#   'b28',
#   'b28',
#   'f29',
#   'b28',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'b2',
#   'b28',
#   'f18',
#   'b29',
#   'b38',
#   'b37',
#   'b37',
#   'f18',
#   'b38',
#   'b18',
#   'b28',
#   'b27',
#   'b28',
#   'b18',
#   'b28',
#   'b28',
#   'b29',
#   'f38',
#   'f18',
#   'b18',
#   'b19',
#   'b27',
#   'b38',
#   'b28',
#   'b19',
#   'b18',
#   'f18',
#   'b29',
#   'b27',
#   'b19',
#   'b18',
#   'b38',
#   'b27',
#   'f18',
#   'b18',
#   'b18',
#   'b38',
#   'b27',
#   'b27',
#   'b29',
#   'b19',
#   's28',
#   's28',
#   's28',
#   'f28',
#   'b37',
#   'f28',
#   'b28',
#   'b38',
#   's28',
#   'b28',
#   'b18',
#   'b28',
#   'b37',
#   'b28',
#   'b27',
#   'b28',
#   'b27',
#   's28',
#   'b28',
#   'b28',
#   'b17',
#   'b28',
#   'f38',
#   'b28',
#   'b27',
#   'b18',
#   'b29',
#   'b29',
#   'b37',
#   's28',
#   'b18',
#   'b28',
#   'b28',
#   'b38',
#   'b28',
#   'b28',
#   'f38',
#   'b27',
#   'f18',
#   'b29',
#   'f28',
#   'b19',
#   'b28',
#   'b28',
#   'f28',
#   'b28',
#   'f28',
#   'b28',
#   'b28',
#   'b18',
#   'b29',
#   'b29',
#   'b28',
#   'b37',
#   'b27',
#   'b19',
#   'b29',
#   'b27',
#   'b29',
#   'b29',
#   'b28',
#   'b29',
#   'b28',
#   'b37',
#   'b29',
#   'b29',
#   'b28',
#   'b37',
#   'b37',
#   'f28',
#   'b19',
#   'b19',
#   'b38',
#   'b27',
#   'b37',
#   'b37',
#   'b37',
#   'b28',
#   'b28',
#   'b38',
#   'b28',
#   'f29',
#   'b29',
#   'b28',
#   'b38',
#   'b38',
#   'b29',
#   'b37',
#   'b38',
#   'f18',
#   's',
#   'b28',
#   'f28',
#   'b28',
#   'b28',
#   'b38',
#   'b18',
#   'b38',
#   'f29',
#   'b28',
#   'b27',
#   'b28',
#   'b28',
#   'b38',
#   'b28',
#   'b28',
#   'b19',
#   'b18',
#   'f28',
#   'b28',
#   'b28',
#   'b29',
#   'b28',
#   'b27',
#   'b17',
#   's28',
#   'f28',
#   'b28',
#   'f28',
#   'b27',
#   'b29',
#   'b28',
#   'b18',
#   'b28',
#   's28',
#   's28',
#   'b28',
#   'b19',
#   'b19',
#   'b19',
#   's28',
#   'b27',
#   'b27',
#   'b28',
#   'b29',
#   'b37',
#   'b27',
#   's28',
#   'b27',
#   'b19',
#   'f29',
#   'b27',
#   'b29',
#   'b19',
#   'f28',
#   's28',
#   'b29',
#   's28',
#   'f28',
#   'f28',
#   'b27',
#   'b18',
#   'b28',
#   'f28',
#   'f28',
#   'f18',
#   'b28'],
#  '4+': ['s'],
#  '5': ['b18',
#   'b28',
#   'f38',
#   'f28',
#   'f18',
#   'f28',
#   'f28',
#   'b18',
#   's28',
#   's28',
#   'b28',
#   'b18',
#   'f1',
#   'b2',
#   'b2',
#   'f1',
#   'b2',
#   'f27',
#   'b28',
#   'f29',
#   'b18',
#   'b27',
#   'b29',
#   'f29',
#   'b19',
#   'f38',
#   'f37',
#   'b18',
#   'b29',
#   'f18',
#   'b18',
#   'b38',
#   'b18',
#   'b28',
#   'b28',
#   'b27',
#   'b28',
#   'b18',
#   'b28',
#   'f38',
#   'b28',
#   'b27',
#   'f29',
#   'f29',
#   'b27',
#   'b27',
#   'f29',
#   'b29',
#   'f29',
#   'f28',
#   'b18',
#   'f29',
#   'b28',
#   'b18',
#   'f18',
#   'b27',
#   'b18',
#   'b19',
#   'b27',
#   'b29',
#   'f27',
#   'b29',
#   'f27',
#   'b19',
#   'b28',
#   'f37',
#   'b28',
#   'b28',
#   'f27',
#   'b28',
#   'f29',
#   'b18',
#   'f28',
#   'b28',
#   'b28',
#   'b38',
#   'b28',
#   'f28',
#   'b28',
#   'f29',
#   'b28',
#   'b28',
#   'f29',
#   'b27',
#   'b38',
#   'b28',
#   'f28',
#   'b19',
#   'f38',
#   'f29',
#   'b29',
#   'f38',
#   'b18',
#   'f38',
#   'b18',
#   'b17',
#   'f18',
#   'b28',
#   'b28',
#   'b28',
#   'f29',
#   'b17',
#   'b27',
#   'f29',
#   'b29',
#   's28',
#   'f27',
#   'f29',
#   'b18',
#   'b28',
#   'f28',
#   'b27',
#   'b18',
#   'f29',
#   'b28',
#   'f18',
#   'f28',
#   'b28',
#   'f18',
#   'b18',
#   'f18',
#   'b27',
#   'f28',
#   'f28',
#   'f18',
#   'f18',
#   'b28',
#   'f27',
#   'f18',
#   'b28',
#   'b29',
#   'f38',
#   'f28',
#   'b28',
#   'b18',
#   'b28',
#   'b19',
#   'f37',
#   'f37',
#   'f27',
#   'f28',
#   'b18',
#   'b17',
#   'f28',
#   'b28',
#   'b28',
#   'f28',
#   'b28',
#   's28',
#   'f27',
#   'f18',
#   'b18',
#   'b18'],
#  '5+': ['b37'],
#  '6': ['b28',
#   'b17',
#   'b28',
#   'b18',
#   'b19',
#   'b28',
#   'b28',
#   'b27',
#   'f28',
#   'f27',
#   'b28',
#   'b19',
#   'b19',
#   'b29',
#   'b18',
#   'b2',
#   'b2',
#   'b2',
#   'f1',
#   'b2',
#   'b1',
#   'b1',
#   'b1',
#   'b1',
#   'b2',
#   'b28',
#   'b19',
#   'b19',
#   'b27',
#   'b29',
#   'b27',
#   'b18',
#   'b19',
#   'b18',
#   'b19',
#   'b18',
#   'b27',
#   'b19',
#   'f29',
#   'b18',
#   'b19',
#   'b27',
#   'b28',
#   'b27',
#   'b27',
#   'b18',
#   's28',
#   'f27',
#   'b37',
#   'b18',
#   'b18',
#   'b28',
#   'f29',
#   'b28',
#   'f28',
#   'b29',
#   'b28',
#   'b28',
#   'f18',
#   'f28',
#   'f18',
#   'f28',
#   'b29',
#   'b18',
#   'b28',
#   'b28',
#   'b28',
#   'b18',
#   'b19',
#   'b19',
#   'b28',
#   'b19',
#   'f18',
#   'b28',
#   'b19',
#   'b18',
#   'b18',
#   'b38',
#   'b18',
#   'b28',
#   'b27',
#   'b19',
#   'b17',
#   'b18',
#   'b27',
#   'b19',
#   'b28',
#   'b28',
#   'b28',
#   'b17',
#   'b29',
#   'f18',
#   'b18',
#   'b28',
#   'b28',
#   'b18',
#   'b18',
#   'f18',
#   'b17',
#   'b19',
#   'b29',
#   'f28',
#   'f28',
#   'f28',
#   'b19',
#   'f29',
#   'f29',
#   'f27',
#   'b27',
#   'b18',
#   'b17',
#   'f28',
#   'b29',
#   'b19',
#   'b19',
#   'f18',
#   'b19',
#   'b19',
#   'b18',
#   'f27',
#   'f28',
#   'b29',
#   'f18',
#   'b18',
#   'b19',
#   'f28',
#   'b28',
#   'b28',
#   'b29',
#   'b18',
#   'b18',
#   'f18',
#   'b28',
#   'b28',
#   'b28',
#   's28',
#   'b27',
#   'b17',
#   'b19',
#   'b28',
#   'b38',
#   'b27',
#   'b19',
#   'f29',
#   'b19',
#   'b38',
#   'b19',
#   'f29',
#   'f27',
#   'b29',
#   'b28',
#   'b37',
#   'b19',
#   'f38',
#   'b18',
#   'f28',
#   'b19',
#   'b29',
#   'b28',
#   'b29',
#   'b28',
#   'b38',
#   'b29',
#   'b19',
#   'b18',
#   'f27',
#   'b19',
#   'b19',
#   'b19',
#   'b28',
#   'b27',
#   'b18',
#   'b28',
#   'b18',
#   'b17',
#   'b28',
#   'b27',
#   'b18',
#   'b18',
#   'b18',
#   'b18',
#   'b28',
#   'b28',
#   'b28',
#   's28',
#   'b38',
#   'b27',
#   'b18',
#   'b18',
#   'b29',
#   'f29',
#   'b28',
#   'f29',
#   'f29',
#   'b29',
#   'b19',
#   'f29',
#   'b18',
#   'b18',
#   'f28',
#   'b17',
#   'f38',
#   'f28',
#   'b28',
#   'b29',
#   'b27',
#   'b28',
#   'b28',
#   's28',
#   'b19',
#   'b19',
#   'b17',
#   'b27',
#   'b19',
#   'b28',
#   'f18',
#   'b28',
#   'b28',
#   'b27',
#   'b28',
#   'b27',
#   'b18',
#   's28',
#   'f27',
#   's28',
#   's28',
#   'b28',
#   'b19',
#   's28',
#   'b28',
#   'b18',
#   'b19',
#   'b38',
#   'b28',
#   'f18',
#   'b29',
#   'b19',
#   'b28',
#   'b28',
#   'b27',
#   'f28',
#   'f29'],
#  'X': ['4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '5',
#   '6',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '5',
#   '5',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   '5',
#   '4',
#   '6',
#   '5',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '4',
#   '5',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6'],
#  'b': ['f', 'b', 'f', 'v1'],
#  'b+1': ['f1'],
#  'b+2': ['b3'],
#  'b+3': ['s2', 's2', 's1', 'b3'],
#  'b+38': ['s3'],
#  'b-1': ['f3'],
#  'b-3': ['z1'],
#  'b1': ['f1',
#   'v3',
#   'f3',
#   'f1',
#   'v3',
#   'f1',
#   'f2',
#   'v3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f',
#   'f2',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f2',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f+3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f2',
#   'f3',
#   'f3',
#   'f1',
#   'f2',
#   'v3',
#   'f2',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'v3',
#   'f1',
#   'v1',
#   'v1',
#   'f2',
#   'f1',
#   'f2',
#   'f3',
#   'f+1',
#   'f3',
#   'f1',
#   'f2',
#   'v1',
#   'f1',
#   'f3',
#   'f+3',
#   'f1',
#   'f1',
#   'f+1',
#   'v3',
#   'f1',
#   'f+1',
#   'f3',
#   'v1',
#   'v3',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f2',
#   'f2',
#   'f2',
#   'f1',
#   'f2',
#   'v3',
#   'f1',
#   'f1',
#   'f2',
#   'f+3',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'v3',
#   'f1',
#   'v3',
#   'r2',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f+3',
#   'v3',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'v1',
#   'f1',
#   'f3',
#   'f1',
#   'f+1',
#   'v1',
#   'f+1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'v1',
#   'f3',
#   'v3',
#   'f+1',
#   'f1',
#   'v3',
#   'f1',
#   'v3',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f2',
#   'v3',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'v3',
#   'f2',
#   'f+3',
#   'f1',
#   'v3',
#   'f1',
#   'v1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f2',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f3',
#   'f1',
#   'f+1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f+3',
#   'f1',
#   'f1',
#   'v3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f2',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f+3',
#   'f3',
#   'r2',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   'f1',
#   'f3',
#   'f+1',
#   'v3',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f3',
#   'f+3',
#   'f3',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f2',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f+1',
#   'v3',
#   'f1',
#   'f1',
#   'f+3',
#   'f3',
#   'f1',
#   'f1',
#   'f+3',
#   'f2',
#   'f1',
#   'f3',
#   'f+3',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'v3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f+3',
#   'f3',
#   'f1',
#   'f1',
#   'f+3',
#   'f1',
#   'f+3',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f+3',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1'],
#  'b17': ['v3',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f2',
#   'v3',
#   'f1',
#   'f1',
#   'f+1',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f3',
#   'v3',
#   'f3',
#   'v3',
#   'f1',
#   'f+3',
#   'f+3',
#   'f+3',
#   'v3',
#   'f2'],
#  'b18': ['f3',
#   'f3',
#   'r2',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f+3',
#   'f3',
#   'f1',
#   'f1',
#   'f+3',
#   'f+3',
#   'f+1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f2'],
#  'b19': ['f2', 'f3', 'f1', 'f1'],
#  'b2': ['f1',
#   'b2',
#   'f2',
#   'b2',
#   'f2',
#   'f1',
#   'b2',
#   'f1',
#   'f+1',
#   'f3',
#   'f+1',
#   'z1',
#   'f1',
#   'f1',
#   'f3',
#   'b2',
#   'f3',
#   'f1',
#   'f+3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f2',
#   'f+1',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'b2',
#   'f3',
#   'f1',
#   'b1',
#   'f1',
#   'v3',
#   'f3',
#   'b1',
#   'f2',
#   'b2',
#   'f3',
#   'f3',
#   'z3',
#   'f3',
#   'f1',
#   'f2',
#   'f2',
#   'b1',
#   'f1',
#   'b3',
#   'f1',
#   'v1',
#   'f2',
#   'f+3',
#   'b2',
#   'b3',
#   'f2',
#   'f+3',
#   'f1',
#   'f2',
#   'b1',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'b3',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'v1',
#   'f3',
#   'z1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f2',
#   'f1',
#   'z3',
#   'f+1',
#   'v3',
#   'f+3',
#   'f1',
#   'f1',
#   'f2',
#   'b1',
#   'f1',
#   'f3',
#   'f1',
#   'f+1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'b2',
#   'f1',
#   'f3',
#   'f+3',
#   'f1',
#   'f3',
#   'b2',
#   'v3',
#   'f2',
#   'v1',
#   'f2',
#   'f1',
#   'f+3',
#   'f+1',
#   'f3',
#   'f2',
#   'b2',
#   'b2',
#   'f1',
#   'f+1',
#   'z1',
#   'z1',
#   'f1',
#   'f3',
#   'f+3',
#   'f3',
#   'f1',
#   'b2',
#   'f2',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'f2',
#   'f2',
#   'z3',
#   'f+3',
#   'f1',
#   'v3',
#   'f+1',
#   'z3',
#   'f2',
#   'f3',
#   'f+1',
#   'f+3',
#   'z3',
#   'f2',
#   'f2',
#   'z1',
#   'v3',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'z1',
#   'f1',
#   'f2',
#   'f+1',
#   'f+3',
#   'b2',
#   'v3',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   'b3',
#   'b1',
#   'f2',
#   'b2',
#   'f1',
#   'b3',
#   's1',
#   'f1',
#   'b3',
#   'f1',
#   'b1',
#   'b3',
#   'f2',
#   'f+3',
#   'f2',
#   'f3',
#   'f+1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f+3',
#   'b3',
#   'b2',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'b2',
#   'f1',
#   's3',
#   'f3',
#   'b3',
#   'f1',
#   's3',
#   'f2',
#   'f2',
#   'f+1',
#   'v3',
#   'f2',
#   'f3',
#   'b3',
#   'f+3',
#   'f1',
#   'b2',
#   'f3',
#   'f1',
#   'f3',
#   'b2',
#   'b3',
#   'b2',
#   'f3',
#   'f+3',
#   'b3',
#   'f1',
#   'b3',
#   'b2',
#   'b2',
#   'f1',
#   'f2',
#   's1',
#   'f1',
#   'f2',
#   'f3',
#   'b2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'b2',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'b2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'b3',
#   'b1',
#   'f3',
#   'b3',
#   'f+1',
#   'b3',
#   'b1',
#   'f2',
#   'f1',
#   'f3',
#   'b3',
#   'f+1',
#   'f+3',
#   'f1',
#   'b1',
#   'f+1',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f+1',
#   'f3',
#   'f+3',
#   'f1',
#   'f3',
#   'f+1',
#   'f3',
#   'f1',
#   'b2',
#   'f1',
#   'f1',
#   'f1',
#   'f+3',
#   'v1',
#   'v1',
#   'f1',
#   'f1',
#   'f3',
#   'b2',
#   'v1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   's1',
#   'f1',
#   'b3',
#   'f3',
#   'b3',
#   'f3',
#   'f2',
#   'f+3',
#   'b3',
#   'f3',
#   'v3',
#   'b2',
#   'b3',
#   'f+1',
#   'b2',
#   'f2',
#   'b1',
#   'b3',
#   'f+1',
#   'f2',
#   'f+1',
#   'b3',
#   'f1',
#   'b2',
#   'f3',
#   'f2',
#   'f2',
#   'f2',
#   'f1',
#   'f+3',
#   'f1',
#   'f1',
#   's2',
#   'f1',
#   'f1',
#   'b1',
#   'b2',
#   'f1',
#   'b2',
#   'f+3',
#   'f+3',
#   'f1',
#   'f+3',
#   'f1',
#   'f1',
#   'f2',
#   'f+3',
#   'f3',
#   'f1',
#   'f3',
#   'z3',
#   'f1',
#   'b3',
#   'f+1',
#   'f1',
#   'f3',
#   'f+3',
#   's3',
#   'f3',
#   'b3',
#   'f1',
#   'f2',
#   's1',
#   'f3',
#   'f3',
#   'b3',
#   'f1',
#   'b1',
#   'b2',
#   'f1',
#   'f+3',
#   'f1',
#   'f2',
#   'f1',
#   'b1',
#   'b1',
#   'z1',
#   'z3',
#   'f1',
#   'f+1',
#   'f3',
#   'f1',
#   'f1',
#   'v1',
#   'f+3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'b2',
#   'f2',
#   'f3',
#   'b2',
#   'b2',
#   'v3',
#   'f3',
#   'f1',
#   'f1',
#   'f3'],
#  'b27': ['f+3',
#   'b2',
#   'z1',
#   'f3',
#   'z3',
#   'z3',
#   'z3',
#   'f2',
#   'b2',
#   'f+1',
#   'f+1',
#   'f1',
#   'f+3',
#   'v3',
#   'z3',
#   'f3',
#   'f+1',
#   'v1',
#   'v1',
#   'b3',
#   'f3',
#   'b2',
#   'f+1',
#   'v1',
#   'f3',
#   'f+1',
#   'v3',
#   'f+1',
#   'f2',
#   'f3',
#   'z3',
#   'f3',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f3',
#   'z3',
#   'f+3',
#   'f1',
#   'f3',
#   'f3',
#   'f+3',
#   'f1',
#   'f+3',
#   'f+3',
#   'f+1',
#   'f3',
#   'f+1',
#   'z3',
#   'f+3',
#   'v3',
#   'f+3',
#   'b3',
#   'v1',
#   'f+1',
#   'f+1',
#   'f+3',
#   'f2',
#   'z1',
#   'f+1',
#   'f+1',
#   'f3',
#   'f+3',
#   'f+3',
#   'f+1',
#   'f+1',
#   'f1',
#   'f+3',
#   'f3',
#   'f+1',
#   'f+1',
#   'f1',
#   'f+1',
#   'f1',
#   'v1',
#   'f+3',
#   'v1',
#   'f3',
#   'v1',
#   'z1',
#   'f3',
#   'f+3',
#   'f+1',
#   'f+1'],
#  'b28': ['b2',
#   'f3',
#   'z3',
#   'z3',
#   'f2',
#   'f3',
#   'f1',
#   'f3',
#   'f2',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'b2',
#   'f2',
#   'f1',
#   'f+3',
#   'f1',
#   'f1',
#   'f+1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'z3',
#   'f1',
#   'f1',
#   'f3',
#   'f+1',
#   'f+1',
#   'f+3',
#   'f2',
#   'f2',
#   'f3',
#   'f3',
#   'v1',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f1',
#   'f1',
#   'f+1',
#   'f3',
#   'z1',
#   'f1',
#   'f+3',
#   'f1',
#   'f+1',
#   'f1',
#   'f1',
#   'f+1',
#   'f3',
#   'f+3',
#   'f+1',
#   'f1',
#   'f3',
#   'v3',
#   'f+3',
#   'f+3',
#   'f+3',
#   'f2',
#   'f+3',
#   'f1',
#   'f+3',
#   'b3',
#   'f+1',
#   'f2',
#   'f1',
#   'f+1',
#   'f+1',
#   'f+3',
#   'f3',
#   'f3',
#   'f+3',
#   'f2',
#   'f3',
#   'f1',
#   'f+1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f+3',
#   'f+1',
#   'f1',
#   'f3',
#   'f+3',
#   'f+3',
#   'f3',
#   'v3',
#   'f3',
#   'f2'],
#  'b29': ['f1',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'b1',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'b3',
#   'f1',
#   'f2',
#   'f3',
#   'f2',
#   'b1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f2',
#   'f1'],
#  'b3': ['f3',
#   'f1',
#   'z1',
#   'z3',
#   'z3',
#   'b3',
#   'b1',
#   'b3',
#   'b3',
#   'b2',
#   'f1',
#   'b3',
#   'b2',
#   'z3',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'z1',
#   'b3',
#   'f1',
#   'b3',
#   'b1',
#   'b2',
#   's3',
#   'f3',
#   'b1',
#   'f3',
#   'b1',
#   'f2',
#   'b1',
#   'b3',
#   'b2',
#   'b2',
#   'b1',
#   'b3',
#   'b3',
#   'b2',
#   'b1',
#   'z1',
#   's1',
#   'z1',
#   'f3',
#   'z3',
#   's1',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b2',
#   'f+1',
#   'b1',
#   'b2',
#   'b3',
#   'b2',
#   'f3',
#   'z3',
#   'f2',
#   'b1',
#   'b3',
#   'z3',
#   'b3',
#   'b3',
#   'z3',
#   'b1',
#   'b1',
#   'b1',
#   'v3',
#   'f3',
#   'b1',
#   'b3',
#   'f2',
#   'f3',
#   'b1',
#   'b2',
#   'z3',
#   'b1',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   's1',
#   'f1',
#   'f1',
#   'f3',
#   'b3',
#   'z3',
#   'z3',
#   'f2',
#   'z3',
#   'b1',
#   'b3',
#   'b2',
#   'f3',
#   's1',
#   'b1',
#   's3',
#   'z3',
#   'z3',
#   's1',
#   'b1',
#   'z3',
#   's3',
#   'z3',
#   'z3',
#   'b1',
#   'b3',
#   'b3',
#   'b1',
#   'b2',
#   'b1',
#   's1',
#   'f3',
#   'f1',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'b1',
#   'f1',
#   's1',
#   's1',
#   'f1',
#   'b3',
#   'b3',
#   's1',
#   'f3',
#   'b1',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'z1',
#   'b1',
#   'b2',
#   'b3',
#   'b3',
#   'f2',
#   'b1',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'z3',
#   'f1',
#   'z3',
#   's3',
#   'b1',
#   'b2',
#   'b3',
#   'b2',
#   'f1',
#   'z3',
#   'b3',
#   'f1',
#   's2',
#   's1',
#   'b3',
#   'b2',
#   'f+1',
#   's3',
#   'b2',
#   'b2',
#   's1',
#   'f1',
#   's1',
#   's3',
#   's1',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'f3',
#   'b2',
#   'b1',
#   'b1',
#   'b1',
#   'b3',
#   'b3',
#   'b1',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'z3',
#   's2',
#   'b1',
#   's1',
#   'b2',
#   'b3',
#   's1',
#   'z3',
#   'b3',
#   'b2',
#   'b1',
#   'f1',
#   'b1',
#   'b1',
#   'b1',
#   'b3',
#   'b1',
#   's1',
#   's2',
#   'b3',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b3',
#   's3',
#   'b1',
#   'b2',
#   'b3',
#   'b2',
#   'z3',
#   'b2',
#   'b1',
#   'f2',
#   'b1',
#   's3',
#   's2',
#   'b1',
#   's1',
#   'b3',
#   's1',
#   'b1',
#   'b3',
#   'b2',
#   'b1',
#   'b1',
#   'b2',
#   's1',
#   's1',
#   's1',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'f3',
#   'z3',
#   'b3',
#   'b1',
#   'b3',
#   's1'],
#  'b37': ['f3',
#   'z1',
#   'b3',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f+1',
#   'b1',
#   'b3',
#   'f2',
#   'f3',
#   'b3',
#   'b3',
#   'f3',
#   'f+1',
#   'f3',
#   'f+1',
#   'f+3',
#   'z3',
#   's3',
#   'f3'],
#  'b38': ['f2',
#   'b1',
#   'b1',
#   'b3',
#   'b3',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'b2',
#   'b3',
#   'b2',
#   'f1',
#   'b1',
#   'f1',
#   'f1',
#   'b2',
#   'b1',
#   'b2',
#   'f1',
#   'b1',
#   'b3',
#   'b1',
#   'b3',
#   'f2',
#   'f1',
#   'b3',
#   'f1',
#   'b3',
#   'b1',
#   'f1',
#   'b2',
#   'f1',
#   'f+1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   's3',
#   'f3'],
#  'b39': ['f3',
#   'b3',
#   'f3',
#   'b3',
#   'f3',
#   'b3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'b1',
#   'b1',
#   'b3',
#   'b1',
#   'b3',
#   'f3',
#   's3',
#   'f1',
#   'f1'],
#  'b7': [],
#  'b8': ['b', 'b'],
#  'b;-3': ['b3'],
#  'b;1': ['f1', 'f1', 'f+1'],
#  'b;2': ['f1', 'f1', 's1'],
#  'b;27': ['f+1'],
#  'b;3': ['f2'],
#  'c4': ['b18', 'f28', 'b19', 'b29', 'b29', 'b28', 'f28'],
#  'c5': ['b28', 'b28', 'b28', 's', 'b28', 'b28', 'b28'],
#  'c6': ['b18', 'b28', 'b29', 's28', 'b19', 'f29', 'b29', 'b28', 'b28', 'b17'],
#  'cc5': [],
#  'f': ['s', 'v3', 'b', 'b', 'b', 'b'],
#  'f+1': ['f2', 'f1', 'f1', 'f3', 'f3', 'f3', 'f1', 'f2', 'f1', 'f3', 'f2'],
#  'f+2': ['b2'],
#  'f+3': ['b2',
#   'b1',
#   'b1',
#   's3',
#   'b3',
#   'b1',
#   's3',
#   's1',
#   'b1',
#   's1',
#   'b3',
#   'b1',
#   'b3',
#   'b3',
#   's3',
#   'b3',
#   's3',
#   's1',
#   's2',
#   's2',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   's3'],
#  'f-1': ['v1'],
#  'f-2': ['z1'],
#  'f-3': ['b2'],
#  'f1': ['f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f2',
#   'f3',
#   'v1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'r2',
#   'v1',
#   'f1',
#   'f1',
#   'f2',
#   'f2',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f2',
#   'f3',
#   'v1',
#   'v1',
#   'f1',
#   'f2',
#   'f2',
#   'v1',
#   'f1',
#   'f1',
#   'f2',
#   'v1',
#   'f2',
#   'f3',
#   'f1',
#   'v1',
#   'f2',
#   'v1',
#   'f3',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'r2',
#   'f2',
#   'f2',
#   'f2',
#   'f1',
#   'v1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   'f1',
#   'v1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f3',
#   'f3',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'v1',
#   'f+1',
#   'f1',
#   'f1',
#   'f1',
#   'f1'],
#  'f1-': ['f1'],
#  'f17': ['f+3', 'f+1', 's3', 'b1', 'f1', 'f2', 'f+1', 'f+3', 'f1'],
#  'f18': ['f1', 'f1', 'f1', 'f1', 'f1', 'f1', 'f2', 'f+3', 'f3', 'f3'],
#  'f19': ['f1', 'f1', 'f1'],
#  'f2': ['b2',
#   'f1',
#   'f1',
#   'v1',
#   'b3',
#   'b2',
#   'f+1',
#   'b2',
#   'f1',
#   'f2',
#   'f3',
#   'b2',
#   'b3',
#   'f1',
#   'b2',
#   'f3',
#   'b1',
#   'f+3',
#   'f+1',
#   'f+1',
#   'f1',
#   'z1',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'b2',
#   'v1',
#   'f1',
#   'f3',
#   'f3',
#   'f3',
#   'b3',
#   'z1',
#   'f1',
#   'f1',
#   'z1',
#   'f2',
#   'f1',
#   'f1',
#   'z1',
#   'f2',
#   'b2',
#   'f+3',
#   'v1',
#   'f2',
#   'f1',
#   'b2',
#   'f1',
#   'f+3',
#   'z1',
#   'b3',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f2',
#   's2',
#   'f2',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'b2',
#   'f2',
#   'z1',
#   'f3',
#   'v1',
#   'f1',
#   'f1',
#   'f+1',
#   'f3',
#   'f1',
#   'v1',
#   'f2',
#   'f3',
#   'f3',
#   'v1',
#   'f+1',
#   'f1',
#   'f2',
#   'b3',
#   's2',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f3',
#   'b3',
#   'f1',
#   'f2',
#   'b2',
#   'b2',
#   'f1',
#   'f1',
#   'f1',
#   'b2',
#   'f',
#   'b2',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f2',
#   'b1',
#   'f3',
#   'b1',
#   'b1',
#   'b1',
#   'f1',
#   'b3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'b1',
#   'b1',
#   'f1',
#   'b2',
#   'f+1',
#   'f3',
#   'f3',
#   'f2',
#   'f2',
#   'f3',
#   'f1',
#   'f+1',
#   'b2',
#   'b2',
#   'b3',
#   'b2',
#   'f3',
#   'f3',
#   'f3',
#   'v1',
#   'f+3',
#   'f1',
#   'b2',
#   'f2',
#   'f1',
#   'f1',
#   'b1',
#   'f3',
#   'b1',
#   'b3',
#   'b1',
#   'b2',
#   'f1',
#   'b2',
#   'f3',
#   'f2',
#   'f1',
#   'b2',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'b3',
#   'f3',
#   'f1',
#   'f3',
#   's1',
#   'b2',
#   'b3',
#   'b2',
#   'f+1',
#   'f+1',
#   'f1',
#   'b1',
#   'b1',
#   'b2',
#   'f2',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'z3',
#   'f1',
#   'f3',
#   'b2',
#   's1',
#   'f1',
#   'f2',
#   'b1',
#   'f1',
#   'f2',
#   'f2',
#   'f3',
#   'f+1',
#   'f1',
#   'b2',
#   'b2',
#   'f1',
#   'f2',
#   'f+1',
#   'b1',
#   'f3',
#   'b2',
#   'f2',
#   'f1',
#   'b2',
#   'f1',
#   'f2',
#   'f1',
#   'b3',
#   'f3',
#   'f3',
#   'f2',
#   'b2',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'b1',
#   'f2',
#   'b2',
#   'f1',
#   'f1',
#   'f2',
#   'b2',
#   'f1',
#   'b2',
#   'f2',
#   'b1',
#   'f1',
#   'f1',
#   'b2',
#   'b2',
#   'b2',
#   'f3',
#   'f1',
#   'b1',
#   'f2',
#   'b3',
#   'f+1',
#   'b3',
#   'b1',
#   'f2',
#   'f1',
#   'f1',
#   'b1',
#   'f2',
#   'f2',
#   'b2',
#   'b2',
#   'b1',
#   'f3',
#   'f1',
#   'f2',
#   'b1',
#   'b1',
#   'f3',
#   'f3',
#   'f+1',
#   'f1',
#   'f2',
#   'f3',
#   'b2',
#   'b1',
#   'f1'],
#  'f238': ['f2'],
#  'f27': ['f3',
#   'f2',
#   'f+1',
#   'f+1',
#   'b1',
#   'f1',
#   'f1',
#   'v1',
#   'f3',
#   'z1',
#   'f1',
#   'f3',
#   'f3',
#   'f3',
#   'b1',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f3',
#   'f3',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f1',
#   'f+3',
#   'f1',
#   'f+1',
#   'f+1',
#   'f+1',
#   'f3',
#   'f1',
#   'v3',
#   'f3',
#   'f+3',
#   'f3',
#   'f3',
#   'f1',
#   'f+3',
#   'f+1',
#   'f1',
#   'f3'],
#  'f28': ['f1',
#   'f3',
#   'f+3',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'f+3',
#   'f3',
#   'f1',
#   'f2',
#   'f3',
#   'v3',
#   'f1',
#   'f+1',
#   'f+1',
#   'f1',
#   'f2',
#   'f1',
#   'b3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f3',
#   'f+1',
#   'f3',
#   'f2',
#   'f1',
#   'f3',
#   'f2',
#   'f+1',
#   'f2',
#   'f+1',
#   'f3',
#   'f3',
#   'f2',
#   'f2',
#   'f+1',
#   'f2',
#   'f1',
#   'f2',
#   'f2',
#   'f+1',
#   'f2',
#   'b3',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   'f3',
#   'f1',
#   'f2',
#   'f+1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f+1',
#   'f1',
#   'f2',
#   'f3',
#   'f+1',
#   'f3',
#   'f1'],
#  'f29': ['f1',
#   'b2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   's1',
#   'f1',
#   'f1',
#   'f3',
#   'f+3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f+1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3'],
#  'f3': ['z1',
#   'b2',
#   'b3',
#   'z1',
#   'f3',
#   's3',
#   'b2',
#   'z1',
#   'b2',
#   'b1',
#   'b1',
#   'f3',
#   'b2',
#   's2',
#   'f1',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'z1',
#   'b3',
#   'f3',
#   'f2',
#   'f3',
#   'b3',
#   'b3',
#   'b2',
#   'f+1',
#   'z1',
#   'b3',
#   's3',
#   'f+1',
#   'b1',
#   'f2',
#   'b3',
#   'f2',
#   'b2',
#   'b3',
#   'b1',
#   'f3',
#   's2',
#   'b2',
#   'b2',
#   's1',
#   'b2',
#   'b1',
#   'b3',
#   's3',
#   's1',
#   'b3',
#   'b2',
#   'b3',
#   's1',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   's3',
#   'b2',
#   'b2',
#   's2',
#   'b3',
#   'b3',
#   's3',
#   'b3',
#   's1',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   's1',
#   'f3',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   'z1',
#   'b1',
#   'b2',
#   'b3',
#   's1',
#   'b3',
#   'b2',
#   'b1',
#   's3',
#   'b1',
#   'b1',
#   'z1',
#   'b3',
#   'b3',
#   'f1',
#   'b3',
#   's1',
#   'f3',
#   'b1',
#   'z3',
#   'f+3',
#   'b1',
#   's3',
#   'b3',
#   'f1',
#   'b2',
#   'b3',
#   'z1',
#   'b2',
#   'b3',
#   'b2',
#   'b1',
#   'f1',
#   'z1',
#   'b3',
#   'b2',
#   'b1',
#   'b3',
#   'b2',
#   'b1',
#   'f3',
#   'b2',
#   'b1',
#   'b2',
#   'b2',
#   'b1',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'b3',
#   'b1',
#   'b1',
#   'b1',
#   's1',
#   'b3',
#   'f3',
#   'f2',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   's1',
#   'b2',
#   'b2',
#   'b2',
#   'b2',
#   'b2',
#   'f2',
#   'f3',
#   's2',
#   'b3',
#   'b3',
#   'f1',
#   'f3',
#   'f3',
#   'f3',
#   'b1',
#   's3',
#   'b3',
#   's3',
#   'f2',
#   'b1',
#   'b3',
#   'f+1',
#   'b1',
#   'f3',
#   'b2',
#   'b3',
#   'b1',
#   'f3',
#   'b3',
#   'z1',
#   'f+1',
#   'f2',
#   'f3',
#   'b2',
#   'z3',
#   's1',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b3',
#   'b3',
#   's1',
#   'b1',
#   'f3',
#   'b3',
#   'b3',
#   'b3',
#   'f1',
#   'f3',
#   'f3',
#   'z1',
#   'b2',
#   'v1',
#   'b2',
#   'f1',
#   'b2',
#   'b3',
#   'b2',
#   's2',
#   'b1',
#   's1',
#   'b2',
#   'b3',
#   'b3',
#   'b3',
#   'b1',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   's3',
#   'f1',
#   'b2',
#   'b3',
#   'b2',
#   's3',
#   'b2',
#   'f3',
#   'f1',
#   'b3',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'b1',
#   'b',
#   'f1',
#   'b2',
#   'b3',
#   'f3',
#   'b1',
#   'b3',
#   'b1',
#   'b2',
#   's3',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'b1',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'b1',
#   's1',
#   'b1',
#   's1',
#   's1',
#   'b1',
#   'b2',
#   's3',
#   'b3',
#   'b2',
#   'b1',
#   'b1',
#   's1',
#   'b3',
#   'b2',
#   'b3',
#   's1',
#   'b3',
#   'b3',
#   'f3',
#   's1',
#   'b3',
#   'b2',
#   'b1',
#   'b1',
#   'f3',
#   'b2',
#   'b3',
#   's1',
#   'z1',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   'f3',
#   'b3',
#   's1',
#   's1',
#   'b2',
#   'b3',
#   'b1',
#   's2',
#   'f1',
#   'b2',
#   'b1',
#   's3',
#   'b3',
#   'b1',
#   'b1',
#   'b2',
#   'b3',
#   'b1',
#   'b3',
#   's2',
#   'b2',
#   'f2',
#   'b2',
#   'b2',
#   'b3',
#   'f2',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'f+1',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'f+3',
#   'b3',
#   'b1',
#   'b3',
#   'b2',
#   's2',
#   'b3',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'f1',
#   'b2',
#   'b2',
#   'b1',
#   'b1',
#   'b3',
#   's3',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   'b2',
#   's3',
#   's1',
#   'b2',
#   'b1',
#   's1',
#   'b3',
#   'b3',
#   's2',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   's1',
#   'b3',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'b1',
#   's2',
#   's1',
#   'b1',
#   'b3',
#   's3',
#   'b3',
#   'f+1',
#   'b3',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   'b2',
#   'b1',
#   'b1',
#   'b2',
#   'f3',
#   'b2',
#   'b3',
#   's3',
#   'b2',
#   'z1',
#   's1',
#   'b3',
#   'b3',
#   'f2',
#   's1',
#   's3',
#   'b1',
#   'f1',
#   'f3',
#   'f1',
#   'b3',
#   'b3',
#   'b1',
#   's2',
#   'b2',
#   'b2',
#   'b3',
#   's2',
#   'f2',
#   'b2',
#   'b2',
#   'b1',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'f2',
#   's2',
#   'b1',
#   'b1',
#   'f2',
#   'b3',
#   'b1',
#   'b2',
#   'f2',
#   'f1',
#   'b3',
#   's2',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b3',
#   'b2',
#   's3',
#   's1',
#   'b3',
#   's1',
#   's2',
#   'b3',
#   'b3',
#   'b2',
#   'f1',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   'f2',
#   'b3',
#   'b3',
#   'f3',
#   's1',
#   'b1',
#   'b2',
#   'b3',
#   'b3',
#   'b2',
#   's2',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   's3',
#   'b1',
#   'b1',
#   'b1',
#   's3',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b3',
#   'b1',
#   's3',
#   'b2',
#   'b1',
#   'b3',
#   'b1',
#   'f1',
#   'f1',
#   's3',
#   'b1',
#   'b1',
#   'b1',
#   'b2',
#   'b3',
#   'b3',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'b1',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b2',
#   'b2',
#   'b1',
#   'b1',
#   'b3',
#   'b1',
#   'b1',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   's3',
#   'f1',
#   'b1',
#   's1',
#   'f1',
#   'b1',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'f1',
#   's3',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'f3',
#   'b2',
#   'f1',
#   'b2',
#   'b1',
#   'b2',
#   'b3',
#   'b3',
#   'b2',
#   'b1',
#   'b3',
#   'b3',
#   'b1',
#   'f2',
#   'b1',
#   'b1',
#   'b1',
#   's1',
#   'b2',
#   'f3',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   's2',
#   'b2',
#   'b2',
#   'b2',
#   's2',
#   'b2',
#   'b2',
#   's3',
#   'b1',
#   'b3',
#   's1',
#   's3',
#   's2',
#   'b2',
#   'b1',
#   's2',
#   'b3',
#   'b2',
#   's3',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   's3',
#   's3',
#   'b2',
#   's3',
#   'b3',
#   'b3',
#   's1',
#   's1',
#   'b1',
#   's1',
#   's2',
#   'b1',
#   's1',
#   's2',
#   's1',
#   'b3',
#   'b2',
#   's3',
#   's1',
#   'b1',
#   's2',
#   'b3',
#   'f3',
#   'f1',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'f1',
#   'f3',
#   'b2',
#   'b1',
#   's3',
#   's3',
#   'f2',
#   'b2',
#   'b3',
#   'f3',
#   'f1',
#   'b1',
#   'b1',
#   'b2',
#   'f2',
#   's1',
#   'b2',
#   'b3',
#   'b2',
#   'f1',
#   's1',
#   's3',
#   'b1',
#   'b1',
#   'b2',
#   'b3',
#   's3',
#   'b3',
#   'f3',
#   'b1',
#   's3',
#   'f1',
#   'b2',
#   'b3',
#   'f3',
#   'b1',
#   'b1',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   's1',
#   'b1',
#   'f2',
#   'b3',
#   's2',
#   'b2',
#   'b3',
#   'f3',
#   's2',
#   'b3',
#   's2',
#   's2',
#   'b3',
#   's1',
#   'f1',
#   'b2',
#   'b3',
#   'b2',
#   's1',
#   'b2',
#   'b1',
#   'f3',
#   's3',
#   's1',
#   'b3',
#   'z3',
#   's3',
#   'b2',
#   'z3',
#   'b1',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'b3',
#   'b2',
#   'b1',
#   'f2',
#   'b3',
#   'b2',
#   'b1',
#   's3',
#   'b2',
#   'b2',
#   'b2',
#   'b1',
#   'b3',
#   's1',
#   'b1',
#   's3',
#   'f3',
#   's2',
#   'b2',
#   'f2',
#   'b2',
#   'b2',
#   's2',
#   'b3',
#   'b3',
#   'b3',
#   's3',
#   'b2',
#   'b2',
#   's1',
#   'b2',
#   'b2',
#   'b2',
#   's1',
#   'b2',
#   's3',
#   'f1',
#   's2',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   's1',
#   'f2'],
#  'f37': ['s1',
#   'z1',
#   'b1',
#   'f2',
#   'z1',
#   'b1',
#   'f3',
#   'b3',
#   'f1',
#   'f+1',
#   'b3',
#   'f1',
#   'f3',
#   'b3',
#   'f1',
#   'b2',
#   'b3',
#   'b3',
#   's1',
#   'f+1',
#   'f1',
#   'f1',
#   's1',
#   'f+1',
#   'f+1',
#   'f1',
#   'b1',
#   'b3',
#   'f3',
#   'b3',
#   'b2',
#   'f3',
#   'f+1',
#   'b1',
#   'f+1',
#   's1',
#   'b1',
#   'b2',
#   'f+1',
#   'f1',
#   'z3',
#   'b3',
#   'f1',
#   'z1',
#   'f1',
#   'b2',
#   'f1',
#   'b1',
#   'f3',
#   'f3',
#   's2'],
#  'f38': ['f3',
#   'f2',
#   'f2',
#   'f2',
#   'b2',
#   'b1',
#   's2',
#   'b1',
#   'b1',
#   'f3',
#   'b3',
#   'f3',
#   'f1',
#   'f3',
#   's1',
#   'b3',
#   'b3',
#   'f1',
#   's1',
#   'f2',
#   'f1',
#   'b1',
#   'b1',
#   'f3',
#   'b2',
#   's1',
#   'b1',
#   'b2',
#   'b2',
#   'b2',
#   'f1',
#   'f1',
#   'b2',
#   'b3',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'b3',
#   'f1',
#   'f1',
#   'f2',
#   'b1',
#   'b1',
#   's1',
#   'f+3',
#   'f+1',
#   'f3',
#   'f1',
#   's1',
#   'b1',
#   'b1',
#   'b3'],
#  'f39': ['f2',
#   'f1',
#   'b1',
#   'f1',
#   'f1',
#   'f1',
#   'b1',
#   'b3',
#   'f2',
#   'b2',
#   'b2',
#   'b2',
#   'b1',
#   'b3',
#   'b2',
#   'f1',
#   'b2',
#   'b2'],
#  'f7': ['s'],
#  'f8': ['b', 'f1'],
#  'f;1': ['f1', 'f+1'],
#  'f;27': ['f3', 'f3'],
#  'f;28': ['f+1'],
#  'f;3': ['s3'],
#  'f;37': ['f3'],
#  'f;38': ['b2'],
#  'h-3': ['b2'],
#  'h=3': ['f1'],
#  'i3': ['b3'],
#  'i=1': [],
#  'i=2': ['f+1'],
#  'k1': ['f3'],
#  'l1': [],
#  'l2': [],
#  'l3': [],
#  'm': [],
#  'm+2': [],
#  'm+3': [],
#  'm1': [],
#  'm17': [],
#  'm2': ['f1'],
#  'm27': [],
#  'm28': [],
#  'm3': ['z3'],
#  'o1': ['f3', 'f3'],
#  'o2': ['b2'],
#  'o=3': ['s1'],
#  'r+3': ['b3'],
#  'r1': ['f1', 'f1', 'v1', 'f1', 'f+3', 'f2', 'v1'],
#  'r19': ['f+1'],
#  'r2': ['f+1',
#   'v1',
#   'f2',
#   'f1',
#   'f+1',
#   'f+1',
#   'f+1',
#   'f+1',
#   'f1',
#   'z1',
#   'f+3'],
#  'r27': ['f+3', 'f3'],
#  'r28': ['f3'],
#  'r29': ['f3'],
#  'r3': ['f3',
#   'f3',
#   'f2',
#   'f+1',
#   'b1',
#   'f3',
#   'b3',
#   'z1',
#   'b3',
#   'b1',
#   'f3',
#   'f+1',
#   'f3',
#   'f+1',
#   'b3',
#   'f+1'],
#  'r;1': ['f3'],
#  's': ['b', 'z3'],
#  's+3': ['b3', 'b1'],
#  's1': ['f1', 'f1', 'f1', 'f3', 'f1', 'f2', 'f+3', 'f3', 'f3', 'f3', 'f+1'],
#  's17': ['f3'],
#  's18': ['f1'],
#  's2': ['f3',
#   'f3',
#   'f+3',
#   'f+1',
#   'v3',
#   'z3',
#   'f+1',
#   'f1',
#   'f3',
#   'z3',
#   'f+3',
#   'f+3',
#   'f1',
#   'z3',
#   'f1',
#   'f+3',
#   'z3',
#   'b3',
#   'f+3',
#   'v1',
#   'f1',
#   'v3',
#   'f+1',
#   'z3',
#   'z3',
#   'f+3',
#   'v3',
#   's1',
#   's1',
#   'z3',
#   'b3',
#   'f3',
#   'f+1',
#   'f1',
#   'f+1',
#   'f1',
#   'f+1',
#   'f3',
#   'f+3',
#   'b3',
#   'f+3',
#   'b3',
#   'f3',
#   'f+1',
#   'f3',
#   'f+3',
#   'f1',
#   'b2',
#   's2',
#   'f1',
#   'f2',
#   'v1',
#   'f+1',
#   'f+1',
#   'b2',
#   'b3',
#   'f1',
#   'f3',
#   'f+3'],
#  's27': ['f+3',
#   'v3',
#   'z1',
#   'z1',
#   'f+1',
#   'f3',
#   'f1',
#   'f3',
#   'f+1',
#   'z3',
#   'f3',
#   'f+1',
#   'f+1',
#   'f+3',
#   's1',
#   'f+1'],
#  's28': ['f+3',
#   'z3',
#   'f1',
#   'f+3',
#   'f+1',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f1',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f3',
#   'f+1',
#   'f1',
#   'f+1',
#   'f+3',
#   'f+3',
#   'z3',
#   'f+3',
#   'z3',
#   'f3',
#   'f3',
#   'f+3'],
#  's29': ['f1', 'f1', 'f1', 'f3'],
#  's3': ['f+1',
#   'f1',
#   'f2',
#   'b1',
#   'b3',
#   'f3',
#   'b3',
#   'f+1',
#   'b1',
#   'f3',
#   'b1',
#   'z3',
#   'b2',
#   'b3',
#   'f1',
#   'b3',
#   'v3',
#   'z3',
#   'b3',
#   'v1',
#   'b1',
#   'f1',
#   'z3',
#   'f3',
#   'b3',
#   'f+1',
#   'f3',
#   'z3',
#   'f3',
#   'f1',
#   'f+1',
#   'f3',
#   'f+3',
#   'b3',
#   'b2',
#   'b1',
#   'f1',
#   'b3',
#   'b3',
#   'f3',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f3',
#   'b2',
#   'f2',
#   'f3',
#   'f3',
#   'f3',
#   'f2',
#   'f+1',
#   'f1',
#   'b3',
#   'b1',
#   'z3',
#   'b3',
#   'z3',
#   'b1',
#   'b3',
#   'b3',
#   's1',
#   'f3',
#   'b3',
#   'f1',
#   'f3',
#   'b3'],
#  's37': ['f1', 'f1', 'z3', 'f+3', 'z1', 'f+3'],
#  's38': ['z1', 'f3', 'f3', 'b3', 'f3', 'b1', 'f3', 'f3', 'z3'],
#  's39': ['b1', 'f3', 'f1', 'f2', 'f3', 'f1', 'f3'],
#  's;3': ['b1'],
#  'u1': ['f3', 'f1', 'f+1'],
#  'u2': ['f3'],
#  'u3': ['s1', 'b3'],
#  'v1': ['f3', 'f3', 'f3'],
#  'v2': ['b3', 'v1', 'f1'],
#  'v3': ['b1'],
#  'y+2': ['b2'],
#  'y2': ['b1'],
#  'y3': ['b1', 'b3', 'b1', 's1'],
#  'y37': ['s1'],
#  'z1': ['f1'],
#  'z2': ['v3'],
#  'z3': ['b1', 'b1']}

# %% [markdown]
# # Your turn to serve!
#
# You can play against the historical RN: just type in the shots and see if you can beat him! You can try first with simple shots, like 'f3' or 'b2' or even with a volley 'v1'.

# %%
Counter(all_dict2['b2'])
# Out:
# Counter({'b1': 15,
#          'b2': 35,
#          'b3': 26,
#          'f': 1,
#          'f+1': 23,
#          'f+3': 26,
#          'f1': 122,
#          'f2': 55,
#          'f3': 63,
#          's1': 4,
#          's2': 1,
#          's3': 3,
#          'v1': 7,
#          'v3': 9,
#          'z1': 7,
#          'z3': 7})

# %%
current_prompt = 'X'
while True:       ###### CAREFUL WHEN INTERRUPTING
    shot = input()
    next_prompt = model(current_prompt, shot)
    print(next_prompt)
    current_prompt = next_prompt
    if is_win(next_prompt) == 1:
        print('Point won!')
        break
    if is_win(next_prompt) == 0:
        print('Point lost!')
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.5/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.5/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     466         """
# --> 467         parts = [self.recv(flags, copy=copy, track=track)]
#     468         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.5/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-179-532339c53dcf> in <module>()
#       1 current_prompt = 'X'
#       2 while True:       ###### CAREFUL WHEN INTERRUPTING
# ----> 3     shot = input()
#       4     next_prompt = model(current_prompt, shot)
#       5     print(next_prompt)
#
# /usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %% [markdown]
# # Example and tester
#
# We provide here an example of policy and a function with which you can test your model.
#
# For testing your personal new policy, simply modify the first line of code and insert your policy dictionary.
#
# The final scoring will be done with this same function, with number_of_points_played >= 1000000 and different values of the threshold, to be sure that statistical fluctuations of the result are reduced.

# %%
# Test function that makes your policy (a.k.a. Phederos) play against historical RN !!

############################## Modify here! ##########################
example_policy = all_dict2
######################################################################

number_of_points_played = 150000


serves_opponent = [shot for shot in [sh[0] for sh in shots_opo_com] if shot[0] in '456']
points_won  = 0
points_lost = 0


for num in range(number_of_points_played):
    print(num, end = '\r')
    # Random choice on who is serving
    if np.random.randint(0,2) == 0:
        current_prompt = 'X'
    else :
        current_prompt = np.random.choice(serves_opponent)
    while True:
        shot = np.random.choice(example_policy.get(current_prompt,['5']))
        next_prompt = model(current_prompt, shot)
        current_prompt = next_prompt
        if is_win(current_prompt) == 1:
            points_won  += 1
            break
        if is_win(current_prompt) == 0:
            points_lost += 1
            break
            
print('How well are we performing? '     , points_won/(points_lost + points_won))
print('Baseline historical performance: ', 1 - (df['Winner'].sum()/len(df['Winner'])))
# Out:
# How well are we performing?  0.5068333333333334
# Baseline historical performance:  0.5030959752321982

# %% [markdown]
# # Your turn now!
# Show us that you are up for the challenge and make your Phederos destroy the historical RN! Just be careful and do not get carried away... real challenges lie ahead of you all!

# %%
is_win('w*')
# Out:
# 0
