# %% [markdown]
# # AMLD workshop by L2F – Learn to Forecast
#
# Welcome to the "Machine Learning Competition: Tennis Analysis" workshop at AMLD 2019, organized by [L2F – Learn to Forecast](https://www.l2f.ch/)!
#
# Starting from Jeff Sackman's crowdsourced [Match Charting Project](https://github.com/JeffSackmann/tennis_MatchChartingProject) dataset, we have put together for you a dataset containing detailed shot-by-shot descriptions of a large collection of points played between the Swiss tennis star Roger Federer and his historical rival Rafael Nadal (RN). The information recorded includes the type of shot, direction of shot, depth of returns, types of errors, and more. This is better explained below; we have also put together some preliminary data preparation to help you get started.
#
# ## Goal
#
# The goal of this workshop is for you to come up with an optimized Phederos – the god of tennis – who will be able to destroy his ancient human rival. Do you think you can beat the beast?
#
# From a more technical perspective, we ask you to provide a strategy function which, given an opponent's shot, will return what you believe to be an optimal response shot. Your answer must be in the form of a JSON dictionary as follows: each key is an opponent's shot, and the corresponding value is a list from which we will uniformly sample your response.
#
# For more clarity, let us consider an example of such a strategy (the strings denote shot types which are better explained below):
#
# *strat* = {'f3': ['b2', 'b2', 'b3', 'v1'], 'f1': ['f2'], ...}.
#
# The keys in this dictionary are shots RN can produce. Suppose RN is performing a forehand on your backhand (the code for this shot is 'f3'); *strat* would reply to this shot in a *probabilistic* way as follows:
# - 'b2' with probability 1/2,
# - 'b3' with probability 1/4,
# - 'v1' with probability 1/4.
#
# On the other hand, the same strategy replies *deterministically* to 'f1' (which is a forehand on our forehand), since we say 'f2' (a forehand straight to RN) with probability 1. In this way, your strategy can incorporate simple deterministic and more complex probabilistic decision-making in an arbitrary way.
#
# ## Testing environment
#
# You have to beat a stochastic model which replies to your shots based on past statistics, but never replies with shots which have historically occurred too rarely. More precisely, this simulation environment will react based on the counting statistics of outcomes to (human) Federer's shots. By 'outcome' here we mean either:
# - a simple reply shot or serve by historical RN (this is perhaps a bit confusing at first, but we consider a player's serve as a 'reply' to the opponent's 'waiting');
# - a 'termination token', e.g. '*' for a winning shot, meaning that RN could not respond to your winning shot and the point terminates, or '@' indicating that with your shot you made an unforced error and lost the point – but note that such tokens can include more detailed information than this and be more than one character long;
# - a shot by RN and a termination token, concatenated in a simple string, e.g., 'f1*' would indicate that our simulated RN replied with a winning forehand shot – ouch!
#
# The Python code for this tester can be found in the last part of this notebook.
#
# ### Important remarks
#
# - The simulation environment will prompt you with shots or termination/waiting tokens from a predetermined list, which can be accessed by loading the pickle file *possible_prompts.p*. Make sure you know how to react to each of the elements in this list!
# - The pickle file *allowed_shots.p* contains a list which can be obtained from the list in *possible_prompts.p* by removing termination and waiting tokens. Replying with a string not in this list leads to losing of the point.
# - The "past statistics" in the stochastic model you will be fighting against come from a hold-out "test set" and **not** from the dataset you have access to. Make sure to build models which generalize well!
# - We will impose a time constraint on the duration of the evalutation of your policy: we expect that your policy can be evaluated on an i7 quadcore 1000000 times in less than 3 minutes.
#
# Will the true heroes of Machine Learning rise? :)

# %% [markdown]
# # Data from Jeff Sackmann's GitHub
#
# As explained above, we provide you with a pandas dataframe (*dataframe.p*), taken from Jeff Sackmann's original dataset.
#
# Each row is one point:
# - the variables 'Player1' and 'Player2' are the name of the players
# - the 'match_id' variable identifies the tournament and date
# - the varaible 'Shots' is a string containing all the shots, played alternatively from the players, during the point
# - the variable 'Shots1' are the shots played only by RF
# - the variable 'Shots0' contain the shots played only by RN
# - The 'Outcome' variable describes the outcome of the point
# - The 'Server' variable has boolean values: it is 1 in case RF is serving
# - The 'Winner' variable has boolean values: it is 1 in case RF has won the point
#
# Numbers are used to indicate direction and depth, while letters are used to specific shot types (e.g. 'f' stands for 'forehand') and error types ('n' stands for 'net'). The letter 'X' means that RN is waiting for RF to serve... don't let him wait too much! A few symbols are used for other purposes, such as types of errors (e.g. '@' means 'unforced error' and '+' indicates an approach shot).
#
# To understand the codes for each shot, we prepared an explanation file named "Shot encodings" with more details. You can also check [this example video](https://drive.google.com/open?id=1Q4obFagfzxkFy_mq9C5gWITQiXxBQfCf) for a visual demonstration of this way of encoding.

# %%
# Importing libraries

import numpy as np
import pickle
import pandas as pd
from nltk import ngrams

# %%
# Historical data

df = pd.read_pickle('dataframe.p')
df.head()
# Out:
#                                             match_id       Player1  \
# 0  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 1  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 2  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 3  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 4  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
#
#          Player2                     Shots         Shots1      Shots0 Outcome  \
# 0  Roger_Federer              4 b;37 f1 f1        b;37 f1        4 f1       *
# 1  Roger_Federer                      6 b3             b3           6      w#
# 2  Roger_Federer                         6                          6       *
# 3  Roger_Federer  5 b18 b2 f1 b2 f1 s2 b+3  b18 f1 f1 b+3  5 b2 b2 s2       *
# 4  Roger_Federer              4 b27 f+3 b1         b27 b1       4 f+3       *
#
#    Server  Winner
# 0       0       1
# 1       0       0
# 2       0       0
# 3       0       1
# 4       0       1

# %%
server_nadal = df[df.Server == 0]
server_nadal_lost = server_nadal[server_nadal.Winner == 1]
len(server_nadal), len(server_nadal_lost)
# Out:
# (2256, 809)

# %%
server_nadal.head()
# Out:
#                                             match_id       Player1  \
# 0  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 1  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 2  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 3  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 4  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
#
#          Player2                     Shots         Shots1      Shots0 Outcome  \
# 0  Roger_Federer              4 b;37 f1 f1        b;37 f1        4 f1       *
# 1  Roger_Federer                      6 b3             b3           6      w#
# 2  Roger_Federer                         6                          6       *
# 3  Roger_Federer  5 b18 b2 f1 b2 f1 s2 b+3  b18 f1 f1 b+3  5 b2 b2 s2       *
# 4  Roger_Federer              4 b27 f+3 b1         b27 b1       4 f+3       *
#
#    Server  Winner
# 0       0       1
# 1       0       0
# 2       0       0
# 3       0       1
# 4       0       1

# %%
server_nadal_lost.head()
# Out:
#                                              match_id       Player1  \
# 0   20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 3   20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 4   20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 12  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 19  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
#
#           Player2                     Shots         Shots1       Shots0  \
# 0   Roger_Federer              4 b;37 f1 f1        b;37 f1         4 f1
# 3   Roger_Federer  5 b18 b2 f1 b2 f1 s2 b+3  b18 f1 f1 b+3   5 b2 b2 s2
# 4   Roger_Federer              4 b27 f+3 b1         b27 b1        4 f+3
# 12  Roger_Federer  5 b28 f3 b2 b;2 f1 b1 f1   b28 b2 f1 f1  5 f3 b;2 b1
# 19  Roger_Federer      4 f17 b1 f3 f2 f1 b2      f17 f3 f1   4 b1 f2 b2
#
#    Outcome  Server  Winner
# 0        *       0       1
# 3        *       0       1
# 4        *       0       1
# 12       *       0       1
# 19      d@       0       1

# %%
nadal_serve_win_response = {}
nadal_serve_lost_response = {}

for index, row in server_nadal.iterrows():
    shots_s = row.Shots.split(' ')
    for k in range(0, len(shots_s) - 1, 2):
        n_shot, f_shot = shots_s[k:k+2]
        # Federer wins
        if row.Winner == 1:
            if n_shot in nadal_serve_win_response:
                nadal_serve_win_response[n_shot].append(f_shot)
            else:
                nadal_serve_win_response[n_shot] = [f_shot]
        # Nadal wins
        if row.Winner == 0:
            if n_shot in nadal_serve_lost_response:
                nadal_serve_lost_response[n_shot].append(f_shot)
            else:
                nadal_serve_lost_response[n_shot] = [f_shot]

# %%
nadal_serve_win_response['4']
# Out:
# ['b;37',
#  'b27',
#  'f17',
#  'f18',
#  'b28',
#  'f38',
#  'f28',
#  'b18',
#  'f29',
#  'f18',
#  'b9',
#  'b37',
#  'f18',
#  'b8',
#  's18',
#  's39',
#  'b19',
#  'b28',
#  'f29',
#  'b37',
#  's28',
#  'b19',
#  's29',
#  'b28',
#  'b28',
#  'b28',
#  'f29',
#  'b28',
#  'b2',
#  'b3',
#  'b1',
#  'b2',
#  'b2',
#  'b2',
#  'b28',
#  'f18',
#  'b29',
#  'b38',
#  's38',
#  'b37',
#  'b37',
#  'f18',
#  'f19',
#  'b38',
#  'b18',
#  'f19',
#  'b28',
#  'b27',
#  'b28',
#  'f17',
#  'b18',
#  'f19',
#  'b28',
#  'b28',
#  'b39',
#  'b29',
#  'f38',
#  'f18',
#  'f17',
#  'b18',
#  'b19',
#  'b27',
#  'b38',
#  'b28',
#  'b19',
#  'b18',
#  'f18',
#  'b29',
#  'b27',
#  'b19',
#  'b18',
#  'b38',
#  'b27',
#  'f18',
#  'b18',
#  'b18',
#  'b38',
#  'b;27',
#  'b;27',
#  's38',
#  'b29',
#  'b19',
#  'f39',
#  's38',
#  's28',
#  's28',
#  's37',
#  's28',
#  'f28',
#  's29',
#  'b37',
#  'f28',
#  'b28',
#  's37',
#  's38',
#  'b38',
#  's37',
#  's28',
#  'b28',
#  'b18',
#  's37',
#  'b28',
#  'b37',
#  'b28',
#  'b27',
#  'b28',
#  'b27',
#  's28',
#  'b28',
#  'b28',
#  'b17',
#  'b28',
#  'f38',
#  'b28',
#  'b;27',
#  's29',
#  'b18',
#  'b29',
#  'b29',
#  'b37',
#  's28',
#  'b18',
#  'b28',
#  'b28',
#  's37',
#  's39',
#  's27',
#  'b38',
#  'b28',
#  'b28',
#  'f38',
#  'b27',
#  'f18',
#  's18',
#  'b29',
#  'f28',
#  's38',
#  'b19',
#  'b28',
#  'b28',
#  'f28',
#  'b28',
#  'f28',
#  'b28',
#  'b28',
#  'b18',
#  'b29',
#  'b29',
#  'b28',
#  'f17',
#  's29',
#  'b37',
#  's29',
#  's39',
#  'b39',
#  'f17',
#  'b27',
#  'b19',
#  'b29',
#  'b27',
#  'b29',
#  'b29',
#  's29',
#  'b39',
#  'b28',
#  'b29',
#  's29',
#  'b28',
#  'b37',
#  'f39',
#  'b29',
#  'b29',
#  'b28',
#  'b37',
#  'b37',
#  'f28',
#  'b19',
#  'b19',
#  'b38',
#  'b27',
#  'b37',
#  'b37',
#  'b37',
#  'b28',
#  'b28',
#  'b38',
#  'b28',
#  'f29',
#  'b29',
#  'b28',
#  'b38',
#  'b38',
#  'b39',
#  'b29',
#  's29',
#  'b37',
#  'b38',
#  'f39',
#  'f18',
#  's39',
#  's',
#  'f19',
#  'b28',
#  'f28',
#  'b28',
#  'f17',
#  'b28',
#  'b38',
#  'b18',
#  'b38',
#  'f29',
#  'b28',
#  'b27',
#  'b28',
#  'b28',
#  'b38',
#  'b28',
#  'b39',
#  'b39',
#  'b28',
#  'b19',
#  'b18',
#  'f28',
#  'b28',
#  'b28',
#  'b29',
#  'b28',
#  'b27',
#  'b17',
#  's28',
#  'f28',
#  'b28',
#  'f28',
#  'b27',
#  'b29',
#  'b28',
#  'b18',
#  'b28',
#  's28',
#  's19',
#  's28',
#  'b28',
#  'b19',
#  'b19',
#  'b19',
#  's28',
#  'b27',
#  'b27',
#  'b28',
#  'f17',
#  'b29',
#  'b37',
#  's38',
#  'b27',
#  's28',
#  'f19',
#  'b27',
#  'b19',
#  'f29',
#  'b27',
#  'b29',
#  'b19',
#  'f28',
#  'f19',
#  's28',
#  'b29',
#  's28',
#  'f28',
#  'f28',
#  'b27',
#  'b18',
#  'b28',
#  'f28',
#  'f28',
#  'f18',
#  'r29',
#  'b28']

# %%
server_federer = df[df.Server == 1]
server_federer_won = server_federer[server_federer.Winner == 1]
server_federer_lost = server_federer[server_federer.Winner == 0]

# %%
server_federer.head()
# Out:
#                                             match_id       Player1  \
# 5  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 6  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 7  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 8  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 9  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
#
#          Player2               Shots    Shots1     Shots0 Outcome  Server  \
# 5  Roger_Federer                4 b2         4         b2      d#       1
# 6  Roger_Federer            4 f37 s1      4 s1        f37      n#       1
# 7  Roger_Federer  4 b28 b2 s3 f+1 b1  4 b2 f+1  b28 s3 b1      w#       1
# 8  Roger_Federer                   4         4                  *       1
# 9  Roger_Federer         5 f37 s1 b1      5 s1     f37 b1      w@       1
#
#    Winner
# 5       1
# 6       0
# 7       1
# 8       1
# 9       1

# %%
server_federer_lost.head()
# Out:
#                                              match_id       Player1  \
# 6   20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 13  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 17  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 37  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
# 50  20171015-M-Shanghai_Masters-F-Rafael_Nadal-Rog...  Rafael_Nadal
#
#           Player2                  Shots      Shots1      Shots0 Outcome  \
# 6   Roger_Federer               4 f37 s1        4 s1         f37      n#
# 13  Roger_Federer  4 s38 f1 b1 f1 b+3 s3  4 f1 f1 s3  s38 b1 b+3      n#
# 17  Roger_Federer               4 b28 f3        4 f3         b28      d@
# 37  Roger_Federer                  4 f19           4         f19       *
# 50  Roger_Federer               4 f37 s1        4 s1         f37      w@
#
#     Server  Winner
# 6        1       0
# 13       1       0
# 17       1       0
# 37       1       0
# 50       1       0

# %%
federer_serve_win_response = {}
federer_serve_lost_response = {}

for index, row in server_federer.iterrows():
    shots_s = row.Shots.split(' ')
    for k in range(1, len(shots_s) - 1, 2):
        n_shot, f_shot = shots_s[k:k+2]
        # Federer wins
        if row.Winner == 1:
            if n_shot in federer_serve_win_response:
                federer_serve_win_response[n_shot].append(f_shot)
            else:
                federer_serve_win_response[n_shot] = [f_shot]
        # Nadal wins
        if row.Winner == 0:
            if n_shot in federer_serve_lost_response:
                federer_serve_lost_response[n_shot].append(f_shot)
            else:
                federer_serve_lost_response[n_shot] = [f_shot]

# %%
federer_serve_lost_response['f37']
# Out:
# ['s1',
#  's1',
#  's3',
#  'f3',
#  'f1',
#  'b1',
#  's+3',
#  's3',
#  'b1',
#  's+1',
#  'b+2',
#  'b2',
#  'b1',
#  'b3',
#  'f3',
#  'b3',
#  'b3',
#  'b3',
#  's+2',
#  'z1',
#  'b3',
#  'f2',
#  'b1',
#  'u+3',
#  'b3',
#  'f1',
#  'f+2',
#  'b+1',
#  's1',
#  'b3',
#  'b+1',
#  's1',
#  'f+3',
#  'f3',
#  'b3',
#  'f2',
#  'f3',
#  'f1',
#  'y3',
#  'b2',
#  's2',
#  'f3',
#  'b+1',
#  'f+3',
#  'f1',
#  'b+1',
#  'b3',
#  'f3',
#  'b1',
#  'f3',
#  'f3',
#  'b2',
#  'f+1',
#  'b3',
#  's1',
#  'b1',
#  'b1',
#  'f3',
#  'f3',
#  'f3',
#  'f+2',
#  's2']

# %%
promp_dict = ['']

# %%
all_dict_win = federer_serve_win_response.copy()
all_dict_lost = federer_serve_lost_response.copy()
for k, v in nadal_serve_win_response.items():
    if k in all_dict_win:
        all_dict_win[k].extend(v)
    else:
        all_dict_win[k] = v
        
for k, v in nadal_serve_lost_response.items():
    if k in all_dict_lost:
        all_dict_lost[k].extend(v)
    else:
        all_dict_lost[k] = v

# %%
from collections import Counter

# %%
cnt_win = Counter([i.split(' ')[0] for i in server_federer_won.Shots.values])
cnt_lost = Counter([i.split(' ')[0] for i in server_federer_lost.Shots.values])
serves_win = [i.split(' ')[0] for i in server_federer_won.Shots.values if cnt_win[i] > 10]
serves_lost = [i.split(' ')[0] for i in server_federer_lost.Shots.values if cnt_lost[i] > 10]
all_dict_win['X'] = serves_win
all_dict_lost['X'] = serves_lost

# %% [markdown]
# # Prompts and shots
#
# We provide here the list of possible prompts and allowed shots – historically the most common shots – that you have to use. There are many more shots in the dataframe, but we only stick to the 100 shots provided and the 40 shots provided. It means that the historical RN/tester, will only shoot with one of the 100 prompts and you can reply using only one of the 40 shots.

# %%
# Loading the prompts and the shots

all_shots = pickle.load(open("allowed_shots.p", "rb"))
poss_prompts = pickle.load(open("possible_prompts.p" , "rb"))

print('Allowed shots: ', all_shots, '\n')
print('Possible prompts: ', poss_prompts)
# Out:
# Allowed shots:  ['4', '4+', '5', '6', '6+', 'X', 'b', 'b1', 'b17', 'b18', 'b19', 'b2', 'b27', 'b28', 'b29', 'b3', 'b37', 'b38', 'f', 'f+1', 'f+3', 'f1', 'f18', 'f2', 'f27', 'f28', 'f29', 'f3', 'f37', 'f38', 'r2', 's', 's1', 's2', 's28', 's3', 'v1', 'v3', 'z1', 'z3']
#
# Possible prompts:  ['f3', 'f1', 'b2', 'b1', 'X', 'f2', 'b3', '4', '6', '5', '*', 'b28', 'f28', 'b27', 's2', 'f+3', 's3', 'n@', 'f+1', 'b18', 'd@', 'f38', 'b29', 's1', 'b38', 'f37', '#', 'w@', 'f27', 'f29', 'n#', 'd#', 'f', 'b', 's28', 'b37', 'b17', 'f1*', 'b19', 'b39', 'w#', 'r2', 'f18', 'f39', 'z3', 'v1', 'v3', 'f#', 's27', '4+', '6+', 'z1', 'b1*', 'f3*', 'm2', 'f17', 'r3', 's', 'r1', 's29', 's38', 'b+1', 'z2', 'o3', 'c6', 'v2', 'c4', 'b1w@', 'b#', 'b1n@', 'b+3', 'f19', 'b3*', 'f+2', 'f1w@', 'b3w@', 's37', 's39', 'f3n@', 'f3w@', 'm3', 'f1n@', 'b1d@', 'b2n#', 'f2d@', 'f1n#', 'b1w#', 's#', 'b1n#', 'x@', 'f1w#', 'y3', 'f2d#', 'b2d@', 'f2n#', 'f3d@', 'y1', 'b3w#', 'o1', 'f-3']

# %%
all_chars = set([])
for i in all_shots:
    all_chars = all_chars.union(set(i))

# %%
all_chars = ''.join(list(all_chars))
all_chars
# Out:
# 'rf5b978+3vX246z1s'

# %%
mapper_win = set()
for k, v in all_dict_win.items():
    v_cnt = Counter(v)
    mapper_win = mapper_win.union(set([i for i in v_cnt.keys() if i not in all_shots]))
    
mapper_lost = set()
for k, v in all_dict_lost.items():
    v_cnt = Counter(v)
    mapper_lost = mapper_lost.union(set([i for i in v_cnt.keys() if i not in all_shots]))

# %%
def transform(s):
    if s.startswith('f'):
        return ''.join([i for i in s if i in all_chars])
    else:
        return ''.join([i for i in s if i in [j for j in all_chars if j!='+']])

# %%
mapper2_win = {i: transform(i) if transform(i) not in ['0', '4', '5', '6'] else '' for i in mapper_win}
mapper2_lost = {i: transform(i) if transform(i) not in ['0', '4', '5', '6'] else '' for i in mapper_lost}

# %%
mapper2_win
# Out:
# {'f+2': 'f+2',
#  'f+29': 'f+29',
#  'f3-': 'f3',
#  'o3': '3',
#  'f+': 'f+',
#  'y-1': '1',
#  'y': '',
#  'z+1': 'z1',
#  'm': '',
#  'h2': '2',
#  'j=+1': '1',
#  'b-3': 'b3',
#  'b;28': 'b28',
#  'u3': '3',
#  's39': 's39',
#  'u-3': '3',
#  's29': 's29',
#  's+2': 's2',
#  'm2': '2',
#  'f1-': 'f1',
#  'f1+1': 'f1+1',
#  's27': 's27',
#  'f;2': 'f2',
#  'o1': '1',
#  'b+2': 'b2',
#  'b;2': 'b2',
#  'y1': '1',
#  'f8': 'f8',
#  'r28': 'r28',
#  'u1': '1',
#  'b32': 'b32',
#  'u+3': '3',
#  'b;37': 'b37',
#  'l': '',
#  'b;27': 'b27',
#  'z2': 'z2',
#  'o2': '2',
#  'f17': 'f17',
#  'h3': '3',
#  'o=3': '3',
#  'i1': '1',
#  'i3': '3',
#  'h1': '1',
#  'b8': 'b8',
#  'o': '',
#  's-1': 's1',
#  'j;1': '1',
#  'f39': 'f39',
#  'r1': 'r1',
#  'y2': '2',
#  'k': '',
#  'j3': '3',
#  'o-3': '3',
#  's37': 's37',
#  'b+3': 'b3',
#  'r29': 'r29',
#  'b3-': 'b3',
#  's-2': 's2',
#  'j+2': '2',
#  's19': 's19',
#  's+1': 's1',
#  'f-3': 'f3',
#  'r3': 'r3',
#  's+19': 's19',
#  's17': 's17',
#  'r+1': 'r1',
#  'b;3': 'b3',
#  'o=2': '2',
#  'c4': '',
#  'v2': 'v2',
#  'p3': '3',
#  'p2': '2',
#  's38': 's38',
#  'j1': '1',
#  'j+1': '1',
#  's18': 's18',
#  'h': '',
#  'y+3': '3',
#  'z=3': 'z3',
#  'l1': '1',
#  'h+3': '3',
#  'u+1': '1',
#  'f;1': 'f1',
#  'u-1': '1',
#  'f19': 'f19',
#  's+3': 's3',
#  'i=2': '2',
#  'b9': 'b9',
#  'y+1': '1',
#  'j2': '2',
#  'f-2': 'f2',
#  'k3': '3',
#  'b+1': 'b1',
#  'f-1': 'f1',
#  'f;3': 'f3',
#  'o=1': '1',
#  'b+28': 'b28',
#  'f;17': 'f17',
#  'b;17': 'b17',
#  'f+-1': 'f+1',
#  'b+18': 'b18',
#  'i2': '2',
#  'v': 'v',
#  'b39': 'b39',
#  'y3': '3',
#  'c6': '',
#  'm1': '1',
#  'f3+3': 'f3+3'}

# %%
mapper2_lost
# Out:
# {'f+2': 'f+2',
#  'i+': '',
#  'f=2': 'f2',
#  'f+18': 'f+18',
#  'o3': '3',
#  'y-1': '1',
#  'f;19': 'f19',
#  'y+2': '2',
#  'y': '',
#  'm': '',
#  's289': 's289',
#  'r27': 'r27',
#  's;37': 's37',
#  'h2': '2',
#  'b-3': 'b3',
#  'u3': '3',
#  's39': 's39',
#  'u-3': '3',
#  's29': 's29',
#  's+2': 's2',
#  'm2': '2',
#  's27': 's27',
#  'f;2': 'f2',
#  'o1': '1',
#  'b+7': 'b7',
#  'b+2': 'b2',
#  'b;2': 'b2',
#  'b=1': 'b1',
#  'y1': '1',
#  'f+;3': 'f+3',
#  'f8': 'f8',
#  'r28': 'r28',
#  'u1': '1',
#  'f;+3': 'f+3',
#  'u+3': '3',
#  'l': '',
#  'b;27': 'b27',
#  'z2': 'z2',
#  'o2': '2',
#  'f17': 'f17',
#  'h3': '3',
#  'o=3': '3',
#  's+29': 's29',
#  'q': '',
#  'i1': '1',
#  'f;+1': 'f+1',
#  'i3': '3',
#  'b+38': 'b38',
#  'h1': '1',
#  'b8': 'b8',
#  's-1': 's1',
#  'f39': 'f39',
#  'b+19': 'b19',
#  'r1': 'r1',
#  'j3': '3',
#  's37': 's37',
#  'b+3': 'b3',
#  'b-2': 'b2',
#  'r-1': 'r1',
#  's19': 's19',
#  's+1': 's1',
#  'f-3': 'f3',
#  'r3': 'r3',
#  's17': 's17',
#  's+28': 's28',
#  'b+17': 'b17',
#  'r+1': 'r1',
#  'o=2': '2',
#  'v2': 'v2',
#  's38': 's38',
#  'j1': '1',
#  's-3': 's3',
#  'b+;1': 'b1',
#  'j+1': '1',
#  's18': 's18',
#  'h': '',
#  'p1': '1',
#  'y+3': '3',
#  'l1': '1',
#  'z': 'z',
#  'u+1': '1',
#  'f;1': 'f1',
#  'l3': '3',
#  'u-1': '1',
#  'b;1': 'b1',
#  'f19': 'f19',
#  'f9': 'f9',
#  's+3': 's3',
#  'r': 'r',
#  'f+17': 'f+17',
#  'b9': 'b9',
#  'y+1': '1',
#  'b-1': 'b1',
#  'b+1': 'b1',
#  'f12': 'f12',
#  'f;3': 'f3',
#  'b+28': 'b28',
#  'b;38': 'b38',
#  'f-1': 'f1',
#  'b+18': 'b18',
#  'l2': '2',
#  'f-;1': 'f1',
#  'i2': '2',
#  'v': 'v',
#  'b39': 'b39',
#  'y3': '3',
#  'm1': '1'}

# %%
all_dict_win
# Out:
# {'b28': ['b2',
#   'f3',
#   'z3',
#   'z3',
#   'f2',
#   'f3',
#   'f-1',
#   'f3',
#   'f2',
#   'f2',
#   'f1',
#   'f3',
#   'j+2',
#   'f1',
#   'f1',
#   'b2',
#   'f2',
#   'f1',
#   'f+3',
#   'f1',
#   'f1',
#   'f+1',
#   'f1',
#   'f1',
#   'f1-',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'u+1',
#   'z3',
#   'f1',
#   'f1',
#   'f3',
#   'f+1',
#   'f+1',
#   'f+3',
#   'f2',
#   'f2',
#   'f3',
#   'f3',
#   'v1',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f1',
#   'f1',
#   'f+1',
#   'f3',
#   'z1',
#   'f1',
#   'f+3',
#   'f1',
#   'f+1',
#   'f1',
#   'f1',
#   'f+1',
#   'f3',
#   'f+3',
#   'f+1',
#   'f1',
#   'f3',
#   'v3',
#   'f+3',
#   'f+3',
#   'f+3',
#   'f2',
#   'f+3',
#   'f1',
#   'f+3',
#   'b3',
#   'f+1',
#   'f2',
#   'f1',
#   'f+1',
#   'f+1',
#   'f+3',
#   'f;3',
#   'f3',
#   'f+3',
#   'f2',
#   'f3',
#   'f1',
#   'f+1',
#   'f+2',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f+3',
#   'f+1',
#   'f1',
#   'f3',
#   'f+3',
#   'f+3',
#   'f3',
#   'v3',
#   'f3',
#   'f2'],
#  's3': ['f+1',
#   'f1',
#   'f2',
#   'f+',
#   'b1',
#   'b3',
#   'f3',
#   'b3',
#   'f+1',
#   'b1',
#   'f3',
#   'o3',
#   'y+1',
#   'b1',
#   'z3',
#   'b2',
#   'b3',
#   'u+1',
#   'f1',
#   'b3',
#   'v3',
#   'z3',
#   'b3',
#   'v1',
#   'b1',
#   'f1',
#   'z3',
#   'f3',
#   'b-3',
#   'f+1',
#   'f3',
#   'z3',
#   'k3',
#   'f3',
#   'f1',
#   'f+1',
#   'f3',
#   'f+3',
#   'o3',
#   'b3',
#   'b2',
#   'b1',
#   'f1',
#   'b-3',
#   'b3',
#   'f3',
#   'f3',
#   'f3',
#   'f3-',
#   'f1',
#   'f3',
#   'f3',
#   'b2',
#   'f2',
#   'f3',
#   'f3',
#   'f3',
#   'f2',
#   'f+1',
#   'f1',
#   'b3',
#   'b+1',
#   'z3',
#   'b3',
#   'z3',
#   'b1',
#   'b3',
#   'b3',
#   's1',
#   'f3',
#   'b3',
#   'f1',
#   'f3',
#   'b3'],
#  'f37': ['s1',
#   'z1',
#   'b1',
#   'f2',
#   'z1',
#   'b1',
#   'f3',
#   'i2',
#   'b3',
#   'f1',
#   'y1',
#   'f+1',
#   'b3',
#   'f1',
#   'y-1',
#   'f3',
#   'b3',
#   'f1',
#   'b2',
#   'b3',
#   'j;1',
#   'b+3',
#   's1',
#   'f+1',
#   'f1',
#   'f1',
#   's1',
#   'f+1',
#   'f+1',
#   'y+1',
#   'f1',
#   'b1',
#   'y+1',
#   'b3',
#   'f3',
#   'y3',
#   'b3',
#   'y1',
#   'b2',
#   'f3',
#   'f+1',
#   'b+1',
#   'f+1',
#   's1',
#   'b+1',
#   'b2',
#   'f+1',
#   'f-1',
#   'z3',
#   'b3',
#   'f1',
#   'f+2',
#   'z1',
#   'y+1',
#   'y+1',
#   'f1',
#   'b+2',
#   'f1',
#   'b1',
#   'f3',
#   'f3',
#   's2'],
#  'b27': ['f+3',
#   'b2',
#   'z1',
#   'f-3',
#   'z3',
#   'z3',
#   'z3',
#   'f2',
#   'b2',
#   'v2',
#   'f+2',
#   'f+1',
#   'f+1',
#   'f1',
#   'f+3',
#   'v3',
#   'z3',
#   'f3',
#   'f+1',
#   'v1',
#   'v1',
#   'b3-',
#   'f3-',
#   'b2',
#   'f+1',
#   'v1',
#   'f3',
#   'f+1',
#   'v3',
#   'f+1',
#   'f2',
#   'f3',
#   'z3',
#   'f3',
#   'f+2',
#   'f+1',
#   'u+1',
#   'f+3',
#   'f+1',
#   'f3',
#   'z3',
#   'f+3',
#   'f1',
#   'f3',
#   'i1',
#   'u+1',
#   'f3',
#   'f+3',
#   'h',
#   'f1',
#   'f+3',
#   'f+3',
#   'f+1',
#   'f3',
#   'f+1',
#   'v2',
#   'z3',
#   'f+3',
#   'v3',
#   'u+1',
#   'f+3',
#   'b3',
#   'v1',
#   'f+1',
#   'f+1',
#   'f+3',
#   'f2',
#   'f+2',
#   'i1',
#   'z1',
#   'f+1',
#   'f+1',
#   'f-3',
#   'f+3',
#   'f+3',
#   'f+1',
#   'f+1',
#   'f-1',
#   'f+3',
#   'f3',
#   'f+1',
#   'f+1',
#   'f-1',
#   'f+1',
#   'f1',
#   'v1',
#   'f+3',
#   'v1',
#   'f-3',
#   'h2',
#   'v1',
#   'z1',
#   'f3',
#   'f+3',
#   'o-3',
#   'f+1',
#   'f+1'],
#  'f3': ['z1',
#   'b2',
#   'b3',
#   'z1',
#   'f3',
#   's3',
#   'z2',
#   'b2',
#   'z1',
#   'b2',
#   'y+3',
#   'b1',
#   'b1',
#   'f3',
#   'b2',
#   's2',
#   'f1',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'z1',
#   'b3',
#   'f3',
#   'f2',
#   'f3',
#   'b3',
#   'y+1',
#   'b3',
#   'b2',
#   'f+1',
#   'z1',
#   'b3',
#   's3',
#   'f+1',
#   'b1',
#   'f2',
#   'b3',
#   'f2',
#   'b2',
#   'b3',
#   'b1',
#   'f3',
#   's2',
#   'b2',
#   'b2',
#   's1',
#   'b2',
#   'b1',
#   'b3',
#   's3',
#   's1',
#   'y1',
#   'b3',
#   'b2',
#   'b3',
#   'y+1',
#   's1',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   's3',
#   'b2',
#   'b2',
#   's2',
#   'b3',
#   'b3',
#   's3',
#   'b3',
#   's1',
#   'y1',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   's1',
#   'f3',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   'z1',
#   'b+1',
#   'b2',
#   'b3',
#   's1',
#   'b3',
#   'b2',
#   'b1',
#   's3',
#   'b1',
#   'b+1',
#   'z1',
#   'b3',
#   'b3',
#   'f1',
#   'b3',
#   's1',
#   'f3',
#   'b1',
#   'z3',
#   'f+3',
#   'b1',
#   's3',
#   'b3',
#   'f1',
#   'b2',
#   'b3',
#   'z1',
#   'b2',
#   'b3',
#   'b2',
#   'b+1',
#   'f1',
#   'z1',
#   'b3',
#   'b2',
#   'b1',
#   'b3',
#   'b2',
#   'b1',
#   'f3',
#   'b2',
#   'b1',
#   'b2',
#   'b2',
#   'b1',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'b3',
#   'b1',
#   'y3',
#   'b1',
#   'b1',
#   's1',
#   'b3',
#   'f3',
#   'f2',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   's1',
#   'b2',
#   'b2',
#   'b2',
#   'b2',
#   'b2',
#   'f2',
#   'f3',
#   's2',
#   'b3',
#   'b3',
#   'f1',
#   'f3',
#   'f3',
#   'f3',
#   'b1',
#   's3',
#   'b3',
#   's3',
#   'f2',
#   'b1',
#   'i=2',
#   'b3',
#   'f+1',
#   'b1',
#   'f3',
#   'y+1',
#   'b2',
#   'b3',
#   'b1',
#   'f3',
#   'b3',
#   'z1',
#   'f+1',
#   'f2',
#   'y3',
#   'f3',
#   'y3',
#   'b2',
#   'z3',
#   's1',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b-3',
#   'b3',
#   's1',
#   'b1',
#   'f3',
#   'b3',
#   'b3',
#   'z2',
#   'y3',
#   'b3',
#   'f1',
#   'f3',
#   'f3',
#   'z1',
#   'b2',
#   'v1',
#   'b2',
#   'f1',
#   'b2',
#   'b3',
#   'b2',
#   's2',
#   'b1',
#   'z2',
#   's+1',
#   'b2',
#   'b3',
#   'b3',
#   'b3',
#   'b1',
#   'b2',
#   'b;3',
#   'b2',
#   'b2',
#   's3',
#   'f1',
#   'b2',
#   'b3',
#   'b2',
#   's3',
#   'b2',
#   'f3',
#   'f1',
#   'b3',
#   'b3',
#   'b+1',
#   'b2',
#   'b2',
#   'b+1',
#   'b',
#   'f1',
#   'b2',
#   'b3',
#   'f3',
#   'b1',
#   'b3',
#   'b1',
#   'b2',
#   's3',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'b1',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'y+3',
#   'b1',
#   's1',
#   'b1',
#   's1',
#   's1',
#   'b1',
#   'b2',
#   's3',
#   'b3',
#   'b2',
#   'b1',
#   'b1',
#   's1',
#   'b3',
#   'b2',
#   'b3',
#   's1',
#   'b3',
#   'b3',
#   'f3',
#   's1',
#   'j3',
#   'b3',
#   'b2',
#   'b1',
#   'y3',
#   'b1',
#   'f3',
#   'b2',
#   'b3',
#   's1',
#   'y2',
#   'y1',
#   'z1',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   'f3',
#   'b3',
#   's1',
#   's1',
#   'b2',
#   'b3',
#   'b+1',
#   's2',
#   'f1',
#   'b2',
#   'b1',
#   's3',
#   'b3',
#   'b1',
#   'b1',
#   'b2',
#   'b3',
#   'b1',
#   'b3',
#   's2',
#   'b2',
#   'f2',
#   'b2',
#   'b2',
#   'b3',
#   'f2',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'f+1',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'f+3',
#   'b3',
#   'b1',
#   'b3',
#   'b2',
#   's+2',
#   'b3',
#   'b2',
#   'b+3',
#   'u+3',
#   'b1',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'f1',
#   'b2',
#   'b2',
#   'b1',
#   'b1',
#   'b3',
#   's3',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   'b2',
#   's3',
#   's1',
#   'b2',
#   'b1',
#   's1',
#   'b3',
#   'b3',
#   's2',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   's1',
#   'b3',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'b1',
#   's2',
#   's1',
#   'b1',
#   'b3',
#   's+3',
#   'b3',
#   'f+1',
#   'b3',
#   'b2',
#   'b3',
#   'y',
#   'b2',
#   'b3',
#   'b2',
#   'b1',
#   'b1',
#   'b2',
#   'f3',
#   'b2',
#   'b3',
#   's3',
#   'b2',
#   'z1',
#   's1',
#   'b3',
#   'b3',
#   'f2',
#   's1',
#   's3',
#   'b1',
#   'f1',
#   'f3',
#   'f1',
#   'b3',
#   'b3',
#   'b1',
#   's2',
#   'b2',
#   'b2',
#   'b3',
#   's2',
#   'f2',
#   'b2',
#   'b2',
#   'b1',
#   'b+2',
#   'b3',
#   'b+1',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'f2',
#   's2',
#   'b1',
#   'b1',
#   'f2',
#   'b3',
#   'b1',
#   'b2',
#   'f2',
#   'f1',
#   'b3',
#   's2',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b3',
#   'b2',
#   's3',
#   's1',
#   'b3',
#   's1',
#   's2',
#   'b3',
#   'b3',
#   'b2',
#   'f1',
#   'b2',
#   'b3',
#   'y+1',
#   'b2',
#   'b2',
#   'f2',
#   'b3',
#   'b3',
#   'f3',
#   's1',
#   'b1',
#   'b2',
#   'b+3',
#   'b3',
#   'b2',
#   's2',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   's3',
#   'b1',
#   'b1',
#   'b+1',
#   's3',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b3',
#   'b+1',
#   's3',
#   'y1',
#   'b2',
#   'b1',
#   'b3',
#   'b1',
#   'f1',
#   'f1',
#   's3',
#   'b1',
#   'b1',
#   'b1',
#   'b2',
#   'b3',
#   'b3',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'b1',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b+2',
#   'b2',
#   'b1',
#   'b1',
#   'b3',
#   'b1',
#   'b+1',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   's3',
#   'f1',
#   'b1',
#   's1',
#   'f1',
#   'b1',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'f1',
#   's3',
#   'b2',
#   'b2',
#   'b3',
#   'b+1',
#   'f3',
#   'b2',
#   'f1',
#   'b2',
#   'b1',
#   'b+2',
#   'b3',
#   'b3',
#   'b2',
#   'b+1',
#   'b3',
#   'b3',
#   'b1',
#   'f2',
#   'b1',
#   'b1',
#   'b1',
#   's1',
#   'b2',
#   'f3',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   's2',
#   'b2',
#   'b2',
#   'b2',
#   's2',
#   'b2',
#   'b2',
#   's3',
#   'b1',
#   'b3',
#   's1',
#   's3',
#   's2',
#   'b2',
#   'b1',
#   's2',
#   'b3',
#   'b2',
#   's3',
#   'b;2',
#   'b2',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   's3',
#   's3',
#   'b2',
#   's3',
#   'b3',
#   'b3',
#   's1',
#   's1',
#   'b+1',
#   's1',
#   's2',
#   'b1',
#   's1',
#   's2',
#   's1',
#   'b3',
#   'b2',
#   's3',
#   's1',
#   'b1',
#   's2',
#   'b3',
#   'f3',
#   'f1',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'f1',
#   'f3',
#   'b2',
#   'b1',
#   's3',
#   's3',
#   'f2',
#   'b2',
#   'b3',
#   'f3',
#   'f1',
#   'b1',
#   'b1',
#   'b2',
#   'f2',
#   's1',
#   'b2',
#   'b3',
#   'b2',
#   'f1',
#   's1',
#   's3',
#   'b1',
#   'b1',
#   'b2',
#   'b3',
#   's3',
#   'b3',
#   'f3',
#   'b1',
#   's3',
#   'f1',
#   'y+1',
#   'b2',
#   'b3',
#   'f3',
#   'b1',
#   'b1',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   's+1',
#   'b1',
#   'f2',
#   'b3',
#   's2',
#   'b2',
#   'b3',
#   'f3',
#   's2',
#   'b3',
#   's2',
#   's2',
#   'b3',
#   'y3',
#   'y+3',
#   's1',
#   'y1',
#   'f1',
#   'b2',
#   'b3',
#   'b2',
#   's1',
#   'b+2',
#   'b1',
#   'f3',
#   's3',
#   'o2',
#   's1',
#   'b+3',
#   'z3',
#   's3',
#   'b2',
#   'z3',
#   'b1',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'b3',
#   'b2',
#   'b1',
#   'f2',
#   'b3',
#   'b2',
#   'b1',
#   's3',
#   'b2',
#   'y+3',
#   'b2',
#   'b2',
#   'b1',
#   'b3',
#   'y+1',
#   's1',
#   'b1',
#   's3',
#   'f3',
#   's2',
#   'b2',
#   'f2',
#   'b2',
#   'b2',
#   's2',
#   'b3',
#   'b+3',
#   'b3',
#   's3',
#   'b2',
#   'b2',
#   's+1',
#   'b2',
#   'b2',
#   'b2',
#   's1',
#   'b2',
#   's3',
#   'f1',
#   's2',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   's+1',
#   'f2'],
#  'm3': ['o3',
#   'p2',
#   'o3',
#   'o3',
#   'o3',
#   'o2',
#   'p3',
#   'z=3',
#   'p2',
#   'o3',
#   'p3',
#   'p3'],
#  'b29': ['f1',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'b1',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'b3',
#   'f1',
#   'f2',
#   'f3',
#   'f2',
#   'b1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f2',
#   'f1'],
#  's2': ['f3',
#   'f3',
#   'f+3',
#   'f+1',
#   'v3',
#   'z3',
#   'f+1',
#   'f1',
#   'f3',
#   'z3',
#   'r1',
#   'f+3',
#   'f+3',
#   'f1',
#   'z3',
#   'f1',
#   'f+3',
#   'z3',
#   'v2',
#   'b3',
#   'o3',
#   'y1',
#   'f+3',
#   'j1',
#   'v1',
#   'j3',
#   'f1',
#   'v3',
#   'f+1',
#   'z3',
#   'y+1',
#   'j=+1',
#   'h1',
#   'z3',
#   'f+3',
#   'v3',
#   's1',
#   's1',
#   'z3',
#   'b+3',
#   'f3',
#   'r+1',
#   'o',
#   'f+1',
#   'f1',
#   'f+1',
#   'f1',
#   'f+1',
#   'f3',
#   'f+3',
#   'b3',
#   'o3',
#   'f+3',
#   'b3',
#   'f3',
#   'f+1',
#   'f3',
#   'f+3',
#   'f1',
#   'b2',
#   'j1',
#   's-2',
#   'f1',
#   'f2',
#   'v1',
#   'f+1',
#   'v2',
#   'f+1',
#   'b+2',
#   'j+1',
#   'b3',
#   'f1',
#   'f-3',
#   'f+3'],
#  'f2': ['b2',
#   'f1',
#   'f1',
#   'v1',
#   'b3',
#   'b+2',
#   'f+2',
#   'f+1',
#   'b2',
#   'f1',
#   'f2',
#   'f3',
#   'b2',
#   'b3',
#   'f1',
#   'b2',
#   'f3',
#   'b1',
#   'f+3',
#   'f+1',
#   'f+1',
#   'f1',
#   'z1',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'b2',
#   'v1',
#   'f1',
#   'f3',
#   'f3',
#   'z2',
#   'f3',
#   'b3',
#   'z1',
#   'f1',
#   'f1',
#   'z1',
#   'f2',
#   'f1',
#   'f1',
#   'z1',
#   'f2',
#   'b2',
#   'f+3',
#   'v1',
#   'f2',
#   'f1',
#   'b2',
#   'f1',
#   'f+3',
#   'z1',
#   'i2',
#   'b3',
#   'f1',
#   'f1',
#   'f1',
#   'o1',
#   'f2',
#   'f2',
#   's2',
#   'f2',
#   'i2',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'b2',
#   'f2',
#   'z1',
#   'v2',
#   'f3',
#   'v1',
#   'f1',
#   'f1',
#   'v2',
#   'f+1',
#   'f3',
#   'f1',
#   'v1',
#   'f2',
#   'f3',
#   'f3',
#   'v1',
#   'f+1',
#   'f1',
#   'f2',
#   'b3',
#   's2',
#   'f1',
#   'f-3',
#   'f2',
#   'f1',
#   'f3',
#   'b3',
#   'f1',
#   'f2',
#   'r+1',
#   'b2',
#   'b2',
#   'f1',
#   'f1',
#   'f1',
#   'j+2',
#   'b2',
#   'f',
#   'b2',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f2',
#   'b1',
#   'f3',
#   'b+1',
#   'b1',
#   'b1',
#   'f1',
#   'b3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'b1',
#   'b1',
#   'f1',
#   'b2',
#   'f+1',
#   'u+1',
#   'f3',
#   'f3',
#   'f2',
#   'f2',
#   'f3',
#   'f1',
#   'f+1',
#   'b2',
#   'b2',
#   'b3',
#   'b2',
#   'f3',
#   'f3',
#   'f3',
#   'v1',
#   'f+3',
#   'f1',
#   'b2',
#   'f2',
#   'f1',
#   'f1',
#   'b1',
#   'u3',
#   'f3',
#   'b1',
#   'b3',
#   'b1',
#   'b2',
#   'f1',
#   'b2',
#   'f3',
#   'f2',
#   'f1',
#   'b2',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'b3',
#   'f3',
#   'f1',
#   'f3',
#   's1',
#   'b2',
#   'b3',
#   'b2',
#   'f+1',
#   'f+1',
#   'f1',
#   'b1',
#   'b1',
#   'b2',
#   'f2',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'z3',
#   'f1',
#   'f3',
#   'b2',
#   's1',
#   'f1',
#   'f2',
#   'b1',
#   'f1',
#   'f2',
#   'f2',
#   'f;3',
#   'f+1',
#   'f1',
#   'b2',
#   'b2',
#   'f1',
#   'f2',
#   'f+1',
#   'b1',
#   'f3',
#   'b2',
#   'f2',
#   'f1',
#   'b2',
#   'f1',
#   'f2',
#   'f1',
#   'b3',
#   'f3',
#   'f3',
#   'f2',
#   'b2',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'b1',
#   'f2',
#   'b2',
#   'f1',
#   'f1',
#   'f2',
#   'b2',
#   'f1',
#   'b2',
#   'f2',
#   'b1',
#   'f1',
#   'f1',
#   'b2',
#   'b2',
#   'j1',
#   'b2',
#   'f3',
#   'f1',
#   'b1',
#   'f1+1',
#   'f2',
#   'b3',
#   'f+1',
#   'b3',
#   'b1',
#   'f2',
#   'f1',
#   'f1',
#   'b1',
#   'f2',
#   'f2',
#   'b2',
#   'b2',
#   'b1',
#   'f3',
#   'f1',
#   'f2',
#   'b1',
#   'b1',
#   'f3',
#   'f3',
#   'f+1',
#   'f1',
#   'f2',
#   'f3',
#   'b2',
#   'b1',
#   'f1'],
#  'b2': ['f1',
#   'b2',
#   'f2',
#   'b2',
#   'f2',
#   'f1',
#   'b2',
#   'f1',
#   'f+1',
#   'f3',
#   'f+1',
#   'z1',
#   'f1',
#   'f1',
#   'f3',
#   'b2',
#   'f3',
#   'f1',
#   'f+3',
#   'y+1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f2',
#   'f+1',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'b2',
#   'f3',
#   'f1',
#   'b1',
#   'f1',
#   'v3',
#   'u-1',
#   'f3',
#   'b1',
#   'f2',
#   'b2',
#   'f3',
#   'f3',
#   'z3',
#   'f3',
#   'f1',
#   'f2',
#   'f2',
#   'b1',
#   'f1',
#   'b3',
#   'f1',
#   'v1',
#   'f2',
#   'f+3',
#   'b2',
#   'b3',
#   'f2',
#   'f+3',
#   'f1',
#   'f2',
#   'b1',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'b3',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'v1',
#   'f3',
#   'z1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f2',
#   'f1',
#   'z3',
#   'f+1',
#   'v3',
#   'f+3',
#   'f1',
#   'f1',
#   'f2',
#   'b1',
#   'f1',
#   'f3',
#   'f1',
#   'f+1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'b2',
#   'f1',
#   'f3',
#   'f+3',
#   'f1',
#   'f3',
#   'b2',
#   'v3',
#   'f2',
#   'v1',
#   'f2',
#   'f1',
#   'f+3',
#   'f+1',
#   'f3',
#   'f2',
#   'b2',
#   'b2',
#   'f1',
#   'f+1',
#   'z1',
#   'z1',
#   'f1',
#   'f3',
#   'f+3',
#   'f3',
#   'f1',
#   'b2',
#   'f2',
#   'f1',
#   'f2',
#   'f2',
#   'i2',
#   'f1',
#   'f2',
#   'f2',
#   'z3',
#   'f+3',
#   'f1',
#   'j+2',
#   'v3',
#   'f+1',
#   'z3',
#   'f2',
#   'f3',
#   'f+-1',
#   'f+3',
#   'z3',
#   'f2',
#   'f2',
#   'z1',
#   'v3',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'z1',
#   'f1',
#   'f2',
#   'f+1',
#   'f+3',
#   'b2',
#   'v3',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   'b3',
#   'b1',
#   'f2',
#   'b2',
#   'f1',
#   'b3',
#   's1',
#   'f1',
#   'b3',
#   'f1',
#   'b1',
#   'b3',
#   'f2',
#   'f+3',
#   'f2',
#   'f3',
#   'f+1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f+3',
#   'b3',
#   'b2',
#   'f-3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'b2',
#   'f1',
#   's3',
#   'f3',
#   'b3',
#   'f1',
#   's3',
#   'f2',
#   'f2',
#   'f+1',
#   'v3',
#   'f2',
#   'f3',
#   'b3',
#   'f+3',
#   'f1',
#   'i2',
#   'b2',
#   'f3',
#   'f1',
#   'f3',
#   'b2',
#   'r1',
#   'b3',
#   'b2',
#   'f3',
#   'f+3',
#   'b3',
#   'f1',
#   'b+3',
#   'b2',
#   'b2',
#   'f1',
#   'f2',
#   's1',
#   'z2',
#   'f1',
#   'f2',
#   'f3',
#   'b2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'b2',
#   'f1',
#   'f2',
#   'f1',
#   'u+1',
#   'f2',
#   'b2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'b3',
#   'b1',
#   'f3',
#   'b3',
#   'f+1',
#   'b3',
#   'b1',
#   'f2',
#   'f1',
#   'f3',
#   'b3',
#   'f+1',
#   'f+3',
#   'f1',
#   'b1',
#   'f+1',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f+1',
#   'f3',
#   'f+3',
#   'f1',
#   'f3',
#   'f+1',
#   'f3',
#   'f1',
#   'b2',
#   'f1',
#   'f1',
#   'f1',
#   'f+3',
#   'v1',
#   'v1',
#   'f1',
#   'f1',
#   'f3',
#   'b+2',
#   'z2',
#   'v1',
#   'f1',
#   'f2',
#   'y+1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'b32',
#   's1',
#   'f1',
#   'b3',
#   'f3',
#   'b3',
#   'f3',
#   'f2',
#   'f+3',
#   'b3',
#   'f3',
#   'v3',
#   'b2',
#   'z2',
#   'z2',
#   'b;3',
#   'f+1',
#   'b2',
#   'f2',
#   'b1',
#   'b3',
#   'f+1',
#   'z2',
#   'f2',
#   'f+1',
#   'b3',
#   'f1',
#   'b2',
#   'f3',
#   'f2',
#   'f2',
#   'f2',
#   'f1',
#   'f+3',
#   'f1',
#   'f1',
#   's2',
#   'f1',
#   'f1',
#   'b1',
#   'b2',
#   'y1',
#   'f1',
#   'b2',
#   'f+3',
#   'f+3',
#   'f1',
#   'f+3',
#   'f1',
#   'f1',
#   'f2',
#   'f+3',
#   'f3',
#   'f1',
#   'f3',
#   'z3',
#   'f1',
#   'b+3',
#   'f+1',
#   'f1',
#   'f3',
#   'f+3',
#   's3',
#   'f3',
#   'b3',
#   'f1',
#   'f2',
#   's1',
#   'f3',
#   'f3',
#   'b3',
#   'f1',
#   'b1',
#   'b2',
#   'f1',
#   'f+3',
#   'f1',
#   'f2',
#   'f1',
#   'b1',
#   'b1',
#   'z1',
#   'z3',
#   'f1',
#   'f+1',
#   'f3',
#   'f1',
#   'f1',
#   'v1',
#   'f+3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'b2',
#   'f2',
#   'f3',
#   'b2',
#   'b2',
#   'v3',
#   'f3',
#   'f1',
#   'f1',
#   'f3'],
#  'b1': ['f1',
#   'v3',
#   'f3',
#   'f1',
#   'v3',
#   'f1',
#   'f2',
#   'v3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f',
#   'f2',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f2',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f+3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f2',
#   'f3',
#   'h3',
#   'f3',
#   'f1',
#   'f2',
#   'v3',
#   'f2',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'v3',
#   'f1',
#   'v1',
#   'v1',
#   'f2',
#   'f1',
#   'f2',
#   'f3',
#   'f+1',
#   'f3',
#   'f+2',
#   'f1',
#   'f2',
#   'v1',
#   'f1',
#   'f3',
#   'f+3',
#   'f1',
#   'f1',
#   'f+1',
#   'v3',
#   'f1',
#   'f+1',
#   'f3',
#   'v1',
#   'v3',
#   'f1',
#   'f2',
#   'f1',
#   'j3',
#   'f1',
#   'f2',
#   'f2',
#   'f2',
#   'f1',
#   'f2',
#   'v3',
#   'f1',
#   'f1',
#   'f2',
#   'f+3',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'v3',
#   'f1',
#   'v3',
#   'r2',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f+3',
#   'v3',
#   'f1',
#   'f1',
#   'f3',
#   'j3',
#   'f1',
#   'v1',
#   'f1',
#   'h3',
#   'f3',
#   'f1',
#   'f+1',
#   'v1',
#   'f+1',
#   'f1',
#   'f1',
#   'f2',
#   'j3',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'v1',
#   'f3',
#   'v3',
#   'f+1',
#   'f1',
#   'v3',
#   'f1',
#   'v3',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f2',
#   'v3',
#   'f1',
#   'f1',
#   'f3',
#   'f+2',
#   'f3',
#   'v3',
#   'f2',
#   'f+3',
#   'f1',
#   'v3',
#   'f1',
#   'v1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f2',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f3',
#   'f1',
#   'f+1',
#   'f1',
#   'f1',
#   'f1',
#   'f-3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'u-1',
#   'u-1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f+3',
#   'f1',
#   'f1',
#   'v3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f2',
#   'f2',
#   'f1',
#   'f1',
#   'r1',
#   'f3',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'l1',
#   'f+3',
#   'f3',
#   'r2',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'u+3',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   'f1',
#   'f3',
#   'f+1',
#   'v3',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f3',
#   'f+3',
#   'f3',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'v1',
#   'f;1',
#   'f2',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f+1',
#   'v3',
#   'f1',
#   'f1',
#   'f+3',
#   'f3',
#   'f1',
#   'f1',
#   'f+3',
#   'f2',
#   'f1',
#   'f3',
#   'f+3',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'v3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f+3',
#   'f3',
#   'f1',
#   'f1',
#   'f+3',
#   'f1',
#   'f+3',
#   'f1',
#   'f1',
#   'f3',
#   'r3',
#   'f3',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f;3',
#   'f+3',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'v2',
#   'r1',
#   'f3',
#   'f2',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1'],
#  'f238': ['f2'],
#  'f38': ['f3',
#   'f2',
#   'f2',
#   'f2',
#   'b2',
#   'b1',
#   's2',
#   'b1',
#   'b1',
#   'f3',
#   'b3',
#   'f3',
#   'f1',
#   'f3',
#   'y+1',
#   's1',
#   'b3',
#   'b3',
#   'f1',
#   's1',
#   'f2',
#   'f1',
#   'b1',
#   'b1',
#   'f3',
#   'b2',
#   's1',
#   'b1',
#   'b2',
#   'b2',
#   'b2',
#   'f1',
#   'f1',
#   'y1',
#   'b2',
#   'b3',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'b3',
#   'f1',
#   'f1',
#   'f2',
#   'b1',
#   'b1',
#   's+1',
#   'f+3',
#   'f+1',
#   'f3',
#   'f1',
#   's+1',
#   'b1',
#   'b1',
#   'b3'],
#  'f28': ['f1',
#   'f-3',
#   'f+3',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'f+3',
#   'f3',
#   'f1',
#   'f2',
#   'f3',
#   'v3',
#   'f1',
#   'f+1',
#   'f+1',
#   'f1',
#   'f2',
#   'f1',
#   'b3',
#   'f1',
#   'y3',
#   'f1',
#   'y1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f3',
#   'f+1',
#   'f3',
#   'f2',
#   'f1',
#   'f3',
#   'f2',
#   'f+1',
#   'f2',
#   'f+1',
#   'f3',
#   'f3',
#   'f2',
#   'f2',
#   'f+1',
#   'f2',
#   'f1',
#   'f2',
#   'f2',
#   'f+1',
#   'f2',
#   'j1',
#   'b3',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f+2',
#   'f1',
#   'f+1',
#   'f3',
#   'f1',
#   'f2',
#   'f+1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f+1',
#   'f1',
#   'f2',
#   'f3',
#   'f+1',
#   'f3',
#   'o=1',
#   'f1'],
#  'b3': ['f3',
#   'f1',
#   'z1',
#   'z3',
#   'z3',
#   'b3',
#   'b1',
#   'b3',
#   'b3',
#   'b2',
#   'f1',
#   'i3',
#   'b3',
#   'b2',
#   'z3',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'z1',
#   'b3',
#   'f1',
#   'b3',
#   'b1',
#   'b2',
#   's3',
#   'f3',
#   'b1',
#   'f3',
#   'b1',
#   'f2',
#   'b1',
#   'b3',
#   'b2',
#   'b;2',
#   'b1',
#   'b3',
#   'b;3',
#   'z2',
#   'b2',
#   'b1',
#   'z1',
#   'y+1',
#   's+1',
#   'z1',
#   'f3',
#   'z3',
#   's1',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b2',
#   'f+1',
#   'b1',
#   'b2',
#   'b3',
#   'b2',
#   'f3',
#   'z3',
#   'f2',
#   'b1',
#   'b;3',
#   'z3',
#   'b3',
#   'b3',
#   'z3',
#   'b1',
#   'b1',
#   'b1',
#   'v3',
#   'f3',
#   'b1',
#   'b+3',
#   'f2',
#   'f3',
#   'b1',
#   'b2',
#   'z3',
#   'z2',
#   'b1',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   's1',
#   'f1',
#   'f1',
#   'f3',
#   'b3',
#   'z3',
#   'z3',
#   'f2',
#   'z3',
#   'b1',
#   'b3',
#   'b2',
#   'f3',
#   's1',
#   'b1',
#   's3',
#   'z3',
#   'z3',
#   's1',
#   'b1',
#   'z3',
#   's3',
#   'z3',
#   'z3',
#   'b+1',
#   'b3',
#   'k',
#   'b3',
#   'b1',
#   'b2',
#   'b1',
#   's1',
#   'f3',
#   'f1',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'b1',
#   'f1',
#   's1',
#   's1',
#   'f1-',
#   'b3',
#   'b3',
#   's1',
#   'f3',
#   'y1',
#   'b1',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'b;3',
#   'b1',
#   'z1',
#   'b1',
#   'b2',
#   'b3',
#   'y+1',
#   'b3',
#   'f2',
#   'b1',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b;2',
#   'b3',
#   'z3',
#   'f1',
#   'z3',
#   's3',
#   'b1',
#   'b2',
#   'b3',
#   'b2',
#   'f1',
#   'z3',
#   'b3',
#   'f1',
#   's2',
#   'z2',
#   'y+1',
#   's1',
#   'b3',
#   'b2',
#   'f+1',
#   's3',
#   'b2',
#   'b2',
#   's1',
#   'f1',
#   's1',
#   's3',
#   's1',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'f3',
#   'b2',
#   'b1',
#   'b1',
#   'b1',
#   'b3',
#   'b3',
#   'b1',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'z3',
#   's2',
#   'b1',
#   's1',
#   'b2',
#   'b3',
#   's1',
#   'z3',
#   'b3',
#   'b2',
#   'b1',
#   'f1',
#   'b1',
#   'b1',
#   'b1',
#   'b3',
#   'b1',
#   's1',
#   's2',
#   'b3',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b3',
#   's3',
#   'b1',
#   'b2',
#   'b3',
#   'b2',
#   'z3',
#   'b2',
#   'b1',
#   'f2',
#   'b1',
#   's3',
#   's2',
#   'b1',
#   's1',
#   'b3',
#   's1',
#   'b1',
#   'b3',
#   'b2',
#   'b+1',
#   'b1',
#   'b2',
#   's1',
#   's1',
#   's1',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'f3',
#   'z3',
#   'b3',
#   'b1',
#   'b3',
#   's1'],
#  's37': ['f1', 'f1', 'z3', 'f+3', 'z1', 'u+1', 'f+3', 'u1'],
#  'f1': ['f;1',
#   'f1',
#   'h2',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'r1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'o3',
#   'f1',
#   'f1',
#   'f-2',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f2',
#   'f3',
#   'v1',
#   'f3',
#   'f1',
#   'r1',
#   'f1',
#   'f1',
#   'r2',
#   'v1',
#   'f1',
#   'r3',
#   'f1',
#   'f2',
#   'f2',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f2',
#   'f3',
#   'v1',
#   'v1',
#   'f1',
#   'f2',
#   'f2',
#   'v1',
#   'f1',
#   'f1',
#   'f2',
#   'v1',
#   'f2',
#   'f3',
#   'f1',
#   'v1',
#   'f2',
#   'v1',
#   'f3',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f;1',
#   'f3',
#   'r1',
#   'f2',
#   'r2',
#   'f2',
#   'f2',
#   'f2',
#   'f1',
#   'v1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f+2',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'r1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   'f1',
#   'v1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f3',
#   'f3',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'r3',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'v1',
#   'f+1',
#   'v2',
#   'f1',
#   'f1',
#   'f1',
#   'f1'],
#  'b18': ['f3',
#   'f3',
#   'r2',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f+3',
#   'f3',
#   'f1',
#   'f1',
#   'f+3',
#   'f+3',
#   'f+1',
#   'f1',
#   'f;2',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f2'],
#  'f8': ['b', 'f-1'],
#  'f27': ['f3',
#   'f2',
#   'f+1',
#   'f+1',
#   'b1',
#   'f1',
#   'f1',
#   'v1',
#   'f3',
#   'u+1',
#   'z1',
#   'f1',
#   'f3',
#   'f-3',
#   'f3',
#   'b1',
#   'v2',
#   'f+2',
#   'f+1',
#   'f+3',
#   'u+3',
#   'f+1',
#   'f3',
#   'f3',
#   'f+1',
#   'z2',
#   'z2',
#   'f+3',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f1',
#   'f+3',
#   'f-1',
#   'f+1',
#   'f+1',
#   'f+1',
#   'f3',
#   'f1',
#   'v3',
#   'f3',
#   'f+3',
#   'f3',
#   'f3',
#   'f-1',
#   'o1',
#   'f+3',
#   'f+1',
#   'f-1',
#   'f3'],
#  'b8': ['b', 'b'],
#  'm2': ['o3',
#   'o3',
#   'o=3',
#   'o3',
#   'o2',
#   'o1',
#   'o3',
#   'o3',
#   'o3',
#   'o1',
#   'o3',
#   'o3',
#   'o1',
#   'f1',
#   'o1',
#   'o3',
#   'o2',
#   'o1',
#   'o3'],
#  'b7': ['v'],
#  's': ['b', 'z3', 'j3', 'j1', 'f+'],
#  'f': ['s', 'v3', 'b', 'b', 'b', 'b'],
#  'b39': ['f3',
#   'b3',
#   'f3',
#   'b3',
#   'f3',
#   'b3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'b1',
#   'b1',
#   'b3',
#   'b1',
#   'b3',
#   'f3',
#   's3',
#   'f1',
#   'f1'],
#  's27': ['j3',
#   'o3',
#   'j3',
#   'f+3',
#   'v3',
#   'z1',
#   'z1',
#   'j3',
#   'f+1',
#   'f3',
#   'f-1',
#   'f-3',
#   'f+1',
#   'z3',
#   'f-3',
#   'f+1',
#   'f+1',
#   'f+3',
#   's+1',
#   'f+1'],
#  'f7': ['s'],
#  'b17': ['v3',
#   'f+2',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f2',
#   'v3',
#   'f1',
#   'f1',
#   'f+1',
#   'f3',
#   'f-3',
#   'f1',
#   'f1',
#   'f2',
#   'f3',
#   'v3',
#   'f3',
#   'v3',
#   'f1',
#   'f+3',
#   'f+3',
#   'f+3',
#   'f+2',
#   'v3',
#   'o3',
#   'f2'],
#  'f19': ['f1', 'f1', 'f1'],
#  's38': ['z1', 'f3', 'f3', 'b3', 'f3', 'b+1', 'f3', 'f3', 'z3'],
#  'b37': ['f3',
#   'z1',
#   'u-1',
#   'b3',
#   'f3',
#   'f3',
#   'f1',
#   'u+1',
#   'f3',
#   'o1',
#   'f+1',
#   'b1',
#   'b3',
#   'f2',
#   'f3',
#   'b3',
#   'b3',
#   'f3',
#   'f+1',
#   'f3',
#   'f+1',
#   'f+3',
#   'z3',
#   's3',
#   'f3'],
#  's28': ['f+3',
#   'z3',
#   'f1',
#   'f+3',
#   'f+1',
#   'f+1',
#   'f+3',
#   'f+1',
#   'u+1',
#   'f1',
#   'f+1',
#   'o2',
#   'f+3',
#   'j1',
#   'f+1',
#   'f3',
#   'j3',
#   'f+1',
#   'f1',
#   'z2',
#   'f+1',
#   'f+3',
#   'j+1',
#   'f+3',
#   'z3',
#   'f+3',
#   'z3',
#   'f3',
#   'f3',
#   'f+3',
#   'j3'],
#  'b38': ['f2',
#   'b1',
#   'b1',
#   'b3',
#   'b3',
#   'y1',
#   'f3',
#   'f;1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'b2',
#   'b3',
#   'b2',
#   'f1',
#   'b+1',
#   'f1',
#   'f1',
#   'b2',
#   'b1',
#   'b2',
#   'f1',
#   'b1',
#   'b3',
#   'b1',
#   'b3',
#   'f2',
#   'f1',
#   'b3',
#   'f1',
#   'b3',
#   'b1',
#   'f1',
#   'b2',
#   'f1',
#   'f+1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   's3',
#   'f3'],
#  'f18': ['f1', 'f1', 'f1', 'f1', 'f1', 'f1', 'f2', 'f+3', 'o1', 'f3', 'f3'],
#  'l2': ['o2', 'o3', 'o1', 'o1', 'o2', 'o1'],
#  'b+3': ['m1', 's2', 's2', 's1', 'm2', 'b3'],
#  'r2': ['f+1',
#   'v1',
#   'f2',
#   'f1',
#   'v2',
#   'f+1',
#   'j2',
#   'f+1',
#   'j=+1',
#   'f+1',
#   'o=1',
#   'f+1',
#   'j2',
#   'j2',
#   'f1',
#   'j+1',
#   'j1',
#   'z1',
#   'i2',
#   'f+3',
#   'j+1'],
#  'f39': ['f2',
#   'f1',
#   'b1',
#   'f1',
#   'f1',
#   'f1',
#   'b1',
#   'b3',
#   'f2',
#   'b2',
#   'b2',
#   'b2',
#   'b1',
#   'b3',
#   'b2',
#   'f1',
#   'b2',
#   'b2'],
#  's39': ['o2', 'b1', 'f3', 'f;1', 'f2', 'f3', 'f1', 'f3'],
#  'm+3': ['p3'],
#  'r3': ['i1',
#   'z2',
#   'f3',
#   'f3',
#   'f2',
#   'f+1',
#   'b+1',
#   'f3',
#   'b3',
#   'z+1',
#   'b3',
#   'b1',
#   'f3',
#   'f+1',
#   'f3',
#   'f+1',
#   'b3',
#   'f+1'],
#  's1': ['f3+3',
#   'f1',
#   'f1',
#   'f1',
#   'f-3',
#   'f1',
#   'f2',
#   'f+3',
#   'h+3',
#   'v2',
#   'u-3',
#   'f3',
#   'f3',
#   'f3',
#   'f+1'],
#  'f17': ['f+3', 'f+1', 's3', 'b+1', 'f1', 'f2', 'f+1', 'f+3', 'f1'],
#  'f-2': ['z1'],
#  'b19': ['f2', 'f3', 'f1', 'f1'],
#  's29': ['f1', 'f1', 'f1', 'f3'],
#  'f29': ['f1',
#   'b2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   's1',
#   'f1',
#   'f1',
#   'f3',
#   'f+3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f+1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3'],
#  'f;1': ['f1', 'f+1'],
#  'b-3': ['z1'],
#  'b+38': ['s3'],
#  'r27': ['f+3', 'f3', 'v2'],
#  'f+3': ['b2',
#   'b1',
#   'b1',
#   's3',
#   'b3',
#   'b1',
#   's3',
#   's1',
#   'b1',
#   's1',
#   'b3',
#   'm2',
#   'b1',
#   'b3',
#   'b3',
#   's3',
#   'b3',
#   's3',
#   'm2',
#   's1',
#   's2',
#   's2',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   's3'],
#  'f+2': ['b2'],
#  'b;27': ['f+1'],
#  'm17': ['o3'],
#  'b;3': ['f2'],
#  'f;37': ['f3'],
#  'u3': ['s1', 'm', 'b3'],
#  'b;1': ['f1', 'f1', 'f+1'],
#  'f;38': ['b2'],
#  'm1': ['o1', 'o3', 'o1', 'o3'],
#  'l3': ['o3', 'o=2'],
#  'f+1': ['f2', 'f1', 'f1', 'f3', 'f3', 'f3', 'f1', 'f2', 'f1', 'f3', 'f2'],
#  'v2': ['b3', 'v1', 'f1'],
#  'm': ['o3', 'o1', 'o3', 'o1', 'o3', 'o3'],
#  'r1': ['f1', 'o1', 'j1', 'f-1', 'v1', 'f1', 'f+3', 'j3', 'f2', 'v1'],
#  'u1': ['f3', 'f-1', 'f+1'],
#  'm27': ['o3'],
#  'm28': ['o2', 'o2'],
#  'r29': ['f3'],
#  'b;2': ['f1', 'f1', 's1'],
#  'l1': ['o3', 'o1'],
#  's17': ['f3'],
#  's18': ['f1'],
#  'f;28': ['f+1'],
#  'y37': ['s-1'],
#  'f;27': ['f3', 'f3'],
#  'r19': ['f+1'],
#  'y2': ['b1'],
#  'u2': ['f3'],
#  'r28': ['f;3'],
#  'f-1': ['v1'],
#  'b+2': ['b3'],
#  '4': ['b;37',
#   'b27',
#   'f17',
#   'f18',
#   'b28',
#   'f38',
#   'f28',
#   'b18',
#   'f29',
#   'f18',
#   'b9',
#   'b37',
#   'f18',
#   'b8',
#   's18',
#   's39',
#   'b19',
#   'b28',
#   'f29',
#   'b37',
#   's28',
#   'b19',
#   's29',
#   'b28',
#   'b28',
#   'b28',
#   'f29',
#   'b28',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'b2',
#   'b28',
#   'f18',
#   'b29',
#   'b38',
#   's38',
#   'b37',
#   'b37',
#   'f18',
#   'f19',
#   'b38',
#   'b18',
#   'f19',
#   'b28',
#   'b27',
#   'b28',
#   'f17',
#   'b18',
#   'f19',
#   'b28',
#   'b28',
#   'b39',
#   'b29',
#   'f38',
#   'f18',
#   'f17',
#   'b18',
#   'b19',
#   'b27',
#   'b38',
#   'b28',
#   'b19',
#   'b18',
#   'f18',
#   'b29',
#   'b27',
#   'b19',
#   'b18',
#   'b38',
#   'b27',
#   'f18',
#   'b18',
#   'b18',
#   'b38',
#   'b;27',
#   'b;27',
#   's38',
#   'b29',
#   'b19',
#   'f39',
#   's38',
#   's28',
#   's28',
#   's37',
#   's28',
#   'f28',
#   's29',
#   'b37',
#   'f28',
#   'b28',
#   's37',
#   's38',
#   'b38',
#   's37',
#   's28',
#   'b28',
#   'b18',
#   's37',
#   'b28',
#   'b37',
#   'b28',
#   'b27',
#   'b28',
#   'b27',
#   's28',
#   'b28',
#   'b28',
#   'b17',
#   'b28',
#   'f38',
#   'b28',
#   'b;27',
#   's29',
#   'b18',
#   'b29',
#   'b29',
#   'b37',
#   's28',
#   'b18',
#   'b28',
#   'b28',
#   's37',
#   's39',
#   's27',
#   'b38',
#   'b28',
#   'b28',
#   'f38',
#   'b27',
#   'f18',
#   's18',
#   'b29',
#   'f28',
#   's38',
#   'b19',
#   'b28',
#   'b28',
#   'f28',
#   'b28',
#   'f28',
#   'b28',
#   'b28',
#   'b18',
#   'b29',
#   'b29',
#   'b28',
#   'f17',
#   's29',
#   'b37',
#   's29',
#   's39',
#   'b39',
#   'f17',
#   'b27',
#   'b19',
#   'b29',
#   'b27',
#   'b29',
#   'b29',
#   's29',
#   'b39',
#   'b28',
#   'b29',
#   's29',
#   'b28',
#   'b37',
#   'f39',
#   'b29',
#   'b29',
#   'b28',
#   'b37',
#   'b37',
#   'f28',
#   'b19',
#   'b19',
#   'b38',
#   'b27',
#   'b37',
#   'b37',
#   'b37',
#   'b28',
#   'b28',
#   'b38',
#   'b28',
#   'f29',
#   'b29',
#   'b28',
#   'b38',
#   'b38',
#   'b39',
#   'b29',
#   's29',
#   'b37',
#   'b38',
#   'f39',
#   'f18',
#   's39',
#   's',
#   'f19',
#   'b28',
#   'f28',
#   'b28',
#   'f17',
#   'b28',
#   'b38',
#   'b18',
#   'b38',
#   'f29',
#   'b28',
#   'b27',
#   'b28',
#   'b28',
#   'b38',
#   'b28',
#   'b39',
#   'b39',
#   'b28',
#   'b19',
#   'b18',
#   'f28',
#   'b28',
#   'b28',
#   'b29',
#   'b28',
#   'b27',
#   'b17',
#   's28',
#   'f28',
#   'b28',
#   'f28',
#   'b27',
#   'b29',
#   'b28',
#   'b18',
#   'b28',
#   's28',
#   's19',
#   's28',
#   'b28',
#   'b19',
#   'b19',
#   'b19',
#   's28',
#   'b27',
#   'b27',
#   'b28',
#   'f17',
#   'b29',
#   'b37',
#   's38',
#   'b27',
#   's28',
#   'f19',
#   'b27',
#   'b19',
#   'f29',
#   'b27',
#   'b29',
#   'b19',
#   'f28',
#   'f19',
#   's28',
#   'b29',
#   's28',
#   'f28',
#   'f28',
#   'b27',
#   'b18',
#   'b28',
#   'f28',
#   'f28',
#   'f18',
#   'r29',
#   'b28'],
#  '5': ['b18',
#   'b28',
#   'f38',
#   'f28',
#   'f18',
#   'f28',
#   'f28',
#   'b9',
#   'f8',
#   'b9',
#   'b18',
#   's28',
#   's28',
#   'b28',
#   'b18',
#   'f1',
#   'b2',
#   'b2',
#   'f1',
#   'b2',
#   'f27',
#   'b28',
#   'f29',
#   'f17',
#   'b18',
#   'b27',
#   'f17',
#   'b29',
#   'f29',
#   's38',
#   'b19',
#   'f38',
#   'f37',
#   'b18',
#   'b29',
#   'f18',
#   'b18',
#   'b38',
#   'b18',
#   'b39',
#   'b28',
#   'b28',
#   'b27',
#   'b28',
#   's18',
#   'b18',
#   'b28',
#   'f38',
#   'b+28',
#   'b27',
#   'f29',
#   'f29',
#   'b27',
#   'b27',
#   'f29',
#   'b29',
#   'f29',
#   'f28',
#   'b18',
#   's29',
#   'f29',
#   'b28',
#   'b18',
#   'f18',
#   'b27',
#   'b18',
#   'b19',
#   'b;27',
#   'b39',
#   'f19',
#   'b29',
#   'f27',
#   'b29',
#   'f27',
#   'f17',
#   'b19',
#   'b28',
#   'f19',
#   'f37',
#   'b28',
#   'b28',
#   'f27',
#   'f39',
#   'b28',
#   'f39',
#   'f19',
#   'f29',
#   'b18',
#   'f28',
#   'b28',
#   'b28',
#   'b38',
#   'b28',
#   'f28',
#   'b28',
#   'f29',
#   'b28',
#   'b28',
#   'f29',
#   'f39',
#   'b27',
#   'b38',
#   'b28',
#   'f19',
#   'f28',
#   'b19',
#   'f38',
#   'f39',
#   'f29',
#   'f19',
#   'b29',
#   'f38',
#   'b18',
#   'f38',
#   'b18',
#   'b17',
#   'f18',
#   'b28',
#   'b28',
#   'f19',
#   'b28',
#   'f29',
#   'b17',
#   'b27',
#   's29',
#   'f29',
#   'b29',
#   's28',
#   'f27',
#   'f39',
#   'f29',
#   'b18',
#   'b28',
#   'f28',
#   'b27',
#   'b18',
#   'f29',
#   'b28',
#   'f18',
#   'f28',
#   'b28',
#   'f18',
#   'b18',
#   'f18',
#   'b27',
#   'f28',
#   'f28',
#   'f18',
#   'f18',
#   'b28',
#   'f27',
#   'f18',
#   'f17',
#   'b28',
#   'b29',
#   'f38',
#   'f28',
#   'b28',
#   'b18',
#   's38',
#   'b28',
#   'b19',
#   'f37',
#   'f17',
#   'f37',
#   'f27',
#   'f28',
#   'b18',
#   'b;17',
#   'f28',
#   's+19',
#   's38',
#   'b28',
#   'b28',
#   'f28',
#   'b28',
#   's28',
#   'f27',
#   'f18',
#   'b18',
#   'r29',
#   'b18'],
#  '6': ['b28',
#   'b17',
#   'b28',
#   'b18',
#   'b19',
#   'b8',
#   'b28',
#   'b28',
#   'b27',
#   'f28',
#   'f27',
#   'b28',
#   'b19',
#   'b19',
#   'b29',
#   'b18',
#   'b2',
#   'b2',
#   'b2',
#   'f1',
#   'b2',
#   'b1',
#   'b1',
#   'b1',
#   'b1',
#   'b2',
#   'b28',
#   'b19',
#   'b19',
#   'b27',
#   'b29',
#   'b27',
#   'f19',
#   'b18',
#   'b19',
#   'b18',
#   'b19',
#   'b18',
#   'b27',
#   'b19',
#   'f29',
#   'b18',
#   'b19',
#   'b27',
#   'b28',
#   'b27',
#   'b27',
#   'b18',
#   's28',
#   'f27',
#   'b37',
#   'b18',
#   'b18',
#   'b28',
#   'f29',
#   'b28',
#   'f28',
#   'b29',
#   'b28',
#   'b28',
#   'f18',
#   'f28',
#   'f18',
#   'f28',
#   'f19',
#   'b29',
#   'f17',
#   'b18',
#   'b28',
#   'b;28',
#   'b28',
#   'b18',
#   'b19',
#   'b19',
#   'b28',
#   'b19',
#   'f18',
#   's17',
#   'b28',
#   'b19',
#   'b18',
#   'b18',
#   'b38',
#   'b18',
#   'b28',
#   'b27',
#   'b19',
#   'b17',
#   'b18',
#   'b27',
#   'b19',
#   'b28',
#   'b28',
#   'b28',
#   'b17',
#   'b29',
#   'f18',
#   'b18',
#   'b28',
#   'b28',
#   'b18',
#   'b+18',
#   'f18',
#   'b17',
#   'b19',
#   'b29',
#   'f28',
#   'f28',
#   'f28',
#   'b19',
#   'f29',
#   'f29',
#   'f27',
#   'f19',
#   'b27',
#   'b18',
#   'b17',
#   'f28',
#   'b29',
#   'b19',
#   'b19',
#   'f18',
#   'b19',
#   's27',
#   'b19',
#   'b39',
#   'b18',
#   'f27',
#   'f28',
#   'b29',
#   'f;17',
#   'f18',
#   'b18',
#   'b19',
#   'f28',
#   'b28',
#   'b28',
#   'b29',
#   'b18',
#   'b18',
#   'f18',
#   'b28',
#   'b28',
#   'b28',
#   's28',
#   'b27',
#   'b17',
#   'b19',
#   'b28',
#   's27',
#   'f17',
#   's29',
#   'f39',
#   'f17',
#   'b38',
#   'b27',
#   'b19',
#   'b39',
#   'f29',
#   'b19',
#   'b38',
#   'b19',
#   'f19',
#   'f29',
#   'f19',
#   'f27',
#   'f19',
#   's27',
#   'b29',
#   'b28',
#   'f17',
#   'b37',
#   'b19',
#   'f38',
#   'b18',
#   'f28',
#   'b19',
#   'b29',
#   'b28',
#   'b29',
#   'b28',
#   'b38',
#   'b29',
#   'b19',
#   'b18',
#   'f27',
#   'b19',
#   'b19',
#   'b19',
#   'b28',
#   'b27',
#   'b18',
#   'b28',
#   'b18',
#   'b17',
#   'b28',
#   'b27',
#   'b18',
#   'b18',
#   'b18',
#   'b18',
#   'b28',
#   'b28',
#   'b28',
#   's28',
#   'b38',
#   'b27',
#   'b18',
#   'b18',
#   'b29',
#   'f29',
#   'b28',
#   's29',
#   's29',
#   's29',
#   'f29',
#   'f29',
#   'b29',
#   'b19',
#   's29',
#   'f29',
#   'f17',
#   'b18',
#   'b18',
#   'f28',
#   'b17',
#   'f38',
#   'f28',
#   'b28',
#   'b29',
#   'b27',
#   'b28',
#   'b28',
#   's28',
#   's29',
#   'f17',
#   's18',
#   's39',
#   'b19',
#   'r28',
#   'b19',
#   'b17',
#   'b27',
#   'b19',
#   'b28',
#   'f18',
#   'b28',
#   'b28',
#   'b27',
#   'b28',
#   'b27',
#   'b18',
#   's28',
#   'f27',
#   's28',
#   's19',
#   's28',
#   'b28',
#   'b19',
#   's28',
#   'b28',
#   'b18',
#   'b19',
#   'b38',
#   'b28',
#   'f18',
#   's29',
#   'b29',
#   'f+29',
#   'f17',
#   'b19',
#   'b28',
#   'b28',
#   'b27',
#   'f28',
#   'f29'],
#  'b': ['f+', 'f', 'b', 'f', 'f+', 'v1'],
#  'h-3': ['b2'],
#  'c5': ['f8', 'b28', 'b28', 'b28', 's', 'b28', 'b28', 'b28'],
#  'c4': ['b18', 'f28', 'b19', 'b29', 's39', 'b29', 'b28', 'f28'],
#  'f-3': ['b2'],
#  'k1': ['f3'],
#  'f1-': ['f1'],
#  'c6': ['b18',
#   'b28',
#   'b29',
#   's37',
#   's29',
#   's28',
#   'b19',
#   'f29',
#   'b29',
#   'b28',
#   'b28',
#   'b17'],
#  'y+2': ['b2'],
#  'z2': ['v2', 'l', 'v3'],
#  'f;3': ['s3'],
#  's;3': ['b+1'],
#  'o1': ['f3', 'f3'],
#  's+3': ['b3', 'b1'],
#  'z3': ['b1', 'b1'],
#  'o2': ['b2'],
#  'v3': ['b1', 'm'],
#  '4+': ['s17', 's', 's27'],
#  'b;-3': ['b3'],
#  'b-1': ['f3'],
#  'z1': ['f1'],
#  'cc5': ['f39'],
#  'y3': ['b1', 'b+3', 'b1', 's-1'],
#  'm+2': ['m2'],
#  'o=3': ['s1'],
#  'v1': ['f3', 'f3', 'f3'],
#  '5+': ['b37'],
#  'i=1': ['j3'],
#  'i=2': ['f+1'],
#  'h=3': ['f1'],
#  'r+3': ['b3'],
#  'r;1': ['f-3'],
#  'i3': ['b3'],
#  'b+1': ['f1'],
#  'X': ['4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '6',
#   'c6',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   'c6',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   'c4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '5',
#   '6',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '5',
#   '5',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   'c4',
#   '4',
#   '6',
#   '6',
#   '5',
#   '4',
#   '6',
#   '5',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   'c6',
#   '4',
#   '6',
#   'c4',
#   '5',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   'c4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   'c4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6']}

# %%
all_dict_win2 = {}
all_dict_lost2 = {}
for k, v in all_dict_win.copy().items():
    v1 = [transform(i) for i in v if transform(i) in all_shots]
    all_dict_win2[k] = v1

for k, v in all_dict_lost.copy().items():
    v1 = [transform(i) for i in v if transform(i) in all_shots]
    all_dict_lost2[k] = v1

# %%
all_dict_win2
# Out:
# {'b28': ['b2',
#   'f3',
#   'z3',
#   'z3',
#   'f2',
#   'f3',
#   'f1',
#   'f3',
#   'f2',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'b2',
#   'f2',
#   'f1',
#   'f+3',
#   'f1',
#   'f1',
#   'f+1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'z3',
#   'f1',
#   'f1',
#   'f3',
#   'f+1',
#   'f+1',
#   'f+3',
#   'f2',
#   'f2',
#   'f3',
#   'f3',
#   'v1',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f1',
#   'f1',
#   'f+1',
#   'f3',
#   'z1',
#   'f1',
#   'f+3',
#   'f1',
#   'f+1',
#   'f1',
#   'f1',
#   'f+1',
#   'f3',
#   'f+3',
#   'f+1',
#   'f1',
#   'f3',
#   'v3',
#   'f+3',
#   'f+3',
#   'f+3',
#   'f2',
#   'f+3',
#   'f1',
#   'f+3',
#   'b3',
#   'f+1',
#   'f2',
#   'f1',
#   'f+1',
#   'f+1',
#   'f+3',
#   'f3',
#   'f3',
#   'f+3',
#   'f2',
#   'f3',
#   'f1',
#   'f+1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f+3',
#   'f+1',
#   'f1',
#   'f3',
#   'f+3',
#   'f+3',
#   'f3',
#   'v3',
#   'f3',
#   'f2'],
#  's3': ['f+1',
#   'f1',
#   'f2',
#   'b1',
#   'b3',
#   'f3',
#   'b3',
#   'f+1',
#   'b1',
#   'f3',
#   'b1',
#   'z3',
#   'b2',
#   'b3',
#   'f1',
#   'b3',
#   'v3',
#   'z3',
#   'b3',
#   'v1',
#   'b1',
#   'f1',
#   'z3',
#   'f3',
#   'b3',
#   'f+1',
#   'f3',
#   'z3',
#   'f3',
#   'f1',
#   'f+1',
#   'f3',
#   'f+3',
#   'b3',
#   'b2',
#   'b1',
#   'f1',
#   'b3',
#   'b3',
#   'f3',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f3',
#   'b2',
#   'f2',
#   'f3',
#   'f3',
#   'f3',
#   'f2',
#   'f+1',
#   'f1',
#   'b3',
#   'b1',
#   'z3',
#   'b3',
#   'z3',
#   'b1',
#   'b3',
#   'b3',
#   's1',
#   'f3',
#   'b3',
#   'f1',
#   'f3',
#   'b3'],
#  'f37': ['s1',
#   'z1',
#   'b1',
#   'f2',
#   'z1',
#   'b1',
#   'f3',
#   'b3',
#   'f1',
#   'f+1',
#   'b3',
#   'f1',
#   'f3',
#   'b3',
#   'f1',
#   'b2',
#   'b3',
#   'b3',
#   's1',
#   'f+1',
#   'f1',
#   'f1',
#   's1',
#   'f+1',
#   'f+1',
#   'f1',
#   'b1',
#   'b3',
#   'f3',
#   'b3',
#   'b2',
#   'f3',
#   'f+1',
#   'b1',
#   'f+1',
#   's1',
#   'b1',
#   'b2',
#   'f+1',
#   'f1',
#   'z3',
#   'b3',
#   'f1',
#   'z1',
#   'f1',
#   'b2',
#   'f1',
#   'b1',
#   'f3',
#   'f3',
#   's2'],
#  'b27': ['f+3',
#   'b2',
#   'z1',
#   'f3',
#   'z3',
#   'z3',
#   'z3',
#   'f2',
#   'b2',
#   'f+1',
#   'f+1',
#   'f1',
#   'f+3',
#   'v3',
#   'z3',
#   'f3',
#   'f+1',
#   'v1',
#   'v1',
#   'b3',
#   'f3',
#   'b2',
#   'f+1',
#   'v1',
#   'f3',
#   'f+1',
#   'v3',
#   'f+1',
#   'f2',
#   'f3',
#   'z3',
#   'f3',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f3',
#   'z3',
#   'f+3',
#   'f1',
#   'f3',
#   'f3',
#   'f+3',
#   'f1',
#   'f+3',
#   'f+3',
#   'f+1',
#   'f3',
#   'f+1',
#   'z3',
#   'f+3',
#   'v3',
#   'f+3',
#   'b3',
#   'v1',
#   'f+1',
#   'f+1',
#   'f+3',
#   'f2',
#   'z1',
#   'f+1',
#   'f+1',
#   'f3',
#   'f+3',
#   'f+3',
#   'f+1',
#   'f+1',
#   'f1',
#   'f+3',
#   'f3',
#   'f+1',
#   'f+1',
#   'f1',
#   'f+1',
#   'f1',
#   'v1',
#   'f+3',
#   'v1',
#   'f3',
#   'v1',
#   'z1',
#   'f3',
#   'f+3',
#   'f+1',
#   'f+1'],
#  'f3': ['z1',
#   'b2',
#   'b3',
#   'z1',
#   'f3',
#   's3',
#   'b2',
#   'z1',
#   'b2',
#   'b1',
#   'b1',
#   'f3',
#   'b2',
#   's2',
#   'f1',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'z1',
#   'b3',
#   'f3',
#   'f2',
#   'f3',
#   'b3',
#   'b3',
#   'b2',
#   'f+1',
#   'z1',
#   'b3',
#   's3',
#   'f+1',
#   'b1',
#   'f2',
#   'b3',
#   'f2',
#   'b2',
#   'b3',
#   'b1',
#   'f3',
#   's2',
#   'b2',
#   'b2',
#   's1',
#   'b2',
#   'b1',
#   'b3',
#   's3',
#   's1',
#   'b3',
#   'b2',
#   'b3',
#   's1',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   's3',
#   'b2',
#   'b2',
#   's2',
#   'b3',
#   'b3',
#   's3',
#   'b3',
#   's1',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   's1',
#   'f3',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   'z1',
#   'b1',
#   'b2',
#   'b3',
#   's1',
#   'b3',
#   'b2',
#   'b1',
#   's3',
#   'b1',
#   'b1',
#   'z1',
#   'b3',
#   'b3',
#   'f1',
#   'b3',
#   's1',
#   'f3',
#   'b1',
#   'z3',
#   'f+3',
#   'b1',
#   's3',
#   'b3',
#   'f1',
#   'b2',
#   'b3',
#   'z1',
#   'b2',
#   'b3',
#   'b2',
#   'b1',
#   'f1',
#   'z1',
#   'b3',
#   'b2',
#   'b1',
#   'b3',
#   'b2',
#   'b1',
#   'f3',
#   'b2',
#   'b1',
#   'b2',
#   'b2',
#   'b1',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'b3',
#   'b1',
#   'b1',
#   'b1',
#   's1',
#   'b3',
#   'f3',
#   'f2',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   's1',
#   'b2',
#   'b2',
#   'b2',
#   'b2',
#   'b2',
#   'f2',
#   'f3',
#   's2',
#   'b3',
#   'b3',
#   'f1',
#   'f3',
#   'f3',
#   'f3',
#   'b1',
#   's3',
#   'b3',
#   's3',
#   'f2',
#   'b1',
#   'b3',
#   'f+1',
#   'b1',
#   'f3',
#   'b2',
#   'b3',
#   'b1',
#   'f3',
#   'b3',
#   'z1',
#   'f+1',
#   'f2',
#   'f3',
#   'b2',
#   'z3',
#   's1',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b3',
#   'b3',
#   's1',
#   'b1',
#   'f3',
#   'b3',
#   'b3',
#   'b3',
#   'f1',
#   'f3',
#   'f3',
#   'z1',
#   'b2',
#   'v1',
#   'b2',
#   'f1',
#   'b2',
#   'b3',
#   'b2',
#   's2',
#   'b1',
#   's1',
#   'b2',
#   'b3',
#   'b3',
#   'b3',
#   'b1',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   's3',
#   'f1',
#   'b2',
#   'b3',
#   'b2',
#   's3',
#   'b2',
#   'f3',
#   'f1',
#   'b3',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'b1',
#   'b',
#   'f1',
#   'b2',
#   'b3',
#   'f3',
#   'b1',
#   'b3',
#   'b1',
#   'b2',
#   's3',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'b1',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'b1',
#   's1',
#   'b1',
#   's1',
#   's1',
#   'b1',
#   'b2',
#   's3',
#   'b3',
#   'b2',
#   'b1',
#   'b1',
#   's1',
#   'b3',
#   'b2',
#   'b3',
#   's1',
#   'b3',
#   'b3',
#   'f3',
#   's1',
#   'b3',
#   'b2',
#   'b1',
#   'b1',
#   'f3',
#   'b2',
#   'b3',
#   's1',
#   'z1',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   'f3',
#   'b3',
#   's1',
#   's1',
#   'b2',
#   'b3',
#   'b1',
#   's2',
#   'f1',
#   'b2',
#   'b1',
#   's3',
#   'b3',
#   'b1',
#   'b1',
#   'b2',
#   'b3',
#   'b1',
#   'b3',
#   's2',
#   'b2',
#   'f2',
#   'b2',
#   'b2',
#   'b3',
#   'f2',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'f+1',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'f+3',
#   'b3',
#   'b1',
#   'b3',
#   'b2',
#   's2',
#   'b3',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'f1',
#   'b2',
#   'b2',
#   'b1',
#   'b1',
#   'b3',
#   's3',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   'b2',
#   's3',
#   's1',
#   'b2',
#   'b1',
#   's1',
#   'b3',
#   'b3',
#   's2',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   's1',
#   'b3',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'b1',
#   's2',
#   's1',
#   'b1',
#   'b3',
#   's3',
#   'b3',
#   'f+1',
#   'b3',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   'b2',
#   'b1',
#   'b1',
#   'b2',
#   'f3',
#   'b2',
#   'b3',
#   's3',
#   'b2',
#   'z1',
#   's1',
#   'b3',
#   'b3',
#   'f2',
#   's1',
#   's3',
#   'b1',
#   'f1',
#   'f3',
#   'f1',
#   'b3',
#   'b3',
#   'b1',
#   's2',
#   'b2',
#   'b2',
#   'b3',
#   's2',
#   'f2',
#   'b2',
#   'b2',
#   'b1',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'f2',
#   's2',
#   'b1',
#   'b1',
#   'f2',
#   'b3',
#   'b1',
#   'b2',
#   'f2',
#   'f1',
#   'b3',
#   's2',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b3',
#   'b2',
#   's3',
#   's1',
#   'b3',
#   's1',
#   's2',
#   'b3',
#   'b3',
#   'b2',
#   'f1',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   'f2',
#   'b3',
#   'b3',
#   'f3',
#   's1',
#   'b1',
#   'b2',
#   'b3',
#   'b3',
#   'b2',
#   's2',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   's3',
#   'b1',
#   'b1',
#   'b1',
#   's3',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b3',
#   'b1',
#   's3',
#   'b2',
#   'b1',
#   'b3',
#   'b1',
#   'f1',
#   'f1',
#   's3',
#   'b1',
#   'b1',
#   'b1',
#   'b2',
#   'b3',
#   'b3',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'b1',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b2',
#   'b2',
#   'b1',
#   'b1',
#   'b3',
#   'b1',
#   'b1',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   's3',
#   'f1',
#   'b1',
#   's1',
#   'f1',
#   'b1',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'f1',
#   's3',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'f3',
#   'b2',
#   'f1',
#   'b2',
#   'b1',
#   'b2',
#   'b3',
#   'b3',
#   'b2',
#   'b1',
#   'b3',
#   'b3',
#   'b1',
#   'f2',
#   'b1',
#   'b1',
#   'b1',
#   's1',
#   'b2',
#   'f3',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   's2',
#   'b2',
#   'b2',
#   'b2',
#   's2',
#   'b2',
#   'b2',
#   's3',
#   'b1',
#   'b3',
#   's1',
#   's3',
#   's2',
#   'b2',
#   'b1',
#   's2',
#   'b3',
#   'b2',
#   's3',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   's3',
#   's3',
#   'b2',
#   's3',
#   'b3',
#   'b3',
#   's1',
#   's1',
#   'b1',
#   's1',
#   's2',
#   'b1',
#   's1',
#   's2',
#   's1',
#   'b3',
#   'b2',
#   's3',
#   's1',
#   'b1',
#   's2',
#   'b3',
#   'f3',
#   'f1',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'f1',
#   'f3',
#   'b2',
#   'b1',
#   's3',
#   's3',
#   'f2',
#   'b2',
#   'b3',
#   'f3',
#   'f1',
#   'b1',
#   'b1',
#   'b2',
#   'f2',
#   's1',
#   'b2',
#   'b3',
#   'b2',
#   'f1',
#   's1',
#   's3',
#   'b1',
#   'b1',
#   'b2',
#   'b3',
#   's3',
#   'b3',
#   'f3',
#   'b1',
#   's3',
#   'f1',
#   'b2',
#   'b3',
#   'f3',
#   'b1',
#   'b1',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   's1',
#   'b1',
#   'f2',
#   'b3',
#   's2',
#   'b2',
#   'b3',
#   'f3',
#   's2',
#   'b3',
#   's2',
#   's2',
#   'b3',
#   's1',
#   'f1',
#   'b2',
#   'b3',
#   'b2',
#   's1',
#   'b2',
#   'b1',
#   'f3',
#   's3',
#   's1',
#   'b3',
#   'z3',
#   's3',
#   'b2',
#   'z3',
#   'b1',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'b3',
#   'b2',
#   'b1',
#   'f2',
#   'b3',
#   'b2',
#   'b1',
#   's3',
#   'b2',
#   'b2',
#   'b2',
#   'b1',
#   'b3',
#   's1',
#   'b1',
#   's3',
#   'f3',
#   's2',
#   'b2',
#   'f2',
#   'b2',
#   'b2',
#   's2',
#   'b3',
#   'b3',
#   'b3',
#   's3',
#   'b2',
#   'b2',
#   's1',
#   'b2',
#   'b2',
#   'b2',
#   's1',
#   'b2',
#   's3',
#   'f1',
#   's2',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   's1',
#   'f2'],
#  'm3': ['z3'],
#  'b29': ['f1',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'b1',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'b3',
#   'f1',
#   'f2',
#   'f3',
#   'f2',
#   'b1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f2',
#   'f1'],
#  's2': ['f3',
#   'f3',
#   'f+3',
#   'f+1',
#   'v3',
#   'z3',
#   'f+1',
#   'f1',
#   'f3',
#   'z3',
#   'f+3',
#   'f+3',
#   'f1',
#   'z3',
#   'f1',
#   'f+3',
#   'z3',
#   'b3',
#   'f+3',
#   'v1',
#   'f1',
#   'v3',
#   'f+1',
#   'z3',
#   'z3',
#   'f+3',
#   'v3',
#   's1',
#   's1',
#   'z3',
#   'b3',
#   'f3',
#   'f+1',
#   'f1',
#   'f+1',
#   'f1',
#   'f+1',
#   'f3',
#   'f+3',
#   'b3',
#   'f+3',
#   'b3',
#   'f3',
#   'f+1',
#   'f3',
#   'f+3',
#   'f1',
#   'b2',
#   's2',
#   'f1',
#   'f2',
#   'v1',
#   'f+1',
#   'f+1',
#   'b2',
#   'b3',
#   'f1',
#   'f3',
#   'f+3'],
#  'f2': ['b2',
#   'f1',
#   'f1',
#   'v1',
#   'b3',
#   'b2',
#   'f+1',
#   'b2',
#   'f1',
#   'f2',
#   'f3',
#   'b2',
#   'b3',
#   'f1',
#   'b2',
#   'f3',
#   'b1',
#   'f+3',
#   'f+1',
#   'f+1',
#   'f1',
#   'z1',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'b2',
#   'v1',
#   'f1',
#   'f3',
#   'f3',
#   'f3',
#   'b3',
#   'z1',
#   'f1',
#   'f1',
#   'z1',
#   'f2',
#   'f1',
#   'f1',
#   'z1',
#   'f2',
#   'b2',
#   'f+3',
#   'v1',
#   'f2',
#   'f1',
#   'b2',
#   'f1',
#   'f+3',
#   'z1',
#   'b3',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f2',
#   's2',
#   'f2',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'b2',
#   'f2',
#   'z1',
#   'f3',
#   'v1',
#   'f1',
#   'f1',
#   'f+1',
#   'f3',
#   'f1',
#   'v1',
#   'f2',
#   'f3',
#   'f3',
#   'v1',
#   'f+1',
#   'f1',
#   'f2',
#   'b3',
#   's2',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f3',
#   'b3',
#   'f1',
#   'f2',
#   'b2',
#   'b2',
#   'f1',
#   'f1',
#   'f1',
#   'b2',
#   'f',
#   'b2',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f2',
#   'b1',
#   'f3',
#   'b1',
#   'b1',
#   'b1',
#   'f1',
#   'b3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'b1',
#   'b1',
#   'f1',
#   'b2',
#   'f+1',
#   'f3',
#   'f3',
#   'f2',
#   'f2',
#   'f3',
#   'f1',
#   'f+1',
#   'b2',
#   'b2',
#   'b3',
#   'b2',
#   'f3',
#   'f3',
#   'f3',
#   'v1',
#   'f+3',
#   'f1',
#   'b2',
#   'f2',
#   'f1',
#   'f1',
#   'b1',
#   'f3',
#   'b1',
#   'b3',
#   'b1',
#   'b2',
#   'f1',
#   'b2',
#   'f3',
#   'f2',
#   'f1',
#   'b2',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'b3',
#   'f3',
#   'f1',
#   'f3',
#   's1',
#   'b2',
#   'b3',
#   'b2',
#   'f+1',
#   'f+1',
#   'f1',
#   'b1',
#   'b1',
#   'b2',
#   'f2',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'z3',
#   'f1',
#   'f3',
#   'b2',
#   's1',
#   'f1',
#   'f2',
#   'b1',
#   'f1',
#   'f2',
#   'f2',
#   'f3',
#   'f+1',
#   'f1',
#   'b2',
#   'b2',
#   'f1',
#   'f2',
#   'f+1',
#   'b1',
#   'f3',
#   'b2',
#   'f2',
#   'f1',
#   'b2',
#   'f1',
#   'f2',
#   'f1',
#   'b3',
#   'f3',
#   'f3',
#   'f2',
#   'b2',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'b1',
#   'f2',
#   'b2',
#   'f1',
#   'f1',
#   'f2',
#   'b2',
#   'f1',
#   'b2',
#   'f2',
#   'b1',
#   'f1',
#   'f1',
#   'b2',
#   'b2',
#   'b2',
#   'f3',
#   'f1',
#   'b1',
#   'f2',
#   'b3',
#   'f+1',
#   'b3',
#   'b1',
#   'f2',
#   'f1',
#   'f1',
#   'b1',
#   'f2',
#   'f2',
#   'b2',
#   'b2',
#   'b1',
#   'f3',
#   'f1',
#   'f2',
#   'b1',
#   'b1',
#   'f3',
#   'f3',
#   'f+1',
#   'f1',
#   'f2',
#   'f3',
#   'b2',
#   'b1',
#   'f1'],
#  'b2': ['f1',
#   'b2',
#   'f2',
#   'b2',
#   'f2',
#   'f1',
#   'b2',
#   'f1',
#   'f+1',
#   'f3',
#   'f+1',
#   'z1',
#   'f1',
#   'f1',
#   'f3',
#   'b2',
#   'f3',
#   'f1',
#   'f+3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f2',
#   'f+1',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'b2',
#   'f3',
#   'f1',
#   'b1',
#   'f1',
#   'v3',
#   'f3',
#   'b1',
#   'f2',
#   'b2',
#   'f3',
#   'f3',
#   'z3',
#   'f3',
#   'f1',
#   'f2',
#   'f2',
#   'b1',
#   'f1',
#   'b3',
#   'f1',
#   'v1',
#   'f2',
#   'f+3',
#   'b2',
#   'b3',
#   'f2',
#   'f+3',
#   'f1',
#   'f2',
#   'b1',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'b3',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'v1',
#   'f3',
#   'z1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f2',
#   'f1',
#   'z3',
#   'f+1',
#   'v3',
#   'f+3',
#   'f1',
#   'f1',
#   'f2',
#   'b1',
#   'f1',
#   'f3',
#   'f1',
#   'f+1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'b2',
#   'f1',
#   'f3',
#   'f+3',
#   'f1',
#   'f3',
#   'b2',
#   'v3',
#   'f2',
#   'v1',
#   'f2',
#   'f1',
#   'f+3',
#   'f+1',
#   'f3',
#   'f2',
#   'b2',
#   'b2',
#   'f1',
#   'f+1',
#   'z1',
#   'z1',
#   'f1',
#   'f3',
#   'f+3',
#   'f3',
#   'f1',
#   'b2',
#   'f2',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'f2',
#   'f2',
#   'z3',
#   'f+3',
#   'f1',
#   'v3',
#   'f+1',
#   'z3',
#   'f2',
#   'f3',
#   'f+1',
#   'f+3',
#   'z3',
#   'f2',
#   'f2',
#   'z1',
#   'v3',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'z1',
#   'f1',
#   'f2',
#   'f+1',
#   'f+3',
#   'b2',
#   'v3',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   'b3',
#   'b1',
#   'f2',
#   'b2',
#   'f1',
#   'b3',
#   's1',
#   'f1',
#   'b3',
#   'f1',
#   'b1',
#   'b3',
#   'f2',
#   'f+3',
#   'f2',
#   'f3',
#   'f+1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f+3',
#   'b3',
#   'b2',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'b2',
#   'f1',
#   's3',
#   'f3',
#   'b3',
#   'f1',
#   's3',
#   'f2',
#   'f2',
#   'f+1',
#   'v3',
#   'f2',
#   'f3',
#   'b3',
#   'f+3',
#   'f1',
#   'b2',
#   'f3',
#   'f1',
#   'f3',
#   'b2',
#   'b3',
#   'b2',
#   'f3',
#   'f+3',
#   'b3',
#   'f1',
#   'b3',
#   'b2',
#   'b2',
#   'f1',
#   'f2',
#   's1',
#   'f1',
#   'f2',
#   'f3',
#   'b2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'b2',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'b2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'b3',
#   'b1',
#   'f3',
#   'b3',
#   'f+1',
#   'b3',
#   'b1',
#   'f2',
#   'f1',
#   'f3',
#   'b3',
#   'f+1',
#   'f+3',
#   'f1',
#   'b1',
#   'f+1',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f+1',
#   'f3',
#   'f+3',
#   'f1',
#   'f3',
#   'f+1',
#   'f3',
#   'f1',
#   'b2',
#   'f1',
#   'f1',
#   'f1',
#   'f+3',
#   'v1',
#   'v1',
#   'f1',
#   'f1',
#   'f3',
#   'b2',
#   'v1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   's1',
#   'f1',
#   'b3',
#   'f3',
#   'b3',
#   'f3',
#   'f2',
#   'f+3',
#   'b3',
#   'f3',
#   'v3',
#   'b2',
#   'b3',
#   'f+1',
#   'b2',
#   'f2',
#   'b1',
#   'b3',
#   'f+1',
#   'f2',
#   'f+1',
#   'b3',
#   'f1',
#   'b2',
#   'f3',
#   'f2',
#   'f2',
#   'f2',
#   'f1',
#   'f+3',
#   'f1',
#   'f1',
#   's2',
#   'f1',
#   'f1',
#   'b1',
#   'b2',
#   'f1',
#   'b2',
#   'f+3',
#   'f+3',
#   'f1',
#   'f+3',
#   'f1',
#   'f1',
#   'f2',
#   'f+3',
#   'f3',
#   'f1',
#   'f3',
#   'z3',
#   'f1',
#   'b3',
#   'f+1',
#   'f1',
#   'f3',
#   'f+3',
#   's3',
#   'f3',
#   'b3',
#   'f1',
#   'f2',
#   's1',
#   'f3',
#   'f3',
#   'b3',
#   'f1',
#   'b1',
#   'b2',
#   'f1',
#   'f+3',
#   'f1',
#   'f2',
#   'f1',
#   'b1',
#   'b1',
#   'z1',
#   'z3',
#   'f1',
#   'f+1',
#   'f3',
#   'f1',
#   'f1',
#   'v1',
#   'f+3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'b2',
#   'f2',
#   'f3',
#   'b2',
#   'b2',
#   'v3',
#   'f3',
#   'f1',
#   'f1',
#   'f3'],
#  'b1': ['f1',
#   'v3',
#   'f3',
#   'f1',
#   'v3',
#   'f1',
#   'f2',
#   'v3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f',
#   'f2',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f2',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f+3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f2',
#   'f3',
#   'f3',
#   'f1',
#   'f2',
#   'v3',
#   'f2',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'v3',
#   'f1',
#   'v1',
#   'v1',
#   'f2',
#   'f1',
#   'f2',
#   'f3',
#   'f+1',
#   'f3',
#   'f1',
#   'f2',
#   'v1',
#   'f1',
#   'f3',
#   'f+3',
#   'f1',
#   'f1',
#   'f+1',
#   'v3',
#   'f1',
#   'f+1',
#   'f3',
#   'v1',
#   'v3',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f2',
#   'f2',
#   'f2',
#   'f1',
#   'f2',
#   'v3',
#   'f1',
#   'f1',
#   'f2',
#   'f+3',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'v3',
#   'f1',
#   'v3',
#   'r2',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f+3',
#   'v3',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'v1',
#   'f1',
#   'f3',
#   'f1',
#   'f+1',
#   'v1',
#   'f+1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'v1',
#   'f3',
#   'v3',
#   'f+1',
#   'f1',
#   'v3',
#   'f1',
#   'v3',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f2',
#   'v3',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'v3',
#   'f2',
#   'f+3',
#   'f1',
#   'v3',
#   'f1',
#   'v1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f2',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f3',
#   'f1',
#   'f+1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f+3',
#   'f1',
#   'f1',
#   'v3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f2',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f+3',
#   'f3',
#   'r2',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   'f1',
#   'f3',
#   'f+1',
#   'v3',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f3',
#   'f+3',
#   'f3',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f2',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f+1',
#   'v3',
#   'f1',
#   'f1',
#   'f+3',
#   'f3',
#   'f1',
#   'f1',
#   'f+3',
#   'f2',
#   'f1',
#   'f3',
#   'f+3',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'v3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f+3',
#   'f3',
#   'f1',
#   'f1',
#   'f+3',
#   'f1',
#   'f+3',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f+3',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1'],
#  'f238': ['f2'],
#  'f38': ['f3',
#   'f2',
#   'f2',
#   'f2',
#   'b2',
#   'b1',
#   's2',
#   'b1',
#   'b1',
#   'f3',
#   'b3',
#   'f3',
#   'f1',
#   'f3',
#   's1',
#   'b3',
#   'b3',
#   'f1',
#   's1',
#   'f2',
#   'f1',
#   'b1',
#   'b1',
#   'f3',
#   'b2',
#   's1',
#   'b1',
#   'b2',
#   'b2',
#   'b2',
#   'f1',
#   'f1',
#   'b2',
#   'b3',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'b3',
#   'f1',
#   'f1',
#   'f2',
#   'b1',
#   'b1',
#   's1',
#   'f+3',
#   'f+1',
#   'f3',
#   'f1',
#   's1',
#   'b1',
#   'b1',
#   'b3'],
#  'f28': ['f1',
#   'f3',
#   'f+3',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'f+3',
#   'f3',
#   'f1',
#   'f2',
#   'f3',
#   'v3',
#   'f1',
#   'f+1',
#   'f+1',
#   'f1',
#   'f2',
#   'f1',
#   'b3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f3',
#   'f+1',
#   'f3',
#   'f2',
#   'f1',
#   'f3',
#   'f2',
#   'f+1',
#   'f2',
#   'f+1',
#   'f3',
#   'f3',
#   'f2',
#   'f2',
#   'f+1',
#   'f2',
#   'f1',
#   'f2',
#   'f2',
#   'f+1',
#   'f2',
#   'b3',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   'f3',
#   'f1',
#   'f2',
#   'f+1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f+1',
#   'f1',
#   'f2',
#   'f3',
#   'f+1',
#   'f3',
#   'f1'],
#  'b3': ['f3',
#   'f1',
#   'z1',
#   'z3',
#   'z3',
#   'b3',
#   'b1',
#   'b3',
#   'b3',
#   'b2',
#   'f1',
#   'b3',
#   'b2',
#   'z3',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'z1',
#   'b3',
#   'f1',
#   'b3',
#   'b1',
#   'b2',
#   's3',
#   'f3',
#   'b1',
#   'f3',
#   'b1',
#   'f2',
#   'b1',
#   'b3',
#   'b2',
#   'b2',
#   'b1',
#   'b3',
#   'b3',
#   'b2',
#   'b1',
#   'z1',
#   's1',
#   'z1',
#   'f3',
#   'z3',
#   's1',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b2',
#   'f+1',
#   'b1',
#   'b2',
#   'b3',
#   'b2',
#   'f3',
#   'z3',
#   'f2',
#   'b1',
#   'b3',
#   'z3',
#   'b3',
#   'b3',
#   'z3',
#   'b1',
#   'b1',
#   'b1',
#   'v3',
#   'f3',
#   'b1',
#   'b3',
#   'f2',
#   'f3',
#   'b1',
#   'b2',
#   'z3',
#   'b1',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   's1',
#   'f1',
#   'f1',
#   'f3',
#   'b3',
#   'z3',
#   'z3',
#   'f2',
#   'z3',
#   'b1',
#   'b3',
#   'b2',
#   'f3',
#   's1',
#   'b1',
#   's3',
#   'z3',
#   'z3',
#   's1',
#   'b1',
#   'z3',
#   's3',
#   'z3',
#   'z3',
#   'b1',
#   'b3',
#   'b3',
#   'b1',
#   'b2',
#   'b1',
#   's1',
#   'f3',
#   'f1',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'b1',
#   'f1',
#   's1',
#   's1',
#   'f1',
#   'b3',
#   'b3',
#   's1',
#   'f3',
#   'b1',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'z1',
#   'b1',
#   'b2',
#   'b3',
#   'b3',
#   'f2',
#   'b1',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'z3',
#   'f1',
#   'z3',
#   's3',
#   'b1',
#   'b2',
#   'b3',
#   'b2',
#   'f1',
#   'z3',
#   'b3',
#   'f1',
#   's2',
#   's1',
#   'b3',
#   'b2',
#   'f+1',
#   's3',
#   'b2',
#   'b2',
#   's1',
#   'f1',
#   's1',
#   's3',
#   's1',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'f3',
#   'b2',
#   'b1',
#   'b1',
#   'b1',
#   'b3',
#   'b3',
#   'b1',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'z3',
#   's2',
#   'b1',
#   's1',
#   'b2',
#   'b3',
#   's1',
#   'z3',
#   'b3',
#   'b2',
#   'b1',
#   'f1',
#   'b1',
#   'b1',
#   'b1',
#   'b3',
#   'b1',
#   's1',
#   's2',
#   'b3',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b3',
#   's3',
#   'b1',
#   'b2',
#   'b3',
#   'b2',
#   'z3',
#   'b2',
#   'b1',
#   'f2',
#   'b1',
#   's3',
#   's2',
#   'b1',
#   's1',
#   'b3',
#   's1',
#   'b1',
#   'b3',
#   'b2',
#   'b1',
#   'b1',
#   'b2',
#   's1',
#   's1',
#   's1',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'f3',
#   'z3',
#   'b3',
#   'b1',
#   'b3',
#   's1'],
#  's37': ['f1', 'f1', 'z3', 'f+3', 'z1', 'f+3'],
#  'f1': ['f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f2',
#   'f3',
#   'v1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'r2',
#   'v1',
#   'f1',
#   'f1',
#   'f2',
#   'f2',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f2',
#   'f3',
#   'v1',
#   'v1',
#   'f1',
#   'f2',
#   'f2',
#   'v1',
#   'f1',
#   'f1',
#   'f2',
#   'v1',
#   'f2',
#   'f3',
#   'f1',
#   'v1',
#   'f2',
#   'v1',
#   'f3',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'r2',
#   'f2',
#   'f2',
#   'f2',
#   'f1',
#   'v1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   'f1',
#   'v1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f3',
#   'f3',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'v1',
#   'f+1',
#   'f1',
#   'f1',
#   'f1',
#   'f1'],
#  'b18': ['f3',
#   'f3',
#   'r2',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f+3',
#   'f3',
#   'f1',
#   'f1',
#   'f+3',
#   'f+3',
#   'f+1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f2'],
#  'f8': ['b', 'f1'],
#  'f27': ['f3',
#   'f2',
#   'f+1',
#   'f+1',
#   'b1',
#   'f1',
#   'f1',
#   'v1',
#   'f3',
#   'z1',
#   'f1',
#   'f3',
#   'f3',
#   'f3',
#   'b1',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f3',
#   'f3',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f1',
#   'f+3',
#   'f1',
#   'f+1',
#   'f+1',
#   'f+1',
#   'f3',
#   'f1',
#   'v3',
#   'f3',
#   'f+3',
#   'f3',
#   'f3',
#   'f1',
#   'f+3',
#   'f+1',
#   'f1',
#   'f3'],
#  'b8': ['b', 'b'],
#  'm2': ['f1'],
#  'b7': [],
#  's': ['b', 'z3'],
#  'f': ['s', 'v3', 'b', 'b', 'b', 'b'],
#  'b39': ['f3',
#   'b3',
#   'f3',
#   'b3',
#   'f3',
#   'b3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'b1',
#   'b1',
#   'b3',
#   'b1',
#   'b3',
#   'f3',
#   's3',
#   'f1',
#   'f1'],
#  's27': ['f+3',
#   'v3',
#   'z1',
#   'z1',
#   'f+1',
#   'f3',
#   'f1',
#   'f3',
#   'f+1',
#   'z3',
#   'f3',
#   'f+1',
#   'f+1',
#   'f+3',
#   's1',
#   'f+1'],
#  'f7': ['s'],
#  'b17': ['v3',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f2',
#   'v3',
#   'f1',
#   'f1',
#   'f+1',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f3',
#   'v3',
#   'f3',
#   'v3',
#   'f1',
#   'f+3',
#   'f+3',
#   'f+3',
#   'v3',
#   'f2'],
#  'f19': ['f1', 'f1', 'f1'],
#  's38': ['z1', 'f3', 'f3', 'b3', 'f3', 'b1', 'f3', 'f3', 'z3'],
#  'b37': ['f3',
#   'z1',
#   'b3',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f+1',
#   'b1',
#   'b3',
#   'f2',
#   'f3',
#   'b3',
#   'b3',
#   'f3',
#   'f+1',
#   'f3',
#   'f+1',
#   'f+3',
#   'z3',
#   's3',
#   'f3'],
#  's28': ['f+3',
#   'z3',
#   'f1',
#   'f+3',
#   'f+1',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f1',
#   'f+1',
#   'f+3',
#   'f+1',
#   'f3',
#   'f+1',
#   'f1',
#   'f+1',
#   'f+3',
#   'f+3',
#   'z3',
#   'f+3',
#   'z3',
#   'f3',
#   'f3',
#   'f+3'],
#  'b38': ['f2',
#   'b1',
#   'b1',
#   'b3',
#   'b3',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'b2',
#   'b3',
#   'b2',
#   'f1',
#   'b1',
#   'f1',
#   'f1',
#   'b2',
#   'b1',
#   'b2',
#   'f1',
#   'b1',
#   'b3',
#   'b1',
#   'b3',
#   'f2',
#   'f1',
#   'b3',
#   'f1',
#   'b3',
#   'b1',
#   'f1',
#   'b2',
#   'f1',
#   'f+1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   's3',
#   'f3'],
#  'f18': ['f1', 'f1', 'f1', 'f1', 'f1', 'f1', 'f2', 'f+3', 'f3', 'f3'],
#  'l2': [],
#  'b+3': ['s2', 's2', 's1', 'b3'],
#  'r2': ['f+1',
#   'v1',
#   'f2',
#   'f1',
#   'f+1',
#   'f+1',
#   'f+1',
#   'f+1',
#   'f1',
#   'z1',
#   'f+3'],
#  'f39': ['f2',
#   'f1',
#   'b1',
#   'f1',
#   'f1',
#   'f1',
#   'b1',
#   'b3',
#   'f2',
#   'b2',
#   'b2',
#   'b2',
#   'b1',
#   'b3',
#   'b2',
#   'f1',
#   'b2',
#   'b2'],
#  's39': ['b1', 'f3', 'f1', 'f2', 'f3', 'f1', 'f3'],
#  'm+3': [],
#  'r3': ['f3',
#   'f3',
#   'f2',
#   'f+1',
#   'b1',
#   'f3',
#   'b3',
#   'z1',
#   'b3',
#   'b1',
#   'f3',
#   'f+1',
#   'f3',
#   'f+1',
#   'b3',
#   'f+1'],
#  's1': ['f1', 'f1', 'f1', 'f3', 'f1', 'f2', 'f+3', 'f3', 'f3', 'f3', 'f+1'],
#  'f17': ['f+3', 'f+1', 's3', 'b1', 'f1', 'f2', 'f+1', 'f+3', 'f1'],
#  'f-2': ['z1'],
#  'b19': ['f2', 'f3', 'f1', 'f1'],
#  's29': ['f1', 'f1', 'f1', 'f3'],
#  'f29': ['f1',
#   'b2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   's1',
#   'f1',
#   'f1',
#   'f3',
#   'f+3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f+1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3'],
#  'f;1': ['f1', 'f+1'],
#  'b-3': ['z1'],
#  'b+38': ['s3'],
#  'r27': ['f+3', 'f3'],
#  'f+3': ['b2',
#   'b1',
#   'b1',
#   's3',
#   'b3',
#   'b1',
#   's3',
#   's1',
#   'b1',
#   's1',
#   'b3',
#   'b1',
#   'b3',
#   'b3',
#   's3',
#   'b3',
#   's3',
#   's1',
#   's2',
#   's2',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   's3'],
#  'f+2': ['b2'],
#  'b;27': ['f+1'],
#  'm17': [],
#  'b;3': ['f2'],
#  'f;37': ['f3'],
#  'u3': ['s1', 'b3'],
#  'b;1': ['f1', 'f1', 'f+1'],
#  'f;38': ['b2'],
#  'm1': [],
#  'l3': [],
#  'f+1': ['f2', 'f1', 'f1', 'f3', 'f3', 'f3', 'f1', 'f2', 'f1', 'f3', 'f2'],
#  'v2': ['b3', 'v1', 'f1'],
#  'm': [],
#  'r1': ['f1', 'f1', 'v1', 'f1', 'f+3', 'f2', 'v1'],
#  'u1': ['f3', 'f1', 'f+1'],
#  'm27': [],
#  'm28': [],
#  'r29': ['f3'],
#  'b;2': ['f1', 'f1', 's1'],
#  'l1': [],
#  's17': ['f3'],
#  's18': ['f1'],
#  'f;28': ['f+1'],
#  'y37': ['s1'],
#  'f;27': ['f3', 'f3'],
#  'r19': ['f+1'],
#  'y2': ['b1'],
#  'u2': ['f3'],
#  'r28': ['f3'],
#  'f-1': ['v1'],
#  'b+2': ['b3'],
#  '4': ['b37',
#   'b27',
#   'f18',
#   'b28',
#   'f38',
#   'f28',
#   'b18',
#   'f29',
#   'f18',
#   'b37',
#   'f18',
#   'b19',
#   'b28',
#   'f29',
#   'b37',
#   's28',
#   'b19',
#   'b28',
#   'b28',
#   'b28',
#   'f29',
#   'b28',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'b2',
#   'b28',
#   'f18',
#   'b29',
#   'b38',
#   'b37',
#   'b37',
#   'f18',
#   'b38',
#   'b18',
#   'b28',
#   'b27',
#   'b28',
#   'b18',
#   'b28',
#   'b28',
#   'b29',
#   'f38',
#   'f18',
#   'b18',
#   'b19',
#   'b27',
#   'b38',
#   'b28',
#   'b19',
#   'b18',
#   'f18',
#   'b29',
#   'b27',
#   'b19',
#   'b18',
#   'b38',
#   'b27',
#   'f18',
#   'b18',
#   'b18',
#   'b38',
#   'b27',
#   'b27',
#   'b29',
#   'b19',
#   's28',
#   's28',
#   's28',
#   'f28',
#   'b37',
#   'f28',
#   'b28',
#   'b38',
#   's28',
#   'b28',
#   'b18',
#   'b28',
#   'b37',
#   'b28',
#   'b27',
#   'b28',
#   'b27',
#   's28',
#   'b28',
#   'b28',
#   'b17',
#   'b28',
#   'f38',
#   'b28',
#   'b27',
#   'b18',
#   'b29',
#   'b29',
#   'b37',
#   's28',
#   'b18',
#   'b28',
#   'b28',
#   'b38',
#   'b28',
#   'b28',
#   'f38',
#   'b27',
#   'f18',
#   'b29',
#   'f28',
#   'b19',
#   'b28',
#   'b28',
#   'f28',
#   'b28',
#   'f28',
#   'b28',
#   'b28',
#   'b18',
#   'b29',
#   'b29',
#   'b28',
#   'b37',
#   'b27',
#   'b19',
#   'b29',
#   'b27',
#   'b29',
#   'b29',
#   'b28',
#   'b29',
#   'b28',
#   'b37',
#   'b29',
#   'b29',
#   'b28',
#   'b37',
#   'b37',
#   'f28',
#   'b19',
#   'b19',
#   'b38',
#   'b27',
#   'b37',
#   'b37',
#   'b37',
#   'b28',
#   'b28',
#   'b38',
#   'b28',
#   'f29',
#   'b29',
#   'b28',
#   'b38',
#   'b38',
#   'b29',
#   'b37',
#   'b38',
#   'f18',
#   's',
#   'b28',
#   'f28',
#   'b28',
#   'b28',
#   'b38',
#   'b18',
#   'b38',
#   'f29',
#   'b28',
#   'b27',
#   'b28',
#   'b28',
#   'b38',
#   'b28',
#   'b28',
#   'b19',
#   'b18',
#   'f28',
#   'b28',
#   'b28',
#   'b29',
#   'b28',
#   'b27',
#   'b17',
#   's28',
#   'f28',
#   'b28',
#   'f28',
#   'b27',
#   'b29',
#   'b28',
#   'b18',
#   'b28',
#   's28',
#   's28',
#   'b28',
#   'b19',
#   'b19',
#   'b19',
#   's28',
#   'b27',
#   'b27',
#   'b28',
#   'b29',
#   'b37',
#   'b27',
#   's28',
#   'b27',
#   'b19',
#   'f29',
#   'b27',
#   'b29',
#   'b19',
#   'f28',
#   's28',
#   'b29',
#   's28',
#   'f28',
#   'f28',
#   'b27',
#   'b18',
#   'b28',
#   'f28',
#   'f28',
#   'f18',
#   'b28'],
#  '5': ['b18',
#   'b28',
#   'f38',
#   'f28',
#   'f18',
#   'f28',
#   'f28',
#   'b18',
#   's28',
#   's28',
#   'b28',
#   'b18',
#   'f1',
#   'b2',
#   'b2',
#   'f1',
#   'b2',
#   'f27',
#   'b28',
#   'f29',
#   'b18',
#   'b27',
#   'b29',
#   'f29',
#   'b19',
#   'f38',
#   'f37',
#   'b18',
#   'b29',
#   'f18',
#   'b18',
#   'b38',
#   'b18',
#   'b28',
#   'b28',
#   'b27',
#   'b28',
#   'b18',
#   'b28',
#   'f38',
#   'b28',
#   'b27',
#   'f29',
#   'f29',
#   'b27',
#   'b27',
#   'f29',
#   'b29',
#   'f29',
#   'f28',
#   'b18',
#   'f29',
#   'b28',
#   'b18',
#   'f18',
#   'b27',
#   'b18',
#   'b19',
#   'b27',
#   'b29',
#   'f27',
#   'b29',
#   'f27',
#   'b19',
#   'b28',
#   'f37',
#   'b28',
#   'b28',
#   'f27',
#   'b28',
#   'f29',
#   'b18',
#   'f28',
#   'b28',
#   'b28',
#   'b38',
#   'b28',
#   'f28',
#   'b28',
#   'f29',
#   'b28',
#   'b28',
#   'f29',
#   'b27',
#   'b38',
#   'b28',
#   'f28',
#   'b19',
#   'f38',
#   'f29',
#   'b29',
#   'f38',
#   'b18',
#   'f38',
#   'b18',
#   'b17',
#   'f18',
#   'b28',
#   'b28',
#   'b28',
#   'f29',
#   'b17',
#   'b27',
#   'f29',
#   'b29',
#   's28',
#   'f27',
#   'f29',
#   'b18',
#   'b28',
#   'f28',
#   'b27',
#   'b18',
#   'f29',
#   'b28',
#   'f18',
#   'f28',
#   'b28',
#   'f18',
#   'b18',
#   'f18',
#   'b27',
#   'f28',
#   'f28',
#   'f18',
#   'f18',
#   'b28',
#   'f27',
#   'f18',
#   'b28',
#   'b29',
#   'f38',
#   'f28',
#   'b28',
#   'b18',
#   'b28',
#   'b19',
#   'f37',
#   'f37',
#   'f27',
#   'f28',
#   'b18',
#   'b17',
#   'f28',
#   'b28',
#   'b28',
#   'f28',
#   'b28',
#   's28',
#   'f27',
#   'f18',
#   'b18',
#   'b18'],
#  '6': ['b28',
#   'b17',
#   'b28',
#   'b18',
#   'b19',
#   'b28',
#   'b28',
#   'b27',
#   'f28',
#   'f27',
#   'b28',
#   'b19',
#   'b19',
#   'b29',
#   'b18',
#   'b2',
#   'b2',
#   'b2',
#   'f1',
#   'b2',
#   'b1',
#   'b1',
#   'b1',
#   'b1',
#   'b2',
#   'b28',
#   'b19',
#   'b19',
#   'b27',
#   'b29',
#   'b27',
#   'b18',
#   'b19',
#   'b18',
#   'b19',
#   'b18',
#   'b27',
#   'b19',
#   'f29',
#   'b18',
#   'b19',
#   'b27',
#   'b28',
#   'b27',
#   'b27',
#   'b18',
#   's28',
#   'f27',
#   'b37',
#   'b18',
#   'b18',
#   'b28',
#   'f29',
#   'b28',
#   'f28',
#   'b29',
#   'b28',
#   'b28',
#   'f18',
#   'f28',
#   'f18',
#   'f28',
#   'b29',
#   'b18',
#   'b28',
#   'b28',
#   'b28',
#   'b18',
#   'b19',
#   'b19',
#   'b28',
#   'b19',
#   'f18',
#   'b28',
#   'b19',
#   'b18',
#   'b18',
#   'b38',
#   'b18',
#   'b28',
#   'b27',
#   'b19',
#   'b17',
#   'b18',
#   'b27',
#   'b19',
#   'b28',
#   'b28',
#   'b28',
#   'b17',
#   'b29',
#   'f18',
#   'b18',
#   'b28',
#   'b28',
#   'b18',
#   'b18',
#   'f18',
#   'b17',
#   'b19',
#   'b29',
#   'f28',
#   'f28',
#   'f28',
#   'b19',
#   'f29',
#   'f29',
#   'f27',
#   'b27',
#   'b18',
#   'b17',
#   'f28',
#   'b29',
#   'b19',
#   'b19',
#   'f18',
#   'b19',
#   'b19',
#   'b18',
#   'f27',
#   'f28',
#   'b29',
#   'f18',
#   'b18',
#   'b19',
#   'f28',
#   'b28',
#   'b28',
#   'b29',
#   'b18',
#   'b18',
#   'f18',
#   'b28',
#   'b28',
#   'b28',
#   's28',
#   'b27',
#   'b17',
#   'b19',
#   'b28',
#   'b38',
#   'b27',
#   'b19',
#   'f29',
#   'b19',
#   'b38',
#   'b19',
#   'f29',
#   'f27',
#   'b29',
#   'b28',
#   'b37',
#   'b19',
#   'f38',
#   'b18',
#   'f28',
#   'b19',
#   'b29',
#   'b28',
#   'b29',
#   'b28',
#   'b38',
#   'b29',
#   'b19',
#   'b18',
#   'f27',
#   'b19',
#   'b19',
#   'b19',
#   'b28',
#   'b27',
#   'b18',
#   'b28',
#   'b18',
#   'b17',
#   'b28',
#   'b27',
#   'b18',
#   'b18',
#   'b18',
#   'b18',
#   'b28',
#   'b28',
#   'b28',
#   's28',
#   'b38',
#   'b27',
#   'b18',
#   'b18',
#   'b29',
#   'f29',
#   'b28',
#   'f29',
#   'f29',
#   'b29',
#   'b19',
#   'f29',
#   'b18',
#   'b18',
#   'f28',
#   'b17',
#   'f38',
#   'f28',
#   'b28',
#   'b29',
#   'b27',
#   'b28',
#   'b28',
#   's28',
#   'b19',
#   'b19',
#   'b17',
#   'b27',
#   'b19',
#   'b28',
#   'f18',
#   'b28',
#   'b28',
#   'b27',
#   'b28',
#   'b27',
#   'b18',
#   's28',
#   'f27',
#   's28',
#   's28',
#   'b28',
#   'b19',
#   's28',
#   'b28',
#   'b18',
#   'b19',
#   'b38',
#   'b28',
#   'f18',
#   'b29',
#   'b19',
#   'b28',
#   'b28',
#   'b27',
#   'f28',
#   'f29'],
#  'b': ['f', 'b', 'f', 'v1'],
#  'h-3': ['b2'],
#  'c5': ['b28', 'b28', 'b28', 's', 'b28', 'b28', 'b28'],
#  'c4': ['b18', 'f28', 'b19', 'b29', 'b29', 'b28', 'f28'],
#  'f-3': ['b2'],
#  'k1': ['f3'],
#  'f1-': ['f1'],
#  'c6': ['b18', 'b28', 'b29', 's28', 'b19', 'f29', 'b29', 'b28', 'b28', 'b17'],
#  'y+2': ['b2'],
#  'z2': ['v3'],
#  'f;3': ['s3'],
#  's;3': ['b1'],
#  'o1': ['f3', 'f3'],
#  's+3': ['b3', 'b1'],
#  'z3': ['b1', 'b1'],
#  'o2': ['b2'],
#  'v3': ['b1'],
#  '4+': ['s'],
#  'b;-3': ['b3'],
#  'b-1': ['f3'],
#  'z1': ['f1'],
#  'cc5': [],
#  'y3': ['b1', 'b3', 'b1', 's1'],
#  'm+2': [],
#  'o=3': ['s1'],
#  'v1': ['f3', 'f3', 'f3'],
#  '5+': ['b37'],
#  'i=1': [],
#  'i=2': ['f+1'],
#  'h=3': ['f1'],
#  'r+3': ['b3'],
#  'r;1': ['f3'],
#  'i3': ['b3'],
#  'b+1': ['f1'],
#  'X': ['4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '5',
#   '6',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '5',
#   '5',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '6',
#   '5',
#   '4',
#   '6',
#   '5',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '4',
#   '5',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '6',
#   '6',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '6',
#   '6']}

# %% [markdown]
# # Testing function for your model performances
#
# See the file *aux_functions*.  The following function makes the historical RN become alive and play against you!

# %%
all_dict_lost2
# Out:
# {'f37': ['s1',
#   's1',
#   's3',
#   'f3',
#   'f1',
#   'b1',
#   's3',
#   's3',
#   'b1',
#   's1',
#   'b2',
#   'b2',
#   'b1',
#   'b3',
#   'f3',
#   'b3',
#   'b3',
#   'b3',
#   's2',
#   'z1',
#   'b3',
#   'f2',
#   'b1',
#   'b3',
#   'f1',
#   'b1',
#   's1',
#   'b3',
#   'b1',
#   's1',
#   'f+3',
#   'f3',
#   'b3',
#   'f2',
#   'f3',
#   'f1',
#   'b2',
#   's2',
#   'f3',
#   'b1',
#   'f+3',
#   'f1',
#   'b1',
#   'b3',
#   'f3',
#   'b1',
#   'f3',
#   'f3',
#   'b2',
#   'f+1',
#   'b3',
#   's1',
#   'b1',
#   'b1',
#   'f3',
#   'f3',
#   'f3',
#   's2'],
#  's38': ['f1', 'f1', 'f3', 'f1', 'b1', 'b1', 'f+1'],
#  'b1': ['f1',
#   'f2',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'r2',
#   'f3',
#   'f1',
#   'f3',
#   'f2',
#   'f2',
#   'v3',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'v3',
#   'f3',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'v3',
#   'f1',
#   'f2',
#   'f2',
#   'f2',
#   'f2',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'v3',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f+3',
#   'f3',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f1',
#   'f+3',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'v3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'v1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'v3',
#   'f2',
#   'f',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'v3',
#   'f1',
#   'r2',
#   'f3',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f2',
#   'f+3',
#   'v3',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'r2',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f+3',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'f',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f',
#   'f2',
#   'v3',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'f+3',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f2',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f+3',
#   'f3',
#   'f1',
#   'v3',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f2',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f+3',
#   'f1',
#   'f1',
#   'f',
#   'f3',
#   'f+3',
#   'f1',
#   'f3',
#   'f2',
#   'f3',
#   'f1',
#   'f+3',
#   'f3',
#   'f2',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'v3',
#   'f1',
#   'f2',
#   'f3',
#   'v3',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'f2',
#   'f2',
#   'f3',
#   'f1',
#   'f3',
#   'f+3',
#   'f1',
#   'f',
#   'f3',
#   'f3',
#   'f3',
#   'f',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'f2',
#   'r2',
#   'f1',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f+3',
#   'f+3',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'v3',
#   'f3',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f2',
#   'f3',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f+1',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'f+1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'f+1',
#   'v3',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'r2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f+3',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'f1',
#   'f2'],
#  'b+3': ['s3', 's2', 'b3', 's2', 's1', 's3', 's2', 'b1'],
#  'b28': ['f3',
#   'f2',
#   'f2',
#   'f1',
#   'f',
#   'f2',
#   'f2',
#   'f3',
#   'f3',
#   'f3',
#   'f2',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'b3',
#   'f2',
#   'f3',
#   'f3',
#   'b2',
#   'f1',
#   'f1',
#   'f3',
#   'b3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f+1',
#   'f1',
#   'f2',
#   'z1',
#   'f1',
#   'f3',
#   'b3',
#   'f1',
#   'f1',
#   'f1',
#   'b1',
#   'f3',
#   'b2',
#   'f1',
#   'f1',
#   'f+1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f+1',
#   'f3',
#   'b1',
#   'f1',
#   'b1',
#   'f3',
#   'f1',
#   'f+1',
#   'f1',
#   'f+3',
#   'f2',
#   'b2',
#   'f2',
#   'f+1',
#   'f1',
#   'f1',
#   'f+1',
#   'f2',
#   'f+1',
#   'f+3',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'v1',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f1'],
#  'b29': ['f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'b',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f',
#   'f1',
#   'b1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f2',
#   'f1'],
#  's27': ['f+3', 'f+1', 'f3', 'f+3'],
#  'f1': ['v3',
#   'f1',
#   'f2',
#   'f2',
#   'f2',
#   'r2',
#   'f1',
#   'f1',
#   'f1',
#   'f',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'v1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f',
#   'f1',
#   'r2',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f2',
#   'r2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f2',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f3',
#   'f1',
#   'r2',
#   'f1',
#   'f3',
#   'f2',
#   'f+3',
#   'r2',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'f1',
#   'v1',
#   'f2',
#   'f2',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f',
#   'f1',
#   'f2',
#   'f2',
#   'r2',
#   'f1',
#   'f3',
#   'f2',
#   'f3',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'r2',
#   'f2',
#   'f3',
#   'f1',
#   'f',
#   'f2',
#   'f1',
#   'f3',
#   'f2',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f',
#   'f',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'f2',
#   'f2',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'r2',
#   'f2',
#   'f1',
#   'f2',
#   'r2',
#   'f2',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'r2',
#   'f2',
#   'r2',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f',
#   'f1',
#   'f',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'v1',
#   'f2',
#   'f1',
#   'b1',
#   'f1',
#   'r2',
#   'f1',
#   'f1',
#   'f1',
#   'r2',
#   'f1',
#   'f2',
#   'r2',
#   'f2',
#   'f1',
#   'f+3',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f',
#   'f1',
#   'f1',
#   'f2',
#   'r2',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f3',
#   'f3',
#   'f',
#   'f3',
#   'f1',
#   'f2',
#   'r2',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'v3',
#   'f',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'r2',
#   'f1',
#   'f',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f3',
#   'f2',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'r2',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'r2',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f3',
#   'r2',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'r2',
#   'f2',
#   'f2',
#   'f2',
#   'f1',
#   'f2',
#   'f2',
#   'f2',
#   'f',
#   'r2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f2',
#   'f2',
#   'f3',
#   'f2',
#   'f1',
#   'f',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'r2',
#   'f1',
#   'f1',
#   'r2',
#   'f1',
#   'v1',
#   'f1',
#   'f1',
#   'f3',
#   'f2',
#   'r2',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f2'],
#  'f7': ['b'],
#  'f8': ['b', 'b', 'b'],
#  'b27': ['z3',
#   'f3',
#   'f3',
#   'v3',
#   'v1',
#   'f+1',
#   'v3',
#   'f1',
#   'f+3',
#   'f+1',
#   'f+3',
#   'f1',
#   'v1',
#   'f+3',
#   'f+1',
#   'f3',
#   'f+3',
#   'f+3',
#   'z1',
#   'f1',
#   'f+3',
#   'f+1',
#   'b2',
#   'f+3',
#   'f+1',
#   'v3',
#   'f+1',
#   's1',
#   'f3',
#   'f+3',
#   'f+1',
#   'f+1',
#   'f1',
#   'f',
#   'f2',
#   'f3',
#   'v3',
#   'f+1',
#   'f3',
#   'v1',
#   'f2',
#   'f+3'],
#  'f': ['b',
#   'f',
#   'f',
#   'b',
#   'v1',
#   'f',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   's',
#   'b',
#   'b',
#   'b',
#   'f',
#   'b',
#   'b'],
#  'b19': ['f+3',
#   'f1',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'f3',
#   'f3',
#   'f',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f1'],
#  'f2': ['b2',
#   'f2',
#   'z1',
#   'f1',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   'f3',
#   'f2',
#   'f1',
#   'b2',
#   'f1',
#   'f2',
#   'b2',
#   'f2',
#   'f2',
#   'b3',
#   'f1',
#   'b3',
#   'f1',
#   'b2',
#   'f1',
#   'f2',
#   'b3',
#   'v1',
#   'f2',
#   'f3',
#   'f2',
#   'f2',
#   'b2',
#   'b3',
#   'f1',
#   'b2',
#   'f2',
#   'b1',
#   'f1',
#   'b2',
#   'b2',
#   'f2',
#   'f2',
#   'b1',
#   'f1',
#   'z1',
#   'f3',
#   'f3',
#   'b3',
#   'f1',
#   'f3',
#   'z3',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'b2',
#   'f2',
#   'f1',
#   'f1',
#   'f+1',
#   'f2',
#   'f3',
#   'f1',
#   'f2',
#   'f2',
#   'f3',
#   'f3',
#   'b1',
#   'f3',
#   'b2',
#   'b2',
#   'b2',
#   'f2',
#   'b3',
#   'b2',
#   'f3',
#   'f+3',
#   'f3',
#   'f2',
#   'f1',
#   'f2',
#   'b2',
#   'b',
#   'b2',
#   'f+3',
#   'b1',
#   'b1',
#   'f1',
#   'b1',
#   'b2',
#   'b1',
#   'b2',
#   'f2',
#   'f2',
#   'f1',
#   'f2',
#   'b3',
#   'b1',
#   'b3',
#   'b1',
#   'f3',
#   'f1',
#   'b2',
#   'f2',
#   'f2',
#   'b3',
#   'f2',
#   'b2',
#   'f1',
#   'f2',
#   'b2',
#   'b3',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'b1',
#   'b2',
#   'f1',
#   'f+3',
#   'f3',
#   'b1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'b2',
#   'f1',
#   'f3',
#   'b1',
#   'b1',
#   'f1',
#   'f1',
#   'b3',
#   'f1',
#   'b1',
#   'b3',
#   'f+1',
#   'f3',
#   's2',
#   'f2',
#   'f+1',
#   'b3',
#   'f2',
#   'f2',
#   'b2',
#   'f2',
#   'f2',
#   'b1',
#   'b1',
#   'b3',
#   'b3',
#   'f2',
#   'f2',
#   'f3',
#   'b2',
#   'b2',
#   'b2',
#   'f2',
#   'f3',
#   'f2',
#   'b2',
#   'f1',
#   'f2',
#   'f3',
#   'f2',
#   'f2',
#   'f2',
#   'b3',
#   'f2',
#   'f1',
#   'f2',
#   'f2',
#   'b1',
#   'b1',
#   'v3',
#   'f1',
#   'b2',
#   'b1',
#   'z1',
#   'b2',
#   'f1',
#   'f2',
#   'f2',
#   'f2',
#   'f3',
#   'b1',
#   'f2',
#   'f1',
#   'f+3',
#   'f3',
#   'f1',
#   'f3',
#   'b2',
#   'f+1',
#   'f2',
#   'f3',
#   'f2',
#   'f3',
#   'f2',
#   'f3',
#   'f3',
#   'f3',
#   'b3',
#   'b3',
#   'f1',
#   'f1',
#   'f2',
#   'b2',
#   'f+3',
#   'b2',
#   'f2',
#   'f2',
#   'b1',
#   's2',
#   'f2',
#   'b1',
#   'b2',
#   'f1',
#   's2',
#   'b3',
#   'f1',
#   'b2',
#   'f1',
#   'f2',
#   'b2',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'b2',
#   'f2',
#   'b1',
#   'b3',
#   'f1',
#   'b2',
#   'b2',
#   'b2',
#   'f1',
#   'b1',
#   'f1',
#   'b2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   's3',
#   'b1',
#   'b2',
#   'f2',
#   'f2',
#   'b2',
#   'b2',
#   'f3',
#   'b2',
#   'f3',
#   'f1',
#   'b2',
#   'b2',
#   'f2',
#   'b2',
#   'b2',
#   'f',
#   'r2',
#   'f3',
#   'f1',
#   'z1',
#   'f1',
#   's1',
#   'f3',
#   'f3',
#   'f3',
#   'f3',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'b2',
#   'b3',
#   'f2',
#   'b1',
#   'f3',
#   'f3',
#   'f+1',
#   'b2',
#   'b3',
#   'f3',
#   'f2',
#   'b2',
#   'f1',
#   'b2',
#   'f1',
#   'f3',
#   'b2',
#   'b2',
#   'f2',
#   's1',
#   'f2',
#   'f3',
#   'b2',
#   'f3'],
#  'b': ['f',
#   'b',
#   'f',
#   'f',
#   'f',
#   'b',
#   'f',
#   'f',
#   'b',
#   'f',
#   'b',
#   'f',
#   'b',
#   'f',
#   's',
#   'b',
#   'f',
#   'f',
#   'b',
#   'f',
#   'b',
#   'f',
#   'b',
#   'f2'],
#  'b9': ['f', 'b'],
#  's': ['b', 'f'],
#  'b39': ['f2',
#   'b2',
#   'f1',
#   'b2',
#   'b2',
#   'f',
#   'b2',
#   'b3',
#   's3',
#   'b1',
#   'f',
#   'b3',
#   'b3',
#   'f1',
#   'f1',
#   'f2'],
#  'f38': ['f2',
#   'f3',
#   'b2',
#   'b2',
#   'f1',
#   'b3',
#   'f1',
#   'f2',
#   's1',
#   'b3',
#   's2',
#   'f2',
#   'f1',
#   'b2',
#   'f1',
#   'f1',
#   'b2',
#   'b1',
#   'f1',
#   'b3',
#   'f3',
#   'f3',
#   'b1',
#   'f1',
#   'b2',
#   'b2',
#   'f2',
#   'f1',
#   'b3',
#   'f1',
#   'f1',
#   'f3',
#   'b2',
#   'f1',
#   'b2',
#   'b1',
#   'b2',
#   'f3',
#   'f1',
#   'b2',
#   'f1',
#   'f3',
#   'f3',
#   'b1',
#   'b2',
#   'f3',
#   's2',
#   'f3',
#   'f3',
#   'b2',
#   'b3',
#   's2',
#   's2',
#   's2',
#   'f1',
#   'f2',
#   'f1',
#   'b1',
#   'f3',
#   'b3',
#   'f2'],
#  'b2': ['f3',
#   'b3',
#   'f1',
#   'b2',
#   'f2',
#   'f2',
#   'f1',
#   'f1',
#   'b1',
#   'b3',
#   'b1',
#   'b2',
#   'f1',
#   'b2',
#   'b3',
#   'f',
#   'f1',
#   'f',
#   'f2',
#   'b2',
#   'b2',
#   'f1',
#   'f1',
#   'f2',
#   'f+1',
#   'b1',
#   'f3',
#   'f3',
#   'f1',
#   'f2',
#   'b1',
#   'b3',
#   'f2',
#   'f2',
#   'b3',
#   'f2',
#   'z3',
#   'b2',
#   'f1',
#   'f1',
#   'f1',
#   'b3',
#   'f+1',
#   'v1',
#   'f1',
#   'f1',
#   'f2',
#   'f3',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   'v1',
#   'b3',
#   'v1',
#   'b1',
#   'b3',
#   'f3',
#   'b3',
#   'f2',
#   'f3',
#   'f1',
#   'b3',
#   'f2',
#   'f+1',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'f2',
#   'b2',
#   'f1',
#   'f2',
#   'f3',
#   'f2',
#   'b1',
#   'f3',
#   'b',
#   'f+1',
#   'f1',
#   'f+3',
#   'b3',
#   'f2',
#   'f3',
#   'v3',
#   'f3',
#   'f+3',
#   'b2',
#   'b1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f+1',
#   'f2',
#   'f1',
#   'f2',
#   'b3',
#   'f1',
#   'f1',
#   'f3',
#   's3',
#   'b2',
#   'f+1',
#   'f1',
#   'f2',
#   'b3',
#   'f3',
#   'b3',
#   'f+1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f2',
#   'f2',
#   'b1',
#   'f1',
#   'f1',
#   'f1',
#   'b2',
#   'f1',
#   'f2',
#   'b1',
#   'b2',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   'b2',
#   'f2',
#   'f2',
#   'f1',
#   'b2',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'b3',
#   'b1',
#   'b1',
#   'f2',
#   'b3',
#   'b1',
#   'f1',
#   'f3',
#   'f+1',
#   'f3',
#   'f1',
#   'b2',
#   'b1',
#   'b1',
#   'b3',
#   'z3',
#   'f3',
#   'f1',
#   'f2',
#   'b3',
#   'f2',
#   's1',
#   'b3',
#   'f3',
#   'f2',
#   'b2',
#   'f3',
#   'f3',
#   'b3',
#   'b2',
#   'b1',
#   'f2',
#   'f2',
#   'f1',
#   'b3',
#   'b1',
#   'b1',
#   'f+1',
#   'b3',
#   'f1',
#   'f1',
#   'f1',
#   'b1',
#   'f2',
#   'b2',
#   'f2',
#   'f2',
#   'f3',
#   'f3',
#   'f1',
#   'f3',
#   'b3',
#   'f2',
#   'b2',
#   'b1',
#   'f1',
#   'f1',
#   'z3',
#   'f1',
#   'b1',
#   'b1',
#   'f1',
#   'b3',
#   'b2',
#   'f3',
#   'b',
#   'f3',
#   'f+3',
#   'f2',
#   'b2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'b2',
#   'f2',
#   'f1',
#   'f+1',
#   'b2',
#   'b3',
#   'f1',
#   'b2',
#   'f1',
#   'f2',
#   'f2',
#   'f3',
#   'f1',
#   'b2',
#   'b3',
#   'z1',
#   'f3',
#   'b1',
#   'b2',
#   'f3',
#   'f',
#   'f+3',
#   'b2',
#   'f2',
#   'v3',
#   'f3',
#   'b3',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'b1',
#   'f3',
#   'z3',
#   'f3',
#   'f3',
#   'b1',
#   'b2',
#   'b1',
#   'b2',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'f2',
#   's2',
#   'f2',
#   'b2',
#   's1',
#   'b1',
#   's2',
#   'f3',
#   'f2',
#   'f1',
#   'b2',
#   'f3',
#   'f3',
#   'f1',
#   'b2',
#   'f+1',
#   'b2',
#   'f2',
#   's1',
#   'b1',
#   'b3',
#   'b1',
#   's2',
#   'f3',
#   'b2',
#   'b2',
#   'f3',
#   'f1',
#   's1',
#   'f1',
#   'f1',
#   's3',
#   'f+1',
#   'f2',
#   'f2',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'b3',
#   'f2',
#   'f1',
#   'f2',
#   'b1',
#   's3',
#   'f2',
#   'v1',
#   'f2',
#   'f1',
#   'b2',
#   'f3',
#   'f2',
#   'f+1',
#   'f1',
#   's3',
#   'f1',
#   'f',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   's1',
#   'f1',
#   'f3',
#   'f2',
#   'b2',
#   'f1',
#   's2',
#   'f2',
#   's1',
#   'f2',
#   'f2',
#   'b1',
#   'f2',
#   'f1',
#   'v1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1'],
#  'f3': ['b3',
#   'b2',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'f3',
#   'b2',
#   'b2',
#   'b2',
#   's2',
#   'b2',
#   'b1',
#   's3',
#   'f1',
#   'b2',
#   'b2',
#   'f1',
#   'b1',
#   's3',
#   'b2',
#   'b3',
#   'b',
#   'b1',
#   'f2',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   's3',
#   'b2',
#   'b2',
#   's3',
#   'b2',
#   'b2',
#   'z1',
#   'b3',
#   'b1',
#   's3',
#   's1',
#   'b1',
#   'b1',
#   'b2',
#   's1',
#   'b1',
#   'b1',
#   'f1',
#   'b2',
#   'f1',
#   'b1',
#   'b1',
#   's3',
#   'f1',
#   'b2',
#   'b1',
#   'b1',
#   'b1',
#   'b1',
#   'b2',
#   'b3',
#   'f3',
#   'f1',
#   'f+1',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   'f2',
#   'f1',
#   's1',
#   'f3',
#   'b3',
#   'b2',
#   'b1',
#   'b2',
#   'b2',
#   'b1',
#   'f3',
#   'b2',
#   'b1',
#   'b2',
#   'b2',
#   'f2',
#   'b2',
#   'b2',
#   's2',
#   'b3',
#   's2',
#   'b1',
#   'b2',
#   'b1',
#   's1',
#   'b2',
#   'b2',
#   'f3',
#   'b2',
#   'b2',
#   's2',
#   'b3',
#   'b3',
#   'b3',
#   'b1',
#   'b2',
#   'z1',
#   's2',
#   'b3',
#   'b2',
#   'f3',
#   'f3',
#   'b3',
#   's',
#   's1',
#   'b3',
#   'b1',
#   's3',
#   'b3',
#   'f2',
#   'f2',
#   'b3',
#   'b3',
#   'f1',
#   'b2',
#   'f2',
#   'b2',
#   'b1',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'f1',
#   'b3',
#   'b2',
#   'b1',
#   'b2',
#   'b2',
#   'b3',
#   'b2',
#   'b1',
#   'f2',
#   'b2',
#   'b2',
#   'b2',
#   'b1',
#   'b2',
#   's2',
#   's1',
#   'f3',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   'b2',
#   'f2',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'f1',
#   's',
#   'z3',
#   'f1',
#   'b2',
#   'b2',
#   'b1',
#   'b2',
#   'b2',
#   'b1',
#   'b3',
#   'b2',
#   'b3',
#   'b2',
#   'b1',
#   'f1',
#   'b3',
#   'b1',
#   'f3',
#   'z3',
#   'f1',
#   'b1',
#   's3',
#   'b1',
#   'b1',
#   'b2',
#   'z1',
#   'b2',
#   's1',
#   'b2',
#   'b1',
#   'b2',
#   'b2',
#   'b2',
#   'b2',
#   'b1',
#   'f1',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'f3',
#   'b2',
#   'f1',
#   'f1',
#   'b2',
#   'b1',
#   's2',
#   'b1',
#   'b3',
#   'b3',
#   's2',
#   'b2',
#   'b2',
#   'b3',
#   'f1',
#   'f3',
#   'f2',
#   'z1',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   's2',
#   'f1',
#   'b1',
#   's1',
#   's1',
#   'b1',
#   'b2',
#   's3',
#   's2',
#   'b3',
#   's1',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'f1',
#   's1',
#   'b3',
#   'f2',
#   'f2',
#   'z1',
#   'f3',
#   'f2',
#   's1',
#   'f2',
#   'b2',
#   'b2',
#   's3',
#   'f2',
#   'b3',
#   'b2',
#   'b3',
#   's2',
#   'f2',
#   's2',
#   'b2',
#   'f3',
#   'b2',
#   's3',
#   'b1',
#   'f1',
#   'b2',
#   'b3',
#   's3',
#   'b3',
#   's2',
#   's2',
#   's2',
#   'b3',
#   'b3',
#   'b2',
#   'f3',
#   'b3',
#   's2',
#   'b2',
#   's2',
#   'b2',
#   'b3',
#   'b2',
#   'f1',
#   's3',
#   'b3',
#   'f3',
#   'b1',
#   'b2',
#   'b2',
#   's2',
#   'b2',
#   'b2',
#   's2',
#   'b1',
#   'b2',
#   'b2',
#   'f1',
#   'b2',
#   's1',
#   'f3',
#   'b2',
#   'b2',
#   'b1',
#   's1',
#   's3',
#   's1',
#   'b2',
#   'b',
#   'b3',
#   'b2',
#   's1',
#   'f2',
#   'b2',
#   'b3',
#   'b3',
#   'b3',
#   's2',
#   'b2',
#   's1',
#   'b2',
#   'f3',
#   'b2',
#   'b1',
#   'z1',
#   'b2',
#   'b3',
#   's1',
#   'b1',
#   'b3',
#   'b2',
#   'b2',
#   'b1',
#   'b2',
#   'f2',
#   'b1',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   'f2',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   'f',
#   'b',
#   'b2',
#   'b3',
#   's',
#   'b',
#   'f1',
#   'f2',
#   'b1',
#   'b1',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   'b1',
#   'b3',
#   'b3',
#   's1',
#   'b3',
#   'b3',
#   'b3',
#   'f2',
#   's2',
#   's1',
#   's3',
#   'b1',
#   'b1',
#   's2',
#   'b2',
#   'f2',
#   'b2',
#   's2',
#   's3',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   's3',
#   'b3',
#   'b1',
#   'b2',
#   'b1',
#   'b3',
#   'b3',
#   'b1',
#   'b2',
#   'b3',
#   's3',
#   's1',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   's1',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'b3',
#   's2',
#   's1',
#   'b2',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'b2',
#   'b2',
#   'b1',
#   'b3',
#   'b1',
#   's2',
#   'b3',
#   'b3',
#   'b3',
#   's1',
#   'b2',
#   'b',
#   'b1',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'b3',
#   'b2',
#   'b3',
#   's3',
#   's1',
#   'b1',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'b2',
#   'f2',
#   'b2',
#   'f2',
#   'b2',
#   'b2',
#   'b1',
#   'b2',
#   'b1',
#   'b3',
#   'b3',
#   'b1',
#   'z1',
#   'f3',
#   'b3',
#   'b2',
#   'b1',
#   'b2',
#   'b2',
#   's2',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b1',
#   's3',
#   'b3',
#   'b2',
#   's3',
#   'b2',
#   'b3',
#   'b2',
#   'f3',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'b3',
#   's3',
#   'b2',
#   'b3',
#   'b2',
#   's2',
#   'b2',
#   'b2',
#   'b1',
#   'b2',
#   's2',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   's1',
#   'b2',
#   'b3',
#   'b2',
#   'b1',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   's2',
#   'b1',
#   'b2',
#   's3',
#   'b3',
#   'b2',
#   's3',
#   'b2',
#   'b3',
#   'b1',
#   'b3',
#   'b2',
#   'b2',
#   's3',
#   'b2',
#   'f3',
#   'b3',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   'f2',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   's3',
#   'f1',
#   'b2',
#   'b1',
#   'b3',
#   'b3',
#   's1',
#   'b2',
#   's3',
#   's2',
#   'f1',
#   's2',
#   'b1',
#   'b2',
#   'b3',
#   'b3',
#   'b2',
#   'b',
#   'b2',
#   'f1',
#   'b3',
#   's2',
#   's3',
#   'b3',
#   'b1',
#   'f3',
#   'b1',
#   'b2',
#   's1',
#   'b3',
#   'b',
#   'b1',
#   'z3',
#   'b1',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b',
#   'f1',
#   's3',
#   'b3',
#   'b1',
#   's3',
#   'b3',
#   's3',
#   's1',
#   'b2',
#   'b2',
#   'b3',
#   'f',
#   'b3',
#   'b1',
#   'b1',
#   's2',
#   'b3',
#   'b2',
#   'b1',
#   'b3',
#   'b1',
#   'b1',
#   's1',
#   's',
#   's1',
#   'b1',
#   'b',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'b1',
#   'b1',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   'b1',
#   'f2',
#   'b3',
#   'b3',
#   'b1',
#   's3',
#   'b2',
#   'f1',
#   's1',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'b1',
#   'b3',
#   's2',
#   'b2',
#   'b2',
#   'b2',
#   'b1',
#   's2',
#   's3',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   'b2',
#   'b2',
#   's3',
#   'b3',
#   'f2',
#   'b1',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'f1',
#   'f2',
#   'b1',
#   'b1',
#   's2',
#   'b1',
#   'f2',
#   'b1',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'f3',
#   's1',
#   'b2',
#   'f2',
#   'b2',
#   'b2',
#   'b2',
#   's1',
#   'b2',
#   'b3',
#   'b2',
#   's1',
#   'b1',
#   'b3',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   's2',
#   'b2',
#   's1',
#   'f3',
#   'b2',
#   'b3',
#   'b2',
#   's1',
#   'f3',
#   'b3',
#   'b1',
#   'b3',
#   'b2',
#   'b3',
#   'b2',
#   's2',
#   's',
#   'b2',
#   'b1',
#   's3',
#   'f2',
#   'b1',
#   'b2',
#   'b2',
#   'b2',
#   's1',
#   's1',
#   'b2',
#   'b2',
#   's2',
#   'b1',
#   's2',
#   'b3',
#   'b3',
#   'f1',
#   'b2',
#   'b2',
#   'b2',
#   'b1',
#   'b3',
#   'b1',
#   's1',
#   's2',
#   'b3',
#   'b3',
#   'b3',
#   's2',
#   'b3',
#   's1',
#   'b2',
#   'f1',
#   'f3',
#   'f3',
#   's1',
#   's3',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   's1',
#   'b3',
#   's3',
#   's3',
#   's1',
#   'b1',
#   'b3',
#   'b1',
#   'f3',
#   'b2',
#   's3',
#   's2',
#   'b3',
#   'b2',
#   'b2',
#   'b1',
#   's1',
#   's3',
#   'b2',
#   's3',
#   's2',
#   'b3',
#   's1',
#   'b3',
#   's1',
#   'b3',
#   'b3',
#   'b2',
#   's',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b1',
#   'b',
#   'b3',
#   's3',
#   's1',
#   'b3',
#   's1',
#   's1',
#   'b3',
#   'b1',
#   'b3',
#   'b',
#   'b2',
#   'f3',
#   'f1',
#   'b1',
#   'b3',
#   'b',
#   'b3',
#   'b1',
#   's1',
#   'b2',
#   'b2',
#   'b3',
#   'b2',
#   'b1',
#   'f3',
#   'b1',
#   'b3',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b3',
#   'b1',
#   'b1',
#   'f1',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   's',
#   'b1',
#   'b2',
#   'b1',
#   'b3',
#   'b1',
#   's2',
#   's',
#   'b1',
#   'b2',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b',
#   'b1',
#   's3',
#   'b3',
#   'b2',
#   'b2',
#   's3',
#   'b3',
#   'b2',
#   'b1',
#   'b3',
#   'f3',
#   's2',
#   's1',
#   'b3',
#   'b2',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   'b3',
#   'b3',
#   'b1',
#   'b2',
#   's1',
#   'b3',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   'f1',
#   's1',
#   'b2',
#   's3',
#   'b1',
#   'f2',
#   'b2',
#   'b2',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   's3',
#   'b2',
#   's3',
#   's1',
#   'b2',
#   'f3',
#   'b1',
#   'f2',
#   'b3',
#   'b',
#   'f1',
#   's1',
#   'b2',
#   'b3',
#   's1',
#   'b1',
#   's2',
#   's1',
#   'b3',
#   'b2',
#   's2',
#   'b2',
#   's1',
#   'b2',
#   's3',
#   'b2',
#   'b2',
#   's2',
#   'b2',
#   'b2',
#   'b1',
#   'b2',
#   's2',
#   'b2',
#   'f3',
#   'b3',
#   's3',
#   'b3',
#   'b2',
#   's1',
#   'b2',
#   'b2',
#   'f+1',
#   'b1',
#   'b1',
#   'b1',
#   'b3',
#   'b1',
#   's2',
#   's3',
#   'f1',
#   's2',
#   'b3',
#   's2',
#   'b3',
#   'b3',
#   's1',
#   's1',
#   'b3',
#   'b2',
#   'b1',
#   'b3',
#   'b1',
#   'b3',
#   'b2',
#   'b2',
#   'b1',
#   'f3',
#   'b2',
#   'b',
#   'b2',
#   'b2',
#   'b2',
#   'b2',
#   'b2',
#   'b2',
#   'b1',
#   'b1',
#   'b2',
#   'b1',
#   's3',
#   'b2',
#   's2',
#   'b3',
#   'b3',
#   'b3',
#   'f3',
#   'b2',
#   's2',
#   'b1',
#   's2',
#   'b3',
#   's1',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   's1',
#   'b2',
#   's2',
#   's2',
#   'b3',
#   'f3',
#   'b2',
#   ...],
#  'f18': ['f1', 'f3', 'f2', 'f2', 'f3', 'f3', 'f+3', 'f3', 'f2', 'f2', 'f1'],
#  'm3': [],
#  's+3': ['z3', 'b3'],
#  'f27': ['b1',
#   'f+1',
#   'f3',
#   'f3',
#   'f2',
#   'f+1',
#   'f1',
#   'f3',
#   'f+3',
#   'f3',
#   'f+3',
#   'z1',
#   'f+1',
#   'f+1',
#   'z1',
#   'f2',
#   'f+1',
#   'f+3',
#   'f+3',
#   'f3',
#   'z1',
#   'f3',
#   'f+3',
#   'f+1',
#   'f1',
#   'f+3',
#   'f+1',
#   'f1',
#   'f3',
#   'f3',
#   'f+1',
#   'f1',
#   'f+1',
#   'f3',
#   'f2'],
#  'b18': ['f2',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f+3',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'r2',
#   'f3',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f3',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f3',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f+3'],
#  'f19': ['r2', 'f', 'f'],
#  'f28': ['f+3',
#   'f1',
#   'f3',
#   'f3',
#   'f2',
#   'b2',
#   'f2',
#   'f2',
#   'f+3',
#   'f1',
#   'f1',
#   'v3',
#   'f1',
#   'f2',
#   'f3',
#   'b2',
#   'f3',
#   'f2',
#   'f3',
#   'f1',
#   'b2',
#   'b3',
#   'b2',
#   'f2',
#   'b2',
#   'f3',
#   'f1',
#   'f1',
#   'f2',
#   'f3',
#   'f1',
#   'b2',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'b2',
#   'f1',
#   'f',
#   'f2',
#   'f1',
#   'f3',
#   'f1',
#   'f1',
#   'z3',
#   'f1',
#   'f1',
#   'f1',
#   'f+1',
#   's1',
#   'z1',
#   'f2',
#   'f+3',
#   'f1',
#   'f+1',
#   'b2',
#   'f1',
#   'f+1',
#   'f1',
#   'f3',
#   'f3',
#   'f2',
#   'f3',
#   'f1',
#   'f3',
#   'f3',
#   'f2',
#   'f1',
#   'f+1',
#   'f1',
#   'f3',
#   'f2',
#   'f3',
#   'f2',
#   'f2',
#   'f2'],
#  'f+3': ['s2',
#   's1',
#   'b3',
#   's2',
#   's3',
#   's2',
#   's2',
#   's2',
#   'b3',
#   's2',
#   'b3',
#   's',
#   's1',
#   'b3',
#   'b1',
#   'b',
#   'b',
#   'b',
#   'b3',
#   's1',
#   'b',
#   'f1',
#   'b3',
#   's1',
#   's3',
#   'b3',
#   'b2',
#   'b3',
#   'b',
#   'b1',
#   's2',
#   's',
#   's3',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   's1',
#   'b3',
#   's1',
#   'b3',
#   'b3',
#   's3',
#   's3',
#   'b2',
#   's2',
#   's',
#   's3',
#   'b2'],
#  'f29': ['f1',
#   'f2',
#   'f1',
#   'f1',
#   'f2',
#   'f',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'f2',
#   'f2',
#   'f2',
#   'f3',
#   'f1',
#   'f2',
#   'f2',
#   'f1',
#   'f3',
#   'f2',
#   'f1',
#   'f1',
#   'f3',
#   'f1',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f1',
#   'f2',
#   'f2',
#   'f2'],
#  'b3': ['b1',
#   'b2',
#   'b3',
#   'f3',
#   'b1',
#   's1',
#   'b1',
#   'b3',
#   'b1',
#   'b1',
#   'b2',
#   'b3',
#   'b',
#   'b',
#   'b1',
#   'b2',
#   'b2',
#   'f2',
#   'b3',
#   'b1',
#   'b2',
#   'b1',
#   'b1',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   's',
#   'f1',
#   's3',
#   's3',
#   'b1',
#   's2',
#   'b2',
#   's2',
#   'b2',
#   'b3',
#   'f3',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   'b1',
#   'b3',
#   'z3',
#   'b3',
#   's1',
#   'b2',
#   'f1',
#   's3',
#   'b2',
#   'f3',
#   'f1',
#   'b1',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b1',
#   'b3',
#   'b2',
#   'b3',
#   'b3',
#   'f1',
#   'b1',
#   'b2',
#   'b1',
#   'b1',
#   'z1',
#   'z3',
#   'b2',
#   'b3',
#   'b1',
#   'b2',
#   's1',
#   'b1',
#   'b1',
#   'b3',
#   'b1',
#   'b2',
#   'z1',
#   'b3',
#   's2',
#   'b2',
#   'f2',
#   'b1',
#   'b1',
#   'z1',
#   's2',
#   'b2',
#   'b2',
#   'b2',
#   'b1',
#   'f1',
#   's1',
#   'b3',
#   'f1',
#   'f1',
#   'f1',
#   'b2',
#   'f3',
#   'b1',
#   's3',
#   's3',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   's3',
#   'f1',
#   'z1',
#   'b1',
#   'b1',
#   'z1',
#   's1',
#   's1',
#   's1',
#   'b2',
#   'b3',
#   'b2',
#   'b1',
#   'b3',
#   'f3',
#   'b3',
#   'b3',
#   'b1',
#   's2',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   'b3',
#   'b2',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b3',
#   'b1',
#   'b1',
#   'b3',
#   's2',
#   's3',
#   'b3',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   'b2',
#   'b1',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'b3',
#   's3',
#   'b3',
#   'f+1',
#   'b3',
#   'b1',
#   's1',
#   'z3',
#   's',
#   'f1',
#   'b3',
#   's2',
#   'b3',
#   'b3',
#   'b1',
#   'b3',
#   'b1',
#   'b2',
#   'b1',
#   'b1',
#   'b1',
#   'b2',
#   'b2',
#   'b1',
#   'b2',
#   'b2',
#   's2',
#   'b3',
#   'b1',
#   's2',
#   'b3',
#   's1',
#   'b1',
#   'b3',
#   'b3',
#   'b1',
#   'b3',
#   's3',
#   'b3',
#   'b2',
#   'b2',
#   'b2',
#   'b1',
#   'b1',
#   'b2',
#   'b1',
#   'b1',
#   'b1',
#   'b1',
#   'b1',
#   'b3',
#   'b',
#   'b2',
#   'b2',
#   'b3',
#   'b1',
#   'b3',
#   'b1',
#   'b1',
#   'f+1',
#   'b3',
#   'b1',
#   'b2',
#   'z3',
#   'b1',
#   'b3',
#   's2',
#   'b1',
#   'b3',
#   'b2',
#   's2',
#   'b2',
#   'b3',
#   'b3',
#   'b2',
#   'b3',
#   's3',
#   'b1',
#   'b1',
#   's1',
#   's2',
#   's3',
#   's2',
#   'b1',
#   'b1',
#   'b3',
#   'b3',
#   'b2',
#   'b2',
#   's2',
#   'b2',
#   's1',
#   'b2',
#   'b3',
#   'b2',
#   'b1',
#   'f1',
#   'f1',
#   'b1',
#   'f1',
#   'b2',
#   'b3',
#   'b3',
#   'b2',
#   's2',
#   's1',
#   'b1',
#   'b2',
#   'b1',
#   'b1',
#   'b3',
#   'f1',
#   'b3',
#   's2',
#   'b3',
#   'b3',
#   'b3',
#   'b2',
#   'b1',
#   'b1',
#   'b1',
#   's3',
#   'b2',
#   'b1',
#   's1',
#   'b1',
#   'b3',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   'b3',
#   'b1',
#   's1',
#   'b1',
#   's2',
#   's1',
#   'b3',
#   'b2',
#   'f1',
#   's1',
#   'b1'],
#  's3': ['f1',
#   'b2',
#   'z3',
#   'b2',
#   'f1',
#   'z3',
#   'f1',
#   'f1',
#   'b3',
#   'f3',
#   'f2',
#   'z1',
#   'b3',
#   'f3',
#   'f3',
#   'f1',
#   's3',
#   'b1',
#   'f1',
#   'f1',
#   'f+1',
#   'b1',
#   'f1',
#   'b1',
#   'b3',
#   'f3',
#   'z1',
#   'b2',
#   'b3',
#   'b3',
#   'b1',
#   'b3',
#   'b3',
#   'f+1'],
#  'b38': ['f2',
#   'b2',
#   'f2',
#   'f1',
#   'f1',
#   'f1',
#   'b3',
#   'f2',
#   'f3',
#   's3',
#   'z1',
#   'b2',
#   'f2',
#   'b3',
#   'f1',
#   'b2',
#   'f3',
#   'b2',
#   'f1',
#   'b1',
#   'f1',
#   'b1',
#   'b2',
#   'f1',
#   'f3',
#   'b3',
#   'b1',
#   'f3',
#   'b2',
#   'f2',
#   'f3'],
#  's2': ['f2',
#   'f3',
#   'f+1',
#   'b3',
#   'f+3',
#   'f1',
#   'f+3',
#   'b3',
#   'b3',
#   'f+1',
#   'b2',
#   'f1',
#   'f2',
#   'f1',
#   'v3',
#   'f3',
#   'b2',
#   'b1',
#   'f+1',
#   's1',
#   'v3',
#   'f3',
#   'f3',
#   'v3',
#   'f3',
#   'f+3',
#   'f1',
#   'z1'],
#  'f23': ['f1'],
#  'y2': ['s1', 'b3'],
#  'b17': ['f1',
#   'f+3',
#   'f3',
#   'f1',
#   'f3',
#   'f+3',
#   'f1',
#   'f3',
#   'f1',
#   'r2',
#   'f2',
#   'f1',
#   'f+3',
#   'v3',
#   'f+1',
#   'f+3',
#   'f1',
#   'f+3'],
#  'b37': ['f1',
#   'z3',
#   'b3',
#   'f3',
#   'z3',
#   'f3',
#   'f+1',
#   'b2',
#   'b3',
#   'f1',
#   'f3',
#   'f3',
#   'b2',
#   'b3',
#   'b3',
#   'f3',
#   'b1',
#   'f3',
#   'b3',
#   'z3',
#   'b3',
#   'b3',
#   'b3',
#   'f+1',
#   'f3',
#   'b1',
#   'f1'],
#  'f39': ['b2',
#   'f2',
#   'b2',
#   'f3',
#   'b2',
#   'f',
#   'b1',
#   'f1',
#   'b2',
#   'b2',
#   'f2',
#   'f1',
#   'f2',
#   'b2',
#   'b1',
#   'f1',
#   'b1',
#   'b1',
#   'f1',
#   'b3',
#   's2',
#   'b3',
#   'f',
#   'f2',
#   'f1',
#   'b2'],
#  'r2': ['f+1', 'f+3', 'f3', 'f+3', 'f2', 'f+1', 'f1', 's1'],
#  'm2': [],
#  's1': ['f2',
#   'f2',
#   'f3',
#   'f1',
#   'f2',
#   'v1',
#   'f1',
#   'f+1',
#   'v3',
#   'f1',
#   'f2',
#   'f1',
#   'f2'],
#  's18': ['f2', 'f3'],
#  'z1': ['f2'],
#  'f17': ['f1', 'f3', 'f1'],
#  'l2': [],
#  's28': ['f+3', 'f+1', 'f1', 'f3', 'f+1', 'f2', 'f3', 'f+3'],
#  'b+2': ['f2'],
#  's29': ['f1', 'f1', 'f1', 'f1', 'f', 'f1'],
#  'f;38': ['f1'],
#  'o3': ['s2', 's1', 'b2', 's2'],
#  'o2': ['f2', 'b2', 'f'],
#  'z3': ['b', 's2'],
#  'p2': ['f3', 'r2'],
#  's39': ['f1', 'f3', 'b1'],
#  'b-3': [],
#  'r1': ['f', 'v1', 'f2', 'f3', 'f2'],
#  'u+2': ['s3'],
#  'v3': ['s2', 'b1', 's', 'b3', 's2', 'b3'],
#  'y3': ['s1', 'b1', 's2'],
#  's37': ['b1'],
#  'b;39': ['b3'],
#  'f+1': ['f', 'r2', 'f', 'f', 'r2', 'f1', 'f2', 'f2', 'f3', 'f1', 'f1'],
#  'f;1': ['v1', 'f1'],
#  'b+1': ['f1', 'f2', 'f2'],
#  'v2': ['s2', 'f1'],
#  'r3': ['f1', 'b1', 'b1', 'f3', 'f+1', 'b3', 's1', 'b1', 'f1'],
#  'u+3': ['s3'],
#  'b;1': ['f3', 'f1'],
#  'b;2': ['v1', 'f3'],
#  'f+2': ['b3', 'b2'],
#  'y+3': ['b2', 's2'],
#  'b;3': [],
#  'b287': ['f1'],
#  'r28': [],
#  'm+1': [],
#  'f;2': [],
#  '6': ['b3',
#   'b2',
#   'f',
#   'b28',
#   'b28',
#   'f2',
#   'b2',
#   'b2',
#   'f',
#   's',
#   'b28',
#   'b17',
#   'b',
#   'b29',
#   'b1',
#   'b28',
#   'f27',
#   's',
#   'b1',
#   'b28',
#   'b18',
#   'f29',
#   'f28',
#   'b29',
#   'f18',
#   'b29',
#   'b17',
#   'f18',
#   'b29',
#   'f28',
#   'b2',
#   'b2',
#   'b',
#   'b2',
#   'b2',
#   'b2',
#   'b2',
#   'b2',
#   'b27',
#   'b38',
#   'b3',
#   'b28',
#   'b17',
#   'f28',
#   'b27',
#   'b3',
#   'b27',
#   'b2',
#   'b18',
#   'f2',
#   'f18',
#   'b2',
#   'f1',
#   'b27',
#   's2',
#   'f28',
#   'b19',
#   'b28',
#   'b1',
#   'b2',
#   'b1',
#   'b29',
#   'b19',
#   'b29',
#   'f29',
#   'b28',
#   'b28',
#   'f1',
#   'b1',
#   'b2',
#   'f28',
#   'f18',
#   'b2',
#   'b27',
#   'b28',
#   'b18',
#   'b1',
#   'b18',
#   'b28',
#   'b18',
#   'b28',
#   'b1',
#   'b28',
#   'b28',
#   'b38',
#   'b2',
#   'b1',
#   'b1',
#   's28',
#   'f18',
#   'b28',
#   'b28',
#   'b18',
#   'b2',
#   'b27',
#   'b1',
#   'b27',
#   'f2',
#   'b1',
#   'b',
#   'b27',
#   'b17',
#   'b',
#   'b18',
#   'b1',
#   'b18',
#   'b2',
#   'b29',
#   's',
#   'b18',
#   'f28',
#   'b27',
#   'b28',
#   'b28',
#   'b28',
#   'f28',
#   'b',
#   'b2',
#   'b18',
#   'b29',
#   'b1',
#   'b28',
#   'f3',
#   'b18',
#   'b3',
#   'b1',
#   'f28',
#   'f',
#   'b2',
#   'b1',
#   'b18',
#   'b28',
#   'b1',
#   'b1',
#   'b28',
#   'b2',
#   'f28',
#   'b28',
#   'b18',
#   'b28',
#   'b27',
#   'b27',
#   'b29',
#   'b19',
#   'b28',
#   'b18',
#   'b28',
#   'f28',
#   'b28',
#   'b28',
#   's',
#   'b1',
#   's',
#   's28',
#   'f',
#   'b28',
#   'b17',
#   'f2',
#   'b29',
#   'b',
#   'b38',
#   'b27',
#   's',
#   'b28',
#   'f',
#   'b',
#   'f',
#   'f29',
#   'b29',
#   'b',
#   'f27',
#   'b28',
#   's28',
#   'b29',
#   'f18',
#   's',
#   'b18',
#   'f',
#   'b28',
#   's28',
#   'f29',
#   'b28',
#   'b27',
#   'b27',
#   'b27',
#   'f28',
#   'b28',
#   'b2',
#   'b2',
#   'b18',
#   'b27',
#   'b17',
#   'b17',
#   's2',
#   'b29',
#   'b2',
#   'b1',
#   'f28',
#   'b2',
#   'b18',
#   'b27',
#   'b29',
#   'b28',
#   's28',
#   'f18',
#   'b28',
#   'b28',
#   's2',
#   'b27',
#   'b',
#   'b27',
#   'b',
#   'b1',
#   'b28',
#   'b',
#   'b18',
#   's',
#   'b27',
#   's28',
#   'b19',
#   'f',
#   'b',
#   'b29',
#   'b',
#   's28',
#   'b27',
#   'f37',
#   'b29',
#   'b29',
#   'b19',
#   'b19',
#   'b29',
#   'b17',
#   'b19',
#   'b',
#   'b28',
#   'b',
#   'f29',
#   'f29',
#   'f',
#   'b19',
#   'b29',
#   'b19',
#   'b',
#   'b29',
#   'b',
#   'b19',
#   'b',
#   's',
#   'b29',
#   'b27',
#   'f28',
#   'b2',
#   'b1',
#   'b28',
#   'b2',
#   'b18',
#   'b28',
#   'f',
#   'b28',
#   'b18',
#   'b28',
#   'b29',
#   'b28',
#   'b28',
#   'b28',
#   'b1',
#   'b28',
#   'b2',
#   'f28',
#   'f29',
#   'b29',
#   'f29',
#   'b28',
#   'b19',
#   'b28',
#   'b28',
#   'f27',
#   'f28',
#   'b19',
#   's28',
#   'f18',
#   'b28',
#   'f38',
#   'b18',
#   'f27',
#   'b27',
#   'b29',
#   'f',
#   'b18',
#   'f',
#   'f',
#   'b18',
#   'b17',
#   'b3',
#   'f1',
#   'b19',
#   'b18',
#   'f2',
#   'b27',
#   's',
#   'b1',
#   'f18',
#   'f27',
#   'f27',
#   'b18',
#   'b1',
#   'b28',
#   'b',
#   'b28',
#   'b1',
#   'b2',
#   's1',
#   'b18',
#   'b2',
#   'b18',
#   'b28',
#   'b3',
#   'b28',
#   'b1',
#   'b1',
#   'b1',
#   'b28',
#   'f18',
#   'b2',
#   'b1',
#   's3',
#   'b28',
#   'b18',
#   'b29',
#   'f',
#   'b19',
#   'b2',
#   'b19',
#   'f3',
#   'b28',
#   'b2',
#   'f28',
#   'b2',
#   'b27',
#   'b28',
#   'b28',
#   'b18',
#   'b28',
#   'b28',
#   'b28',
#   'f29',
#   's28',
#   's28',
#   'b18',
#   'b29',
#   'b37',
#   'b38',
#   'b28',
#   'b18',
#   's1',
#   'b28',
#   'b28',
#   'f2',
#   'b1',
#   'b29',
#   'b27',
#   'f27',
#   'b19',
#   'f1',
#   'f27',
#   'b18',
#   'b2',
#   'b28',
#   'b28',
#   'b28',
#   'b27',
#   'b19',
#   'b28',
#   'b29',
#   'f18',
#   'b29',
#   'b27',
#   'b37',
#   'b28',
#   'b27',
#   'f28',
#   'b27',
#   's28',
#   'b28',
#   'b18',
#   's1',
#   'b28',
#   'b27',
#   'b28',
#   'b28',
#   'b28',
#   'f27',
#   'b18',
#   'f2',
#   'b29',
#   'b29',
#   's2',
#   's28',
#   'b38'],
#  '4': ['b28',
#   'f1',
#   'f18',
#   'f28',
#   'b28',
#   'b2',
#   'b38',
#   'b19',
#   'f',
#   'f',
#   'b29',
#   'b29',
#   's28',
#   'b1',
#   's28',
#   'b38',
#   'b1',
#   's28',
#   'f1',
#   'f28',
#   'b3',
#   'b1',
#   'b28',
#   'f28',
#   'b28',
#   'b28',
#   'b27',
#   's1',
#   's2',
#   's28',
#   'f2',
#   's2',
#   's1',
#   'b18',
#   's1',
#   'b1',
#   'b1',
#   'b29',
#   'b2',
#   'f2',
#   'b1',
#   's1',
#   'b1',
#   'b1',
#   'b28',
#   'b2',
#   'b27',
#   'b28',
#   'f2',
#   'b28',
#   'b2',
#   'b3',
#   's',
#   'b2',
#   'f2',
#   'b3',
#   'f',
#   'b18',
#   'b28',
#   'b28',
#   'f1',
#   's3',
#   'b38',
#   'b37',
#   's3',
#   'b38',
#   'b28',
#   'b2',
#   'b37',
#   'f27',
#   'b2',
#   'b29',
#   'b28',
#   'b3',
#   'f28',
#   'b28',
#   'b1',
#   'b37',
#   'b27',
#   'b28',
#   'f1',
#   'b27',
#   'b28',
#   'b38',
#   'b28',
#   's28',
#   's2',
#   'b27',
#   'b28',
#   'b28',
#   'b38',
#   'b18',
#   's28',
#   'b',
#   'b28',
#   'b18',
#   'b28',
#   'b28',
#   'b1',
#   'b2',
#   'f28',
#   'b18',
#   'b28',
#   'f28',
#   'f27',
#   'b28',
#   'b2',
#   'b28',
#   'b27',
#   'b2',
#   's2',
#   'b28',
#   'b28',
#   'f1',
#   'b37',
#   'f2',
#   's28',
#   'b2',
#   'b28',
#   'b28',
#   'b28',
#   'b2',
#   's28',
#   'b2',
#   'b28',
#   's28',
#   'f2',
#   's28',
#   's',
#   's2',
#   'b28',
#   'b28',
#   'b1',
#   'f3',
#   'b28',
#   'b28',
#   's28',
#   'b2',
#   'f1',
#   's1',
#   'b2',
#   'f37',
#   'f18',
#   'b2',
#   'f1',
#   'b3',
#   'f1',
#   'f27',
#   'b28',
#   'f28',
#   's28',
#   's28',
#   's2',
#   'b3',
#   'b37',
#   's2',
#   'b28',
#   'b18',
#   'b2',
#   'b3',
#   's3',
#   'b38',
#   'b18',
#   'b28',
#   'b27',
#   'b38',
#   's',
#   'b37',
#   'b27',
#   'b2',
#   'b27',
#   's2',
#   'b3',
#   'b18',
#   'b28',
#   's2',
#   'b28',
#   'b28',
#   'f18',
#   'b2',
#   'b27',
#   'b17',
#   'f28',
#   'b1',
#   's1',
#   'b28',
#   'b',
#   'b19',
#   'b38',
#   'f',
#   'f18',
#   'b29',
#   'b',
#   'f29',
#   'f',
#   'f27',
#   'f',
#   'f',
#   's',
#   'f2',
#   's',
#   'f',
#   'f29',
#   'f',
#   'f',
#   'f',
#   'f37',
#   'f',
#   'b28',
#   'b27',
#   'b27',
#   'b3',
#   'b1',
#   'f27',
#   'f1',
#   'b28',
#   'b28',
#   'b38',
#   'f28',
#   'b1',
#   'b28',
#   's28',
#   'b28',
#   'b28',
#   'b2',
#   'b38',
#   'b18',
#   'b28',
#   'b28',
#   'b28',
#   'b29',
#   'b3',
#   'b2',
#   'b27',
#   'b37',
#   'f28',
#   'b18',
#   'b28',
#   'b38',
#   's',
#   'b28',
#   'b2',
#   'b28',
#   'b1',
#   'b28',
#   'b28',
#   'b19',
#   'b29',
#   'b27',
#   'b29',
#   's28',
#   'f28',
#   'b2',
#   'b28',
#   'b2',
#   'b27',
#   'b28',
#   'f28',
#   'b28',
#   'b28',
#   'b37',
#   'b28',
#   'b2',
#   'b38',
#   'b28',
#   'b29',
#   'b1',
#   'b38',
#   'b1',
#   's3',
#   'b27',
#   'b29',
#   'b27',
#   'b37',
#   's28',
#   'f28',
#   'b27',
#   'f',
#   'b37',
#   's',
#   'b28',
#   's',
#   'b29',
#   'b',
#   'b29',
#   'b',
#   'b',
#   'b38',
#   'b',
#   'f',
#   'b',
#   'b',
#   'b',
#   'b38',
#   'b27',
#   'b',
#   'f',
#   'b29',
#   'b37',
#   's',
#   'b19',
#   'b27',
#   'b19',
#   'b19',
#   'b',
#   'b29',
#   'b',
#   'b18',
#   'b2',
#   'b28',
#   'b28',
#   'b37',
#   'b28',
#   'b28',
#   'b28',
#   'b2',
#   'b18',
#   'b37',
#   'b28',
#   'b28',
#   'b2',
#   'b29',
#   'b29',
#   'f28',
#   'b2',
#   'b28',
#   'b38',
#   'b28',
#   'f18',
#   's1',
#   'b28',
#   'b38',
#   'f28',
#   'b2',
#   'f38',
#   'f18',
#   's28',
#   'b28',
#   'b28',
#   'f2',
#   'b28',
#   'b2',
#   'b28',
#   'b38',
#   's28',
#   'b28',
#   'b',
#   'b38',
#   's28',
#   'f37',
#   's28',
#   'f29',
#   'b28',
#   'b27',
#   'b28',
#   'f18',
#   'b28',
#   'b28',
#   's2',
#   'b19',
#   'b37',
#   'b28',
#   'b1',
#   'b38',
#   'b2',
#   'b28',
#   'b3',
#   'b2',
#   'b28',
#   'b2',
#   'b19',
#   'f29',
#   'b28',
#   'b38',
#   'b27',
#   'b28',
#   'b27',
#   'b',
#   'b3',
#   'f2',
#   'b38',
#   'b38',
#   'b18',
#   'b29',
#   's28',
#   'b3',
#   'b28',
#   'b3',
#   'b37',
#   'b19',
#   'b28',
#   'b27',
#   'b29',
#   'b29',
#   'b29',
#   'b28',
#   'f3',
#   'f3',
#   'b29',
#   'b27',
#   'b28',
#   'f27',
#   'f28',
#   'b28',
#   'b28',
#   'b29',
#   'f2',
#   'b2',
#   'b29',
#   'b3',
#   'b28',
#   'f28',
#   'b28',
#   'b38',
#   'b28',
#   'f3',
#   'b28',
#   's28',
#   'b17',
#   'b28',
#   'b28',
#   'b28',
#   'b28',
#   'b38',
#   'b28',
#   'b28',
#   'f28',
#   'b2',
#   'f38',
#   'f',
#   'b27',
#   'b2',
#   'b27',
#   'b29',
#   'f18',
#   'b17',
#   'b1',
#   'f27',
#   'b28',
#   'f1',
#   'b28',
#   'b27',
#   'b27',
#   'b27',
#   'b18',
#   'b37',
#   'b28',
#   'b38',
#   'f1',
#   'b28',
#   'f38',
#   'b38',
#   'b1',
#   'b28',
#   'b2',
#   'b19',
#   'b18',
#   'b28',
#   's28',
#   's28',
#   's',
#   's28',
#   'f1',
#   'f2',
#   's28',
#   'f28',
#   's2',
#   's28',
#   's28',
#   's28',
#   's2',
#   's28',
#   's28',
#   's2',
#   'f28',
#   'f3',
#   'b2',
#   's28',
#   'f1',
#   'b2',
#   'b29'],
#  '5': ['f18',
#   'f28',
#   'f28',
#   'b27',
#   'f',
#   'b17',
#   'b',
#   'b28',
#   'b38',
#   'b',
#   'b2',
#   'f',
#   'b28',
#   's28',
#   'b',
#   'f29',
#   'b28',
#   'f2',
#   's28',
#   'b37',
#   'b',
#   'b',
#   'f29',
#   'b27',
#   'f2',
#   'b1',
#   'b28',
#   's28',
#   'b1',
#   'f28',
#   'b38',
#   'b28',
#   'b2',
#   'b18',
#   'f1',
#   'b29',
#   'f1',
#   'b27',
#   'b1',
#   'b29',
#   'f',
#   'b1',
#   'b28',
#   'b17',
#   'b29',
#   'f1',
#   'b38',
#   'b2',
#   'b27',
#   'b3',
#   'b2',
#   'b2',
#   'b',
#   'b3',
#   'b2',
#   'b',
#   'f29',
#   'b29',
#   'b1',
#   'f2',
#   'f1',
#   'b2',
#   'f2',
#   'b1',
#   'b29',
#   'b29',
#   'b29',
#   'b19',
#   'b2',
#   'b28',
#   'b17',
#   'b1',
#   'f28',
#   'b2',
#   'f2',
#   'b17',
#   'b1',
#   'b18',
#   'b28',
#   'b27',
#   'b18',
#   'b2',
#   'b28',
#   'b28',
#   'b1',
#   'f28',
#   'b2',
#   'f28',
#   'b19',
#   'b18',
#   'f28',
#   'b28',
#   's28',
#   'b2',
#   'b2',
#   'f28',
#   'b29',
#   'f1',
#   'f2',
#   'f2',
#   'b27',
#   'f29',
#   'b27',
#   'f3',
#   'b29',
#   'b18',
#   'f28',
#   'f2',
#   'f29',
#   'b28',
#   'f18',
#   'b28',
#   'f28',
#   'b29',
#   'b27',
#   'b28',
#   'f2',
#   'b28',
#   'b29',
#   'f28',
#   'f18',
#   'f27',
#   'f',
#   'b27',
#   'b',
#   'f37',
#   'f29',
#   'f',
#   'f29',
#   'b28',
#   'b38',
#   'b29',
#   'f29',
#   'b27',
#   'b17',
#   'b27',
#   'f',
#   'f27',
#   's28',
#   'f18',
#   's28',
#   'b18',
#   'f',
#   'f',
#   'f28',
#   'f18',
#   'b18',
#   'b28',
#   'f2',
#   'b1',
#   'b28',
#   'b18',
#   'b28',
#   'f27',
#   'b29',
#   'b18',
#   'b28',
#   'b28',
#   'b18',
#   'f2',
#   'b3',
#   'f18',
#   'b18',
#   'b28',
#   'b18',
#   'f2',
#   'b2',
#   'b2',
#   'f38',
#   'b27',
#   'b28',
#   'f27',
#   'f29',
#   'f28',
#   'f27',
#   'b',
#   'f29',
#   'f29',
#   'f',
#   'b18',
#   'b38',
#   'f',
#   'f29',
#   'b28',
#   'b29',
#   'b28',
#   'b18',
#   'b28',
#   'b28',
#   'f2',
#   'b',
#   'f18',
#   'f2',
#   'f1',
#   'b2',
#   'f28',
#   'f2',
#   'b28',
#   'b28',
#   'b',
#   'f28',
#   'f2',
#   'f27',
#   'b29',
#   'b2',
#   'b28',
#   'f29',
#   'f',
#   'f28',
#   'b28',
#   'b28',
#   'b17',
#   'f1',
#   'f28',
#   'b29',
#   'b27',
#   'b19',
#   'b37',
#   'b37',
#   'b27',
#   'b27',
#   'f3',
#   'f27',
#   'b3',
#   's3',
#   'b29',
#   'b19',
#   'b1',
#   'b18',
#   'f3',
#   'b27',
#   'b18',
#   'b18',
#   'f27',
#   'f1',
#   'b17',
#   'b2',
#   'b28',
#   'b28',
#   'b28',
#   'b28',
#   'f1',
#   'b38',
#   'b28',
#   'b28',
#   'b27',
#   'b28',
#   'b19',
#   'f2',
#   'b28',
#   'f28',
#   'f18',
#   'f18',
#   's28',
#   'b38',
#   'b37',
#   'f28',
#   'f27',
#   'b2',
#   'f28',
#   'f1',
#   'f2',
#   'f28',
#   's2',
#   'f29',
#   'f28',
#   'b18',
#   'f29',
#   'b27',
#   'b18',
#   'b28',
#   'f2',
#   's28',
#   'f28',
#   'f2',
#   's28',
#   'f28',
#   's28',
#   'b27',
#   'f37',
#   'f2',
#   'b38',
#   's28'],
#  'v1': ['f1', 'f1', 'f', 'f1'],
#  '': [],
#  'c6': ['b',
#   'b28',
#   'b1',
#   'b2',
#   'b1',
#   'b28',
#   'b2',
#   'b27',
#   'b18',
#   'b27',
#   'b2',
#   'f29',
#   'b27',
#   'b28',
#   'b29',
#   'b27',
#   'f1'],
#  'o=3': ['s'],
#  'c4': ['b18', 'b2', 'b38', 'b28', 'b', 'f27', 'b28', 'b27', 'b28'],
#  'c5': ['b28',
#   'b2',
#   'f29',
#   'f28',
#   'b18',
#   'b18',
#   'b28',
#   'f37',
#   'f18',
#   'b28',
#   'f1'],
#  'b-1': ['f2', 'f3'],
#  'f-1': ['f1'],
#  'm1': ['f'],
#  'cc4': ['b29'],
#  'f3+': ['b2'],
#  '6+': [],
#  'u1': ['f+1', 'f', 'f1', 'f3'],
#  'u3': ['b3', 's3'],
#  'u2': [],
#  'u+;3': ['s3'],
#  'r-3': ['s1'],
#  '4+': ['s', 'b2'],
#  'cc6': ['b18'],
#  'f-3': [],
#  'f;3': ['f3'],
#  's-1': [],
#  'r+3': ['b3'],
#  'i=1': ['f3'],
#  's+2': [],
#  'i3': ['s3'],
#  'z2': ['s3'],
#  'o-2': ['f1'],
#  'o1': [],
#  'X': ['5',
#   '6',
#   '4',
#   '4',
#   '4',
#   '6',
#   '4',
#   '6',
#   '6',
#   '4',
#   '4',
#   '4',
#   '4',
#   '5',
#   '4',
#   '4',
#   '4',
#   '5',
#   '6',
#   '5',
#   '6',
#   '5',
#   '5',
#   '4',
#   '4',
#   '6',
#   '6',
#   '5',
#   '4',
#   '4',
#   '5',
#   '5',
#   '4',
#   '5',
#   '5',
#   '4',
#   '5']}

# %%
from collections import Counter

cnts = {}
for k, v in all_dict_win2.copy().items():
    tmp_cnt = Counter(v)
    cnts[k] = tmp_cnt
for k, v in all_dict_lost2.copy().items():
    tmp_cnt = Counter(v)
    if k not in cnts:
        cnts[k]={i:-j for i, j in tmp_cnt.items()}
    else:
        for i, j in tmp_cnt.items():
            if i in cnts[k]:
                cnts[k][i] -= j
            else:
                cnts[k][i] = -j
    
cnts

cnts2 = {}

for k, v in cnts.items():
    tmp = []
    for i, j in v.items():
        if j < 10:
            continue
        else:
            tmp.extend([i for _ in range(j)])
    if len(tmp) == 0:
        print(k, '1')
        temp_val = -1000
        temp_key = ''
        for i, j in v.items():
            if j > temp_val:
                temp_val = j
                temp_key = i 
        if temp_key != '':
            tmp.extend([temp_key])
    if len(tmp) == 0:
        print(k, '2')
        continue
    cnts2[k] = tmp
#cnts2
# Out:
# f37 1
# f3 1
# m3 1
# b29 1
# s2 1
# b1 1
# f238 1
# f38 1
# f28 1
# s37 1
# b18 1
# f8 1
# f27 1
# b8 1
# m2 1
# b7 1
# b7 2
# s 1
# f 1
# b39 1
# s27 1
# f7 1
# b17 1
# f19 1
# s38 1
# b37 1
# s28 1
# b38 1
# f18 1
# l2 1
# l2 2
# b+3 1
# r2 1
# f39 1
# s39 1
# m+3 1
# m+3 2
# r3 1
# s1 1
# f17 1
# f-2 1
# b19 1
# s29 1
# f;1 1
# b-3 1
# b+38 1
# r27 1
# f+3 1
# f+2 1
# b;27 1
# m17 1
# m17 2
# b;3 1
# f;37 1
# u3 1
# b;1 1
# f;38 1
# m1 1
# l3 1
# l3 2
# f+1 1
# v2 1
# m 1
# m 2
# r1 1
# u1 1
# m27 1
# m27 2
# m28 1
# m28 2
# r29 1
# b;2 1
# l1 1
# l1 2
# s17 1
# s18 1
# f;28 1
# y37 1
# f;27 1
# r19 1
# y2 1
# u2 1
# r28 1
# f-1 1
# b+2 1
# 4 1
# 5 1
# b 1
# h-3 1
# c5 1
# c4 1
# f-3 1
# k1 1
# f1- 1
# c6 1
# y+2 1
# z2 1
# f;3 1
# s;3 1
# o1 1
# s+3 1
# z3 1
# o2 1
# v3 1
# 4+ 1
# b;-3 1
# b-1 1
# z1 1
# cc5 1
# cc5 2
# y3 1
# m+2 1
# m+2 2
# o=3 1
# v1 1
# 5+ 1
# i=1 1
# i=2 1
# h=3 1
# r+3 1
# r;1 1
# i3 1
# b+1 1
# b9 1
# f23 1
# o3 1
# p2 1
# u+2 1
# b;39 1
# u+3 1
# y+3 1
# b287 1
# m+1 1
# m+1 2
# f;2 1
# f;2 2
#  1
#  2
# cc4 1
# f3+ 1
# 6+ 1
# 6+ 2
# u+;3 1
# r-3 1
# cc6 1
# s-1 1
# s-1 2
# s+2 1
# s+2 2
# o-2 1

# %%
from aux_functions import *

# %%
Model, shots_opo_com = aux_fn(df, poss_prompts, all_shots)

# %%
# Building up the model function

#################### The threshold on shots rarity ###################
threshold = 1                                                        #
######################################################################

# Given current prompt p_t and shot s_t, return next prompt p_(t+1)
def model(prompt, shot):
    n_grams_ps = Model[poss_prompts.index(prompt), all_shots.index(shot)]
    if(len(n_grams_ps) > threshold):    # exclude rare reactions
        return np.random.choice(n_grams_ps)
    return 'n@'   # when (p, s) never happened, return unforced error in net

# Example: RN just served ('5') and we want to reply with a forehand ('f28'). This is what RN will reply (stochastic function)
model('5', 'f28')
# Out:
# 'b3'

# %% [markdown]
# # Your turn to serve!
#
# You can play against the historical RN: just type in the shots and see if you can beat him! You can try first with simple shots, like 'f3' or 'b2' or even with a volley 'v1'.

# %%
current_prompt = 'X'
while True:       ###### CAREFUL WHEN INTERRUPTING
    shot = input()
    next_prompt = model(current_prompt, shot)
    print(next_prompt)
    current_prompt = next_prompt
    if is_win(next_prompt) == 1:
        print('Point won!')
        break
    if is_win(next_prompt) == 0:
        print('Point lost!')
        break
# Out:
# 4
# f37
# f3
# f1*
# Point lost!

# %% [markdown]
# # Example and tester
#
# We provide here an example of policy and a function with which you can test your model.
#
# For testing your personal new policy, simply modify the first line of code and insert your policy dictionary.
#
# The final scoring will be done with this same function, with number_of_points_played >= 1000000 and different values of the threshold, to be sure that statistical fluctuations of the result are reduced.

# %%
# Test function that makes your policy (a.k.a. Phederos) play against historical RN !!

############################## Modify here! ##########################
example_policy = cnts2
######################################################################

number_of_points_played = 150000


serves_opponent = [shot for shot in [sh[0] for sh in shots_opo_com] if shot[0] in '456']
points_won  = 0
points_lost = 0


for num in range(number_of_points_played):
    print(num, end = '\r')
    # Random choice on who is serving
    if np.random.randint(0,2) == 0:
        current_prompt = 'X'
    else :
        current_prompt = np.random.choice(serves_opponent)
    while True:
        shot = np.random.choice(example_policy.get(current_prompt,['5']))
        next_prompt = model(current_prompt, shot)
        current_prompt = next_prompt
        if is_win(current_prompt) == 1:
            points_won  += 1
            break
        if is_win(current_prompt) == 0:
            points_lost += 1
            break
            
print('How well are we performing? '     , points_won/(points_lost + points_won))
print('Baseline historical performance: ', 1 - (df['Winner'].sum()/len(df['Winner'])))
# Out:
# How well are we performing?  0.7034133333333333
# Baseline historical performance:  0.5030959752321982

# %% [markdown]
# # Your turn now!
# Show us that you are up for the challenge and make your Phederos destroy the historical RN! Just be careful and do not get carried away... real challenges lie ahead of you all!
